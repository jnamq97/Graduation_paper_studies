# %% [markdown]
# # Model

# %% [markdown]
# VDSR\
# epoch : 80\
# filter : 64\
# layers : 5\
# loss function : L1

# %%
import os
import torch.nn as nn
import torch.optim as optim
from torchvision.transforms import *
import torch
import math 
from os.path import join
import torch.utils.data as data
import numpy as np
from os import listdir
from os.path import join
from PIL import Image, ImageOps
import random
from random import randrange
from math import sqrt
       
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------------        
class Conv_ReLU_Block(nn.Module): #used for VDSR
    def __init__(self):
        super(Conv_ReLU_Block, self).__init__() #super를 안해주면 부모 클래스의 init 함수가 Overriding 된다.
        self.conv = nn.Conv2d(in_channels= 64, out_channels = 64, kernel_size = 3, stride = 1, padding = 1, bias =False)
        self.relu = nn.ReLU(inplace=True) #inplace 연산은 결과값을 새로운 변수에 값을 저장하는 대신 기존의 데이터를 대체하는것
    def forward(self, x):
        return self.relu(self.conv(x)) 
    
class VDSR(nn.Module):
    def __init__(self):
        super(VDSR, self).__init__()
        self.input = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, stride=1, padding=1, bias=False)
        self.residual_layer = self.make_layer(Conv_ReLU_Block, 5)
        self.output = nn.Conv2d(in_channels=64, out_channels=3, kernel_size=3, stride=1, padding=1, bias=False)
        self.relu = nn.ReLU(inplace=True)
        
        for m in self.modules(): #모델의 모듈을 불러온다
            if isinstance(m, nn.Conv2d): #만약 그 모듈이 Conv2d이면 초기화를 해준다.
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, sqrt(2. / n)) #weight initialization (평균, 표준편차)
    def make_layer(self, block, num_of_layer):
        layers=[]
        for _ in range(num_of_layer):
            layers.append(block())
        return nn.Sequential(*layers) #*layers -> unpacking(deal with list elements separately)
    def forward(self, x):
        residual = x
        out = self.relu(self.input(x))
        out = self.residual_layer(out)
        out = self.output(out)
        out = torch.add(out, residual)
        return out
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------------  
def is_image_file(filename): #image file 인지 확인해줌
    return any(filename.endswith(extension) for extension in [".png", ".jpg", ".jpeg",".bmp"])
    
def load_img(filepath):
    img = Image.open(filepath).convert('RGB')
    return img
    
def rescale_img(img_in, scale):
    size_in = img_in.size
    new_size_in = tuple([int(x * scale) for x in size_in])
    img_in = img_in.resize(new_size_in, resample = Image.BICUBIC)
    return img_in
    
def get_patch(img_in, img_tar, img_bic, patch_size, scale, ix= -1, iy = -1): 
    #잘 이해 안됨. 각 크기가 맞는 랜덤한 패치를 return 하는거?
    (ih, iw) = img_in.size
    (th, tw) = (scale * ih, scale * iw)
    
    patch_mult = scale
    tp = patch_mult * patch_size
    ip = tp // scale
    
    if ix == -1:
        ix = random.randrange(0, iw - ip + 1)
    if iy == -1:
        iy = random.randrange(0, ih - ip + 1)

    (tx, ty) = (scale * ix, scale * iy)

    img_in = img_in.crop((iy,ix,iy + ip, ix + ip))
    img_tar = img_tar.crop((ty,tx,ty + tp, tx + tp))
    img_bic = img_bic.crop((ty,tx,ty + tp, tx + tp))
                
    info_patch = {
        'ix': ix, 'iy': iy, 'ip': ip, 'tx': tx, 'ty': ty, 'tp': tp}

    return img_in, img_tar, img_bic, info_patch

def augment(img_in, img_tar, img_bic, flip_h=True, rot=True):
    info_aug = {'flip_h': False, 'flip_v': False, 'trans': False}
    
    if random.random() < 0.5 and flip_h :
        img_in = ImageOps.flip(img_in)
        img_tar = ImageOps.flip(img_tar)
        img_bic = ImageOps.flip(img_bic)
        info_aug['flip_h'] = True
    if rot : 
        if random.random() < 0.5:
            img_in = ImageOps.mirror(img_in)
            img_tar = ImageOps.mirror(img_tar)
            img_bic = ImageOps.mirror(img_bic)
            info_aug['flip_v'] = True
        if random.random() < 0.5:
            img_in = img_in.rotate(180)
            img_tar = img_tar.rotate(180)
            img_bic = img_bic.rotate(180)
            info_aug['trans'] = True
    return img_in, img_tar, img_bic, info_aug
    
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------------
class DatasetFromFolder(data.Dataset): #training dataset class
    def __init__(self, image_dir, patch_size, upscale_factor, data_augmentation, transform=None):
        super(DatasetFromFolder, self).__init__()
        self.image_filenames = [join(image_dir, x) for x in listdir(image_dir) if is_image_file(x)]  #image file들의 name(dir)을 담은 리스트
        self.patch_size = patch_size
        self.upscale_factor = upscale_factor
        self.transform = transform
        self.data_augmentation = data_augmentation
    def __getitem__(self, index):
        target = load_img(self.image_filenames[index])
        
        input = target.resize((int(target.size[0]/self.upscale_factor), int(target.size[1]/self.upscale_factor)), Image.BICUBIC) 
        bicubic = rescale_img(input, self.upscale_factor) #upscale_factor로 줄이고 다시 늘려서 LR image 를 만든것 같다.(방식은 bicubic)
        input, target, bicubic, _ = get_patch(input,target,bicubic,self.patch_size, self.upscale_factor) #crop된 image로 다시 정의함
        
        if self.data_augmentation :
            input, target, bicubic, _ = augment(input, target, bicubic)
        if self.transform :
            input = self.transform(input)
            bicubic = self.transform(bicubic)
            target = self.transform(target)
            
        return input, target, bicubic #그럼 최종 return은 patch(crop된 image)인 건가?
    
    def __len__(self):
        return len(self.image_filenames)
    
class DatasetFromFolderEval(data.Dataset): #test dataset class
    
    def __init__(self, lr_dir, upscale_factor, transform = None):
        super(DatasetFromFolderEval, self).__init__()
        self.image_filenames = [join(lr_dir, x) for x in listdir(lr_dir) if is_image_file(x)]
        self.upscale_factor = upscale_factor
        self.transform = transform
        
    def __getitem__(self, index):
        target = load_img(self.image_filenames[index])
        _, file = os.path.split(self.image_filenames[index])  #주소 split해서 파일이름을 가지는 file 변수 정의(head, tail) tail은 마지막 구성요소
        
        input = target.resize((int(target.size[0]/self.upscale_factor),int(target.size[1]/self.upscale_factor)), Image.BICUBIC)
        bicubic = rescale_img(input, self.upscale_factor)
        
        if self.transform:
            input = self.transform(input)
            bicubic = self.transform(bicubic)
            target = self.transform(target)
        
        return input, bicubic, target, file
        
    def __len__(self):
        return len(self.image_filenames)
        
def transform():
    return Compose([
        ToTensor(),
    ])
def get_training_set(data_dir, hr, upscale_factor, patch_size, data_augmentation):
    hr_dir = join(data_dir, hr)
    return DatasetFromFolder(hr_dir, patch_size, upscale_factor, data_augmentation, 
                            transform = transform())
def get_eval_set(lr_dir, upscale_factor):
    return DatasetFromFolderEval(lr_dir, upscale_factor,
                                transform = transform())

# %% [markdown]
# # Training

# %%
from __future__ import print_function
import argparse
from math import log10

import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.backends.cudnn as cudnn
from torch.autograd import Variable
from torch.utils.data import DataLoader
import pdb
import socket
import time
import easydict

from google.colab import drive
drive.mount('/content/gdrive')

opt  = easydict.EasyDict({ 
    "batchSize": 32,           # batch size - 한번에 training할 patch의 숫자
    "lr": 1e-3,                # learning rate
    "upscale_factor": 2,       # Upscale 정도 - 2배, 4배
    "patch_size": 64,         # patch 크기
    "feature_number": 64,     # SRCNN model에서 사용할 feature 숫자
    
    "start_iter": 1,           
    "nEpochs": 80,            # training 횟수
    "snapshots": 20,           # weight 저장 주기
   
    "data_dir":"/content/gdrive/My Drive/study/VDSR/data/train/", # dataset 저장 위치
    "hr_train_dataset": "DIV2K_train_HR", # training에 사용할 dataset 종류

    "model_type": "VDSR",         # 모델이름

    "save_folder": "/content/gdrive/My Drive/study/VDSR/weights/", # weight 저장 위치
    

    "pretrained_sr": "/content/gdrive/My Drive/study/VDSR/weights/ckpt_diff11_label",
    "pretrained": False,
    "data_augmentation": False,
    "residual": False,
    "gpu_mode": True,
    "threads": 1,
    "seed": 123,
    "gpus": 1,
    "prefix": "tpami_residual_filter8"})

gpus_list = range(opt.gpus)
hostname = str(socket.gethostname) #저장 파일명으로 사용하려고 그냥 가져온것
cudnn.benchmark = True # cuDNN이 최적의 알고리즘을 선택하도록 해줌(잘 이해 안됨)
print(opt)

def train(epoch):
    epoch_loss = 0
    model.train()
    for iteration, batch in enumerate(training_data_loader, 1): #시작 인덱스(i)를 1부터 세겠다는 뜻
        _, target, bicubic = Variable(batch[0]), Variable(batch[1]), Variable(batch[2]) #torch.autograd.Variable 하는 이유??
        if cuda : 
             # input = input.cuda(gpus_list[0])
            target = target.cuda(gpus_list[0])
            bicubic = bicubic.cuda(gpus_list[0])
        optimizer.zero_grad()
        t0 = time.time()
        prediction = model(bicubic)
        
        if opt.residual :
            prediction = prediction + bicubic
        
        loss = criterion(prediction, target)
        t1 = time.time()
        epoch_loss += loss.data
        loss.backward()
        optimizer.step()
        
        print("===> Epoch[{}]({}/{}) : Loss: {:.4f} || Timer: {:.4f} sec.".format(epoch, iteration, len(training_data_loader), loss.data, (t1-t0))) 
    print("===> Epoch {} Complete : Avg. Loss: {:.4f}".format(epoch, epoch_loss / len(training_data_loader)))
 #-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------       
def print_network(net):  #어디에 쓰임????
    num_params = 0
    for param in net.parameters():
        num_params += param.numel()
    print(net)
    print('Total number of parameters: %d' % num_params)
    
def checkpoint(epoch): #check point 마다 weight를 저장해줌 (모델의 매개변수들을 저장해준다)
    model_out_path = opt.save_folder+hostname+"_epoch_{}.pth".format(epoch)
    torch.save(model.state_dict(), model_out_path)
    print("Checkpoint saved to {}".format(model_out_path))
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------    
if __name__ == '__main__':
    
    cuda = opt.gpu_mode
    if cuda and not torch.cuda.is_available():
        raise Exception("No GPU found, please run without --cuda")
    torch.manual_seed(opt.seed)
    if cuda : 
        torch.cuda.manual_seed(opt.seed)
    
    print('===> Loading datasets')
    train_set = get_training_set(opt.data_dir, opt.hr_train_dataset, opt.upscale_factor, opt.patch_size, opt.data_augmentation)
    training_data_loader = DataLoader(dataset = train_set, num_workers=opt.threads, batch_size = opt.batchSize, shuffle=True)
    
    print('===> Building model ', opt.model_type)
    if opt.model_type == 'VDSR':
        model = VDSR()
        model = torch.nn.DataParallel(model, device_ids=gpus_list)
    criterion = nn.L1Loss()   #Loss function
    
    if opt.pretrained:
        model_name = os.path.join(opt.save_folder + opt.pretrained_sr)
        if os.path.exists(model_name):
            #model= torch.load(model_name, map_location=lambda storage, loc: storage)
            model.load_state_dict(torch.load(model_name, map_location=lambda storage, loc: storage))
            print('Pre-trained SR model is loaded.')  
    if cuda:
        model = model.cuda(gpus_list[0])
        criterion = criterion.cuda(gpus_list[0])
        
    optimizer = optim.Adam(model.parameters(), lr = opt.lr, betas = (0.9, 0.999), eps=1e-8)
    
    for epoch in range(opt.start_iter, opt.nEpochs +1):
        train(epoch)
        #learning rate decay
        if (epoch+1) % (opt.nEpochs/2) == 0:
            for param_group in optimizer.param_groups:
                param_group['lr'] /= 10.0
            print('Learning rate decay : lr={}'.format(optimizer.param_groups[0]['lr']))
        
        if (epoch+1) % (opt.snapshots) == 0:
            checkpoint(epoch)
# Out:
# Mounted at /content/gdrive
# {'batchSize': 32, 'lr': 0.001, 'upscale_factor': 2, 'patch_size': 64, 'feature_number': 64, 'start_iter': 1, 'nEpochs': 80, 'snapshots': 20, 'data_dir': '/content/gdrive/My Drive/study/SRCNN/data/train/', 'hr_train_dataset': 'DIV2K_train_HR', 'model_type': 'VDSR', 'save_folder': '/content/gdrive/My Drive/study/SRCNN/weights/', 'pretrained_sr': '/content/gdrive/My Drive/study/SRCNN/weights/ckpt_diff11_label', 'pretrained': False, 'data_augmentation': False, 'residual': False, 'gpu_mode': True, 'threads': 1, 'seed': 123, 'gpus': 1, 'prefix': 'tpami_residual_filter8'}
# ===> Loading datasets
# ===> Building model  VDSR
# ===> Epoch[1](1/25) : Loss: 0.5398 || Timer: 0.9544 sec.
# ===> Epoch[1](2/25) : Loss: 0.9230 || Timer: 0.0057 sec.
# ===> Epoch[1](3/25) : Loss: 0.2629 || Timer: 0.0021 sec.
# ===> Epoch[1](4/25) : Loss: 0.1621 || Timer: 0.0019 sec.
# ===> Epoch[1](5/25) : Loss: 0.0667 || Timer: 0.0023 sec.
# ===> Epoch[1](6/25) : Loss: 0.0514 || Timer: 0.0025 sec.
# ===> Epoch[1](7/25) : Loss: 0.0604 || Timer: 0.0032 sec.
# ===> Epoch[1](8/25) : Loss: 0.0649 || Timer: 0.0021 sec.
# ===> Epoch[1](9/25) : Loss: 0.0559 || Timer: 0.0019 sec.
# ===> Epoch[1](10/25) : Loss: 0.0413 || Timer: 0.0020 sec.
# ===> Epoch[1](11/25) : Loss: 0.0318 || Timer: 0.0021 sec.
# ===> Epoch[1](12/25) : Loss: 0.0262 || Timer: 0.0018 sec.
# ===> Epoch[1](13/25) : Loss: 0.0297 || Timer: 0.0022 sec.
# ===> Epoch[1](14/25) : Loss: 0.0320 || Timer: 0.0021 sec.
# ===> Epoch[1](15/25) : Loss: 0.0237 || Timer: 0.0050 sec.
# ===> Epoch[1](16/25) : Loss: 0.0244 || Timer: 0.0021 sec.
# ===> Epoch[1](17/25) : Loss: 0.0195 || Timer: 0.0020 sec.
# ===> Epoch[1](18/25) : Loss: 0.0217 || Timer: 0.0018 sec.
# ===> Epoch[1](19/25) : Loss: 0.0235 || Timer: 0.0020 sec.
# ===> Epoch[1](20/25) : Loss: 0.0237 || Timer: 0.0018 sec.
# ===> Epoch[1](21/25) : Loss: 0.0272 || Timer: 0.0022 sec.
# ===> Epoch[1](22/25) : Loss: 0.0213 || Timer: 0.0019 sec.
# ===> Epoch[1](23/25) : Loss: 0.0166 || Timer: 0.0018 sec.
# ===> Epoch[1](24/25) : Loss: 0.0210 || Timer: 0.0018 sec.
# ===> Epoch[1](25/25) : Loss: 0.0203 || Timer: 0.0015 sec.
# ===> Epoch 1 Complete : Avg. Loss: 0.1036
# ===> Epoch[2](1/25) : Loss: 0.0200 || Timer: 0.0031 sec.
# ===> Epoch[2](2/25) : Loss: 0.0219 || Timer: 0.0019 sec.
# ===> Epoch[2](3/25) : Loss: 0.0201 || Timer: 0.0025 sec.
# ===> Epoch[2](4/25) : Loss: 0.0219 || Timer: 0.0019 sec.
# ===> Epoch[2](5/25) : Loss: 0.0200 || Timer: 0.0024 sec.
# ===> Epoch[2](6/25) : Loss: 0.0169 || Timer: 0.0019 sec.
# ===> Epoch[2](7/25) : Loss: 0.0191 || Timer: 0.0021 sec.
# ===> Epoch[2](8/25) : Loss: 0.0151 || Timer: 0.0020 sec.
# ===> Epoch[2](9/25) : Loss: 0.0211 || Timer: 0.0020 sec.
# ===> Epoch[2](10/25) : Loss: 0.0174 || Timer: 0.0016 sec.
# ===> Epoch[2](11/25) : Loss: 0.0223 || Timer: 0.0019 sec.
# ===> Epoch[2](12/25) : Loss: 0.0223 || Timer: 0.0020 sec.
# ===> Epoch[2](13/25) : Loss: 0.0222 || Timer: 0.0021 sec.
# ===> Epoch[2](14/25) : Loss: 0.0181 || Timer: 0.0018 sec.
# ===> Epoch[2](15/25) : Loss: 0.0189 || Timer: 0.0019 sec.
# ===> Epoch[2](16/25) : Loss: 0.0180 || Timer: 0.0015 sec.
# ===> Epoch[2](17/25) : Loss: 0.0230 || Timer: 0.0021 sec.
# ===> Epoch[2](18/25) : Loss: 0.0270 || Timer: 0.0018 sec.
# ===> Epoch[2](19/25) : Loss: 0.0169 || Timer: 0.0022 sec.
# ===> Epoch[2](20/25) : Loss: 0.0148 || Timer: 0.0019 sec.
# ===> Epoch[2](21/25) : Loss: 0.0167 || Timer: 0.0020 sec.
# ===> Epoch[2](22/25) : Loss: 0.0175 || Timer: 0.0023 sec.
# ===> Epoch[2](23/25) : Loss: 0.0246 || Timer: 0.0021 sec.
# ===> Epoch[2](24/25) : Loss: 0.0205 || Timer: 0.0023 sec.
# ===> Epoch[2](25/25) : Loss: 0.0215 || Timer: 0.0014 sec.
# ===> Epoch 2 Complete : Avg. Loss: 0.0199
# ===> Epoch[3](1/25) : Loss: 0.0176 || Timer: 0.0031 sec.
# ===> Epoch[3](2/25) : Loss: 0.0214 || Timer: 0.0021 sec.
# ===> Epoch[3](3/25) : Loss: 0.0211 || Timer: 0.0024 sec.
# ===> Epoch[3](4/25) : Loss: 0.0195 || Timer: 0.0020 sec.
# ===> Epoch[3](5/25) : Loss: 0.0211 || Timer: 0.0023 sec.
# ===> Epoch[3](6/25) : Loss: 0.0165 || Timer: 0.0019 sec.
# ===> Epoch[3](7/25) : Loss: 0.0190 || Timer: 0.0023 sec.
# ===> Epoch[3](8/25) : Loss: 0.0174 || Timer: 0.0020 sec.
# ===> Epoch[3](9/25) : Loss: 0.0216 || Timer: 0.0018 sec.
# ===> Epoch[3](10/25) : Loss: 0.0186 || Timer: 0.0018 sec.
# ===> Epoch[3](11/25) : Loss: 0.0181 || Timer: 0.0019 sec.
# ===> Epoch[3](12/25) : Loss: 0.0167 || Timer: 0.0015 sec.
# ===> Epoch[3](13/25) : Loss: 0.0210 || Timer: 0.0023 sec.
# ===> Epoch[3](14/25) : Loss: 0.0216 || Timer: 0.0019 sec.
# ===> Epoch[3](15/25) : Loss: 0.0198 || Timer: 0.0020 sec.
# ===> Epoch[3](16/25) : Loss: 0.0168 || Timer: 0.0023 sec.
# ===> Epoch[3](17/25) : Loss: 0.0189 || Timer: 0.0020 sec.
# ===> Epoch[3](18/25) : Loss: 0.0164 || Timer: 0.0021 sec.
# ===> Epoch[3](19/25) : Loss: 0.0183 || Timer: 0.0021 sec.
# ===> Epoch[3](20/25) : Loss: 0.0154 || Timer: 0.0014 sec.
# ===> Epoch[3](21/25) : Loss: 0.0231 || Timer: 0.0020 sec.
# ===> Epoch[3](22/25) : Loss: 0.0226 || Timer: 0.0023 sec.
# ===> Epoch[3](23/25) : Loss: 0.0187 || Timer: 0.0019 sec.
# ===> Epoch[3](24/25) : Loss: 0.0230 || Timer: 0.0020 sec.
# ===> Epoch[3](25/25) : Loss: 0.0171 || Timer: 0.0014 sec.
# ===> Epoch 3 Complete : Avg. Loss: 0.0192
# ===> Epoch[4](1/25) : Loss: 0.0184 || Timer: 0.0032 sec.
# ===> Epoch[4](2/25) : Loss: 0.0158 || Timer: 0.0024 sec.
# ===> Epoch[4](3/25) : Loss: 0.0166 || Timer: 0.0018 sec.
# ===> Epoch[4](4/25) : Loss: 0.0225 || Timer: 0.0039 sec.
# ===> Epoch[4](5/25) : Loss: 0.0193 || Timer: 0.0014 sec.
# ===> Epoch[4](6/25) : Loss: 0.0227 || Timer: 0.0018 sec.
# ===> Epoch[4](7/25) : Loss: 0.0169 || Timer: 0.0014 sec.
# ===> Epoch[4](8/25) : Loss: 0.0174 || Timer: 0.0019 sec.
# ===> Epoch[4](9/25) : Loss: 0.0155 || Timer: 0.0020 sec.
# ===> Epoch[4](10/25) : Loss: 0.0160 || Timer: 0.0020 sec.
# ===> Epoch[4](11/25) : Loss: 0.0177 || Timer: 0.0022 sec.
# ===> Epoch[4](12/25) : Loss: 0.0201 || Timer: 0.0025 sec.
# ===> Epoch[4](13/25) : Loss: 0.0149 || Timer: 0.0042 sec.
# ===> Epoch[4](14/25) : Loss: 0.0170 || Timer: 0.0022 sec.
# ===> Epoch[4](15/25) : Loss: 0.0204 || Timer: 0.0072 sec.
# ===> Epoch[4](16/25) : Loss: 0.0189 || Timer: 0.0020 sec.
# ===> Epoch[4](17/25) : Loss: 0.0226 || Timer: 0.0020 sec.
# ===> Epoch[4](18/25) : Loss: 0.0208 || Timer: 0.0018 sec.
# ===> Epoch[4](19/25) : Loss: 0.0188 || Timer: 0.0018 sec.
# ===> Epoch[4](20/25) : Loss: 0.0138 || Timer: 0.0018 sec.
# ===> Epoch[4](21/25) : Loss: 0.0162 || Timer: 0.0014 sec.
# ===> Epoch[4](22/25) : Loss: 0.0184 || Timer: 0.0020 sec.
# ===> Epoch[4](23/25) : Loss: 0.0179 || Timer: 0.0029 sec.
# ===> Epoch[4](24/25) : Loss: 0.0123 || Timer: 0.0021 sec.
# ===> Epoch[4](25/25) : Loss: 0.0154 || Timer: 0.0014 sec.
# ===> Epoch 4 Complete : Avg. Loss: 0.0179
# ===> Epoch[5](1/25) : Loss: 0.0186 || Timer: 0.0030 sec.
# ===> Epoch[5](2/25) : Loss: 0.0181 || Timer: 0.0022 sec.
# ===> Epoch[5](3/25) : Loss: 0.0138 || Timer: 0.0019 sec.
# ===> Epoch[5](4/25) : Loss: 0.0234 || Timer: 0.0021 sec.
# ===> Epoch[5](5/25) : Loss: 0.0186 || Timer: 0.0019 sec.
# ===> Epoch[5](6/25) : Loss: 0.0146 || Timer: 0.0021 sec.
# ===> Epoch[5](7/25) : Loss: 0.0176 || Timer: 0.0018 sec.
# ===> Epoch[5](8/25) : Loss: 0.0180 || Timer: 0.0025 sec.
# ===> Epoch[5](9/25) : Loss: 0.0159 || Timer: 0.0015 sec.
# ===> Epoch[5](10/25) : Loss: 0.0184 || Timer: 0.0022 sec.
# ===> Epoch[5](11/25) : Loss: 0.0218 || Timer: 0.0016 sec.
# ===> Epoch[5](12/25) : Loss: 0.0193 || Timer: 0.0019 sec.
# ===> Epoch[5](13/25) : Loss: 0.0143 || Timer: 0.0023 sec.
# ===> Epoch[5](14/25) : Loss: 0.0182 || Timer: 0.0017 sec.
# ===> Epoch[5](15/25) : Loss: 0.0137 || Timer: 0.0024 sec.
# ===> Epoch[5](16/25) : Loss: 0.0170 || Timer: 0.0018 sec.
# ===> Epoch[5](17/25) : Loss: 0.0125 || Timer: 0.0028 sec.
# ===> Epoch[5](18/25) : Loss: 0.0185 || Timer: 0.0019 sec.
# ===> Epoch[5](19/25) : Loss: 0.0192 || Timer: 0.0019 sec.
# ===> Epoch[5](20/25) : Loss: 0.0173 || Timer: 0.0021 sec.
# ===> Epoch[5](21/25) : Loss: 0.0202 || Timer: 0.0019 sec.
# ===> Epoch[5](22/25) : Loss: 0.0257 || Timer: 0.0019 sec.
# ===> Epoch[5](23/25) : Loss: 0.0158 || Timer: 0.0065 sec.
# ===> Epoch[5](24/25) : Loss: 0.0186 || Timer: 0.0020 sec.
# ===> Epoch[5](25/25) : Loss: 0.0178 || Timer: 0.0013 sec.
# ===> Epoch 5 Complete : Avg. Loss: 0.0179
# ===> Epoch[6](1/25) : Loss: 0.0221 || Timer: 0.0029 sec.
# ===> Epoch[6](2/25) : Loss: 0.0178 || Timer: 0.0020 sec.
# ===> Epoch[6](3/25) : Loss: 0.0172 || Timer: 0.0017 sec.
# ===> Epoch[6](4/25) : Loss: 0.0182 || Timer: 0.0020 sec.
# ===> Epoch[6](5/25) : Loss: 0.0230 || Timer: 0.0019 sec.
# ===> Epoch[6](6/25) : Loss: 0.0166 || Timer: 0.0021 sec.
# ===> Epoch[6](7/25) : Loss: 0.0197 || Timer: 0.0025 sec.
# ===> Epoch[6](8/25) : Loss: 0.0145 || Timer: 0.0019 sec.
# ===> Epoch[6](9/25) : Loss: 0.0168 || Timer: 0.0017 sec.
# ===> Epoch[6](10/25) : Loss: 0.0195 || Timer: 0.0018 sec.
# ===> Epoch[6](11/25) : Loss: 0.0145 || Timer: 0.0015 sec.
# ===> Epoch[6](12/25) : Loss: 0.0183 || Timer: 0.0018 sec.
# ===> Epoch[6](13/25) : Loss: 0.0124 || Timer: 0.0019 sec.
# ===> Epoch[6](14/25) : Loss: 0.0175 || Timer: 0.0020 sec.
# ===> Epoch[6](15/25) : Loss: 0.0110 || Timer: 0.0020 sec.
# ===> Epoch[6](16/25) : Loss: 0.0204 || Timer: 0.0014 sec.
# ===> Epoch[6](17/25) : Loss: 0.0164 || Timer: 0.0020 sec.
# ===> Epoch[6](18/25) : Loss: 0.0192 || Timer: 0.0019 sec.
# ===> Epoch[6](19/25) : Loss: 0.0167 || Timer: 0.0020 sec.
# ===> Epoch[6](20/25) : Loss: 0.0198 || Timer: 0.0019 sec.
# ===> Epoch[6](21/25) : Loss: 0.0201 || Timer: 0.0020 sec.
# ===> Epoch[6](22/25) : Loss: 0.0150 || Timer: 0.0014 sec.
# ===> Epoch[6](23/25) : Loss: 0.0163 || Timer: 0.0020 sec.
# ===> Epoch[6](24/25) : Loss: 0.0189 || Timer: 0.0023 sec.
# ===> Epoch[6](25/25) : Loss: 0.0166 || Timer: 0.0014 sec.
# ===> Epoch 6 Complete : Avg. Loss: 0.0175
# ===> Epoch[7](1/25) : Loss: 0.0197 || Timer: 0.0030 sec.
# ===> Epoch[7](2/25) : Loss: 0.0133 || Timer: 0.0020 sec.
# ===> Epoch[7](3/25) : Loss: 0.0181 || Timer: 0.0022 sec.
# ===> Epoch[7](4/25) : Loss: 0.0154 || Timer: 0.0020 sec.
# ===> Epoch[7](5/25) : Loss: 0.0125 || Timer: 0.0021 sec.
# ===> Epoch[7](6/25) : Loss: 0.0155 || Timer: 0.0018 sec.
# ===> Epoch[7](7/25) : Loss: 0.0117 || Timer: 0.0019 sec.
# ===> Epoch[7](8/25) : Loss: 0.0159 || Timer: 0.0019 sec.
# ===> Epoch[7](9/25) : Loss: 0.0186 || Timer: 0.0025 sec.
# ===> Epoch[7](10/25) : Loss: 0.0154 || Timer: 0.0024 sec.
# ===> Epoch[7](11/25) : Loss: 0.0141 || Timer: 0.0020 sec.
# ===> Epoch[7](12/25) : Loss: 0.0165 || Timer: 0.0022 sec.
# ===> Epoch[7](13/25) : Loss: 0.0221 || Timer: 0.0019 sec.
# ===> Epoch[7](14/25) : Loss: 0.0182 || Timer: 0.0018 sec.
# ===> Epoch[7](15/25) : Loss: 0.0197 || Timer: 0.0020 sec.
# ===> Epoch[7](16/25) : Loss: 0.0135 || Timer: 0.0022 sec.
# ===> Epoch[7](17/25) : Loss: 0.0217 || Timer: 0.0019 sec.
# ===> Epoch[7](18/25) : Loss: 0.0190 || Timer: 0.0019 sec.
# ===> Epoch[7](19/25) : Loss: 0.0154 || Timer: 0.0022 sec.
# ===> Epoch[7](20/25) : Loss: 0.0116 || Timer: 0.0018 sec.
# ===> Epoch[7](21/25) : Loss: 0.0154 || Timer: 0.0020 sec.
# ===> Epoch[7](22/25) : Loss: 0.0161 || Timer: 0.0021 sec.
# ===> Epoch[7](23/25) : Loss: 0.0200 || Timer: 0.0014 sec.
# ===> Epoch[7](24/25) : Loss: 0.0161 || Timer: 0.0020 sec.
# ===> Epoch[7](25/25) : Loss: 0.0156 || Timer: 0.0014 sec.
# ===> Epoch 7 Complete : Avg. Loss: 0.0164
# ===> Epoch[8](1/25) : Loss: 0.0149 || Timer: 0.0034 sec.
# ===> Epoch[8](2/25) : Loss: 0.0206 || Timer: 0.0020 sec.
# ===> Epoch[8](3/25) : Loss: 0.0151 || Timer: 0.0019 sec.
# ===> Epoch[8](4/25) : Loss: 0.0226 || Timer: 0.0018 sec.
# ===> Epoch[8](5/25) : Loss: 0.0166 || Timer: 0.0020 sec.
# ===> Epoch[8](6/25) : Loss: 0.0145 || Timer: 0.0019 sec.
# ===> Epoch[8](7/25) : Loss: 0.0168 || Timer: 0.0020 sec.
# ===> Epoch[8](8/25) : Loss: 0.0201 || Timer: 0.0019 sec.
# ===> Epoch[8](9/25) : Loss: 0.0206 || Timer: 0.0021 sec.
# ===> Epoch[8](10/25) : Loss: 0.0162 || Timer: 0.0022 sec.
# ===> Epoch[8](11/25) : Loss: 0.0174 || Timer: 0.0020 sec.
# ===> Epoch[8](12/25) : Loss: 0.0161 || Timer: 0.0018 sec.
# ===> Epoch[8](13/25) : Loss: 0.0150 || Timer: 0.0018 sec.
# ===> Epoch[8](14/25) : Loss: 0.0181 || Timer: 0.0019 sec.
# ===> Epoch[8](15/25) : Loss: 0.0189 || Timer: 0.0021 sec.
# ===> Epoch[8](16/25) : Loss: 0.0175 || Timer: 0.0018 sec.
# ===> Epoch[8](17/25) : Loss: 0.0197 || Timer: 0.0020 sec.
# ===> Epoch[8](18/25) : Loss: 0.0145 || Timer: 0.0019 sec.
# ===> Epoch[8](19/25) : Loss: 0.0147 || Timer: 0.0021 sec.
# ===> Epoch[8](20/25) : Loss: 0.0160 || Timer: 0.0020 sec.
# ===> Epoch[8](21/25) : Loss: 0.0178 || Timer: 0.0020 sec.
# ===> Epoch[8](22/25) : Loss: 0.0223 || Timer: 0.0020 sec.
# ===> Epoch[8](23/25) : Loss: 0.0170 || Timer: 0.0020 sec.
# ===> Epoch[8](24/25) : Loss: 0.0141 || Timer: 0.0019 sec.
# ===> Epoch[8](25/25) : Loss: 0.0180 || Timer: 0.0014 sec.
# ===> Epoch 8 Complete : Avg. Loss: 0.0174
# ===> Epoch[9](1/25) : Loss: 0.0133 || Timer: 0.0031 sec.
# ===> Epoch[9](2/25) : Loss: 0.0189 || Timer: 0.0022 sec.
# ===> Epoch[9](3/25) : Loss: 0.0142 || Timer: 0.0083 sec.
# ===> Epoch[9](4/25) : Loss: 0.0180 || Timer: 0.0022 sec.
# ===> Epoch[9](5/25) : Loss: 0.0162 || Timer: 0.0019 sec.
# ===> Epoch[9](6/25) : Loss: 0.0173 || Timer: 0.0018 sec.
# ===> Epoch[9](7/25) : Loss: 0.0162 || Timer: 0.0018 sec.
# ===> Epoch[9](8/25) : Loss: 0.0169 || Timer: 0.0019 sec.
# ===> Epoch[9](9/25) : Loss: 0.0173 || Timer: 0.0018 sec.
# ===> Epoch[9](10/25) : Loss: 0.0166 || Timer: 0.0019 sec.
# ===> Epoch[9](11/25) : Loss: 0.0134 || Timer: 0.0021 sec.
# ===> Epoch[9](12/25) : Loss: 0.0187 || Timer: 0.0021 sec.
# ===> Epoch[9](13/25) : Loss: 0.0187 || Timer: 0.0020 sec.
# ===> Epoch[9](14/25) : Loss: 0.0189 || Timer: 0.0091 sec.
# ===> Epoch[9](15/25) : Loss: 0.0212 || Timer: 0.0020 sec.
# ===> Epoch[9](16/25) : Loss: 0.0211 || Timer: 0.0020 sec.
# ===> Epoch[9](17/25) : Loss: 0.0172 || Timer: 0.0019 sec.
# ===> Epoch[9](18/25) : Loss: 0.0147 || Timer: 0.0018 sec.
# ===> Epoch[9](19/25) : Loss: 0.0169 || Timer: 0.0021 sec.
# ===> Epoch[9](20/25) : Loss: 0.0159 || Timer: 0.0018 sec.
# ===> Epoch[9](21/25) : Loss: 0.0176 || Timer: 0.0020 sec.
# ===> Epoch[9](22/25) : Loss: 0.0167 || Timer: 0.0022 sec.
# ===> Epoch[9](23/25) : Loss: 0.0213 || Timer: 0.0024 sec.
# ===> Epoch[9](24/25) : Loss: 0.0130 || Timer: 0.0014 sec.
# ===> Epoch[9](25/25) : Loss: 0.0208 || Timer: 0.0014 sec.
# ===> Epoch 9 Complete : Avg. Loss: 0.0172
# ===> Epoch[10](1/25) : Loss: 0.0120 || Timer: 0.0031 sec.
# ===> Epoch[10](2/25) : Loss: 0.0139 || Timer: 0.0019 sec.
# ===> Epoch[10](3/25) : Loss: 0.0190 || Timer: 0.0018 sec.
# ===> Epoch[10](4/25) : Loss: 0.0140 || Timer: 0.0019 sec.
# ===> Epoch[10](5/25) : Loss: 0.0186 || Timer: 0.0019 sec.
# ===> Epoch[10](6/25) : Loss: 0.0154 || Timer: 0.0024 sec.
# ===> Epoch[10](7/25) : Loss: 0.0175 || Timer: 0.0019 sec.
# ===> Epoch[10](8/25) : Loss: 0.0179 || Timer: 0.0019 sec.
# ===> Epoch[10](9/25) : Loss: 0.0166 || Timer: 0.0020 sec.
# ===> Epoch[10](10/25) : Loss: 0.0157 || Timer: 0.0023 sec.
# ===> Epoch[10](11/25) : Loss: 0.0211 || Timer: 0.0020 sec.
# ===> Epoch[10](12/25) : Loss: 0.0190 || Timer: 0.0021 sec.
# ===> Epoch[10](13/25) : Loss: 0.0133 || Timer: 0.0019 sec.
# ===> Epoch[10](14/25) : Loss: 0.0162 || Timer: 0.0023 sec.
# ===> Epoch[10](15/25) : Loss: 0.0169 || Timer: 0.0020 sec.
# ===> Epoch[10](16/25) : Loss: 0.0169 || Timer: 0.0017 sec.
# ===> Epoch[10](17/25) : Loss: 0.0177 || Timer: 0.0019 sec.
# ===> Epoch[10](18/25) : Loss: 0.0122 || Timer: 0.0019 sec.
# ===> Epoch[10](19/25) : Loss: 0.0196 || Timer: 0.0018 sec.
# ===> Epoch[10](20/25) : Loss: 0.0146 || Timer: 0.0019 sec.
# ===> Epoch[10](21/25) : Loss: 0.0215 || Timer: 0.0050 sec.
# ===> Epoch[10](22/25) : Loss: 0.0139 || Timer: 0.0018 sec.
# ===> Epoch[10](23/25) : Loss: 0.0209 || Timer: 0.0021 sec.
# ===> Epoch[10](24/25) : Loss: 0.0148 || Timer: 0.0018 sec.
# ===> Epoch[10](25/25) : Loss: 0.0176 || Timer: 0.0015 sec.
# ===> Epoch 10 Complete : Avg. Loss: 0.0167
# ===> Epoch[11](1/25) : Loss: 0.0138 || Timer: 0.0030 sec.
# ===> Epoch[11](2/25) : Loss: 0.0118 || Timer: 0.0020 sec.
# ===> Epoch[11](3/25) : Loss: 0.0139 || Timer: 0.0020 sec.
# ===> Epoch[11](4/25) : Loss: 0.0143 || Timer: 0.0019 sec.
# ===> Epoch[11](5/25) : Loss: 0.0243 || Timer: 0.0019 sec.
# ===> Epoch[11](6/25) : Loss: 0.0170 || Timer: 0.0019 sec.
# ===> Epoch[11](7/25) : Loss: 0.0160 || Timer: 0.0020 sec.
# ===> Epoch[11](8/25) : Loss: 0.0193 || Timer: 0.0023 sec.
# ===> Epoch[11](9/25) : Loss: 0.0179 || Timer: 0.0020 sec.
# ===> Epoch[11](10/25) : Loss: 0.0159 || Timer: 0.0021 sec.
# ===> Epoch[11](11/25) : Loss: 0.0179 || Timer: 0.0020 sec.
# ===> Epoch[11](12/25) : Loss: 0.0150 || Timer: 0.0018 sec.
# ===> Epoch[11](13/25) : Loss: 0.0166 || Timer: 0.0020 sec.
# ===> Epoch[11](14/25) : Loss: 0.0174 || Timer: 0.0018 sec.
# ===> Epoch[11](15/25) : Loss: 0.0180 || Timer: 0.0020 sec.
# ===> Epoch[11](16/25) : Loss: 0.0134 || Timer: 0.0019 sec.
# ===> Epoch[11](17/25) : Loss: 0.0160 || Timer: 0.0021 sec.
# ===> Epoch[11](18/25) : Loss: 0.0150 || Timer: 0.0022 sec.
# ===> Epoch[11](19/25) : Loss: 0.0218 || Timer: 0.0020 sec.
# ===> Epoch[11](20/25) : Loss: 0.0164 || Timer: 0.0030 sec.
# ===> Epoch[11](21/25) : Loss: 0.0132 || Timer: 0.0019 sec.
# ===> Epoch[11](22/25) : Loss: 0.0196 || Timer: 0.0020 sec.
# ===> Epoch[11](23/25) : Loss: 0.0134 || Timer: 0.0021 sec.
# ===> Epoch[11](24/25) : Loss: 0.0113 || Timer: 0.0029 sec.
# ===> Epoch[11](25/25) : Loss: 0.0215 || Timer: 0.0015 sec.
# ===> Epoch 11 Complete : Avg. Loss: 0.0164
# ===> Epoch[12](1/25) : Loss: 0.0165 || Timer: 0.0031 sec.
# ===> Epoch[12](2/25) : Loss: 0.0189 || Timer: 0.0020 sec.
# ===> Epoch[12](3/25) : Loss: 0.0131 || Timer: 0.0750 sec.
# ===> Epoch[12](4/25) : Loss: 0.0185 || Timer: 0.0018 sec.
# ===> Epoch[12](5/25) : Loss: 0.0199 || Timer: 0.0020 sec.
# ===> Epoch[12](6/25) : Loss: 0.0167 || Timer: 0.0020 sec.
# ===> Epoch[12](7/25) : Loss: 0.0165 || Timer: 0.0018 sec.
# ===> Epoch[12](8/25) : Loss: 0.0194 || Timer: 0.0019 sec.
# ===> Epoch[12](9/25) : Loss: 0.0151 || Timer: 0.0019 sec.
# ===> Epoch[12](10/25) : Loss: 0.0188 || Timer: 0.0022 sec.
# ===> Epoch[12](11/25) : Loss: 0.0237 || Timer: 0.0021 sec.
# ===> Epoch[12](12/25) : Loss: 0.0183 || Timer: 0.0017 sec.
# ===> Epoch[12](13/25) : Loss: 0.0167 || Timer: 0.0022 sec.
# ===> Epoch[12](14/25) : Loss: 0.0140 || Timer: 0.0018 sec.
# ===> Epoch[12](15/25) : Loss: 0.0183 || Timer: 0.0019 sec.
# ===> Epoch[12](16/25) : Loss: 0.0199 || Timer: 0.0019 sec.
# ===> Epoch[12](17/25) : Loss: 0.0174 || Timer: 0.0019 sec.
# ===> Epoch[12](18/25) : Loss: 0.0200 || Timer: 0.0027 sec.
# ===> Epoch[12](19/25) : Loss: 0.0199 || Timer: 0.0020 sec.
# ===> Epoch[12](20/25) : Loss: 0.0153 || Timer: 0.0019 sec.
# ===> Epoch[12](21/25) : Loss: 0.0190 || Timer: 0.0023 sec.
# ===> Epoch[12](22/25) : Loss: 0.0128 || Timer: 0.0023 sec.
# ===> Epoch[12](23/25) : Loss: 0.0146 || Timer: 0.0023 sec.
# ===> Epoch[12](24/25) : Loss: 0.0142 || Timer: 0.0020 sec.
# ===> Epoch[12](25/25) : Loss: 0.0139 || Timer: 0.0013 sec.
# ===> Epoch 12 Complete : Avg. Loss: 0.0173
# ===> Epoch[13](1/25) : Loss: 0.0166 || Timer: 0.0030 sec.
# ===> Epoch[13](2/25) : Loss: 0.0225 || Timer: 0.0022 sec.
# ===> Epoch[13](3/25) : Loss: 0.0159 || Timer: 0.0018 sec.
# ===> Epoch[13](4/25) : Loss: 0.0138 || Timer: 0.0018 sec.
# ===> Epoch[13](5/25) : Loss: 0.0208 || Timer: 0.0018 sec.
# ===> Epoch[13](6/25) : Loss: 0.0199 || Timer: 0.0021 sec.
# ===> Epoch[13](7/25) : Loss: 0.0163 || Timer: 0.0020 sec.
# ===> Epoch[13](8/25) : Loss: 0.0137 || Timer: 0.0019 sec.
# ===> Epoch[13](9/25) : Loss: 0.0144 || Timer: 0.0018 sec.
# ===> Epoch[13](10/25) : Loss: 0.0173 || Timer: 0.0022 sec.
# ===> Epoch[13](11/25) : Loss: 0.0201 || Timer: 0.0019 sec.
# ===> Epoch[13](12/25) : Loss: 0.0126 || Timer: 0.0019 sec.
# ===> Epoch[13](13/25) : Loss: 0.0138 || Timer: 0.0027 sec.
# ===> Epoch[13](14/25) : Loss: 0.0214 || Timer: 0.0019 sec.
# ===> Epoch[13](15/25) : Loss: 0.0143 || Timer: 0.0022 sec.
# ===> Epoch[13](16/25) : Loss: 0.0193 || Timer: 0.0022 sec.
# ===> Epoch[13](17/25) : Loss: 0.0138 || Timer: 0.0028 sec.
# ===> Epoch[13](18/25) : Loss: 0.0174 || Timer: 0.0019 sec.
# ===> Epoch[13](19/25) : Loss: 0.0153 || Timer: 0.0027 sec.
# ===> Epoch[13](20/25) : Loss: 0.0155 || Timer: 0.0019 sec.
# ===> Epoch[13](21/25) : Loss: 0.0172 || Timer: 0.0015 sec.
# ===> Epoch[13](22/25) : Loss: 0.0159 || Timer: 0.0029 sec.
# ===> Epoch[13](23/25) : Loss: 0.0185 || Timer: 0.0018 sec.
# ===> Epoch[13](24/25) : Loss: 0.0178 || Timer: 0.0019 sec.
# ===> Epoch[13](25/25) : Loss: 0.0127 || Timer: 0.0014 sec.
# ===> Epoch 13 Complete : Avg. Loss: 0.0167
# ===> Epoch[14](1/25) : Loss: 0.0179 || Timer: 0.0047 sec.
# ===> Epoch[14](2/25) : Loss: 0.0172 || Timer: 0.0019 sec.
# ===> Epoch[14](3/25) : Loss: 0.0165 || Timer: 0.0018 sec.
# ===> Epoch[14](4/25) : Loss: 0.0179 || Timer: 0.0018 sec.
# ===> Epoch[14](5/25) : Loss: 0.0159 || Timer: 0.0020 sec.
# ===> Epoch[14](6/25) : Loss: 0.0132 || Timer: 0.0019 sec.
# ===> Epoch[14](7/25) : Loss: 0.0150 || Timer: 0.0018 sec.
# ===> Epoch[14](8/25) : Loss: 0.0167 || Timer: 0.0018 sec.
# ===> Epoch[14](9/25) : Loss: 0.0188 || Timer: 0.0020 sec.
# ===> Epoch[14](10/25) : Loss: 0.0159 || Timer: 0.0019 sec.
# ===> Epoch[14](11/25) : Loss: 0.0180 || Timer: 0.0019 sec.
# ===> Epoch[14](12/25) : Loss: 0.0164 || Timer: 0.0025 sec.
# ===> Epoch[14](13/25) : Loss: 0.0166 || Timer: 0.0018 sec.
# ===> Epoch[14](14/25) : Loss: 0.0190 || Timer: 0.0018 sec.
# ===> Epoch[14](15/25) : Loss: 0.0145 || Timer: 0.0018 sec.
# ===> Epoch[14](16/25) : Loss: 0.0177 || Timer: 0.0019 sec.
# ===> Epoch[14](17/25) : Loss: 0.0154 || Timer: 0.0018 sec.
# ===> Epoch[14](18/25) : Loss: 0.0156 || Timer: 0.0019 sec.
# ===> Epoch[14](19/25) : Loss: 0.0169 || Timer: 0.0023 sec.
# ===> Epoch[14](20/25) : Loss: 0.0164 || Timer: 0.0020 sec.
# ===> Epoch[14](21/25) : Loss: 0.0144 || Timer: 0.0020 sec.
# ===> Epoch[14](22/25) : Loss: 0.0158 || Timer: 0.0019 sec.
# ===> Epoch[14](23/25) : Loss: 0.0126 || Timer: 0.0018 sec.
# ===> Epoch[14](24/25) : Loss: 0.0215 || Timer: 0.0019 sec.
# ===> Epoch[14](25/25) : Loss: 0.0148 || Timer: 0.0014 sec.
# ===> Epoch 14 Complete : Avg. Loss: 0.0164
# ===> Epoch[15](1/25) : Loss: 0.0206 || Timer: 0.0032 sec.
# ===> Epoch[15](2/25) : Loss: 0.0176 || Timer: 0.0020 sec.
# ===> Epoch[15](3/25) : Loss: 0.0184 || Timer: 0.0020 sec.
# ===> Epoch[15](4/25) : Loss: 0.0199 || Timer: 0.0018 sec.
# ===> Epoch[15](5/25) : Loss: 0.0181 || Timer: 0.0019 sec.
# ===> Epoch[15](6/25) : Loss: 0.0159 || Timer: 0.0020 sec.
# ===> Epoch[15](7/25) : Loss: 0.0162 || Timer: 0.0021 sec.
# ===> Epoch[15](8/25) : Loss: 0.0179 || Timer: 0.0022 sec.
# ===> Epoch[15](9/25) : Loss: 0.0223 || Timer: 0.0021 sec.
# ===> Epoch[15](10/25) : Loss: 0.0153 || Timer: 0.0018 sec.
# ===> Epoch[15](11/25) : Loss: 0.0209 || Timer: 0.0024 sec.
# ===> Epoch[15](12/25) : Loss: 0.0155 || Timer: 0.0032 sec.
# ===> Epoch[15](13/25) : Loss: 0.0169 || Timer: 0.0022 sec.
# ===> Epoch[15](14/25) : Loss: 0.0162 || Timer: 0.0020 sec.
# ===> Epoch[15](15/25) : Loss: 0.0137 || Timer: 0.0020 sec.
# ===> Epoch[15](16/25) : Loss: 0.0223 || Timer: 0.0020 sec.
# ===> Epoch[15](17/25) : Loss: 0.0177 || Timer: 0.0019 sec.
# ===> Epoch[15](18/25) : Loss: 0.0121 || Timer: 0.0021 sec.
# ===> Epoch[15](19/25) : Loss: 0.0163 || Timer: 0.0021 sec.
# ===> Epoch[15](20/25) : Loss: 0.0145 || Timer: 0.0021 sec.
# ===> Epoch[15](21/25) : Loss: 0.0155 || Timer: 0.0021 sec.
# ===> Epoch[15](22/25) : Loss: 0.0138 || Timer: 0.0023 sec.
# ===> Epoch[15](23/25) : Loss: 0.0152 || Timer: 0.0021 sec.
# ===> Epoch[15](24/25) : Loss: 0.0163 || Timer: 0.0020 sec.
# ===> Epoch[15](25/25) : Loss: 0.0184 || Timer: 0.0014 sec.
# ===> Epoch 15 Complete : Avg. Loss: 0.0171
# ===> Epoch[16](1/25) : Loss: 0.0180 || Timer: 0.0035 sec.
# ===> Epoch[16](2/25) : Loss: 0.0161 || Timer: 0.0022 sec.
# ===> Epoch[16](3/25) : Loss: 0.0165 || Timer: 0.0019 sec.
# ===> Epoch[16](4/25) : Loss: 0.0201 || Timer: 0.0025 sec.
# ===> Epoch[16](5/25) : Loss: 0.0169 || Timer: 0.0020 sec.
# ===> Epoch[16](6/25) : Loss: 0.0172 || Timer: 0.0018 sec.
# ===> Epoch[16](7/25) : Loss: 0.0150 || Timer: 0.0020 sec.
# ===> Epoch[16](8/25) : Loss: 0.0242 || Timer: 0.0020 sec.
# ===> Epoch[16](9/25) : Loss: 0.0135 || Timer: 0.0019 sec.
# ===> Epoch[16](10/25) : Loss: 0.0180 || Timer: 0.0020 sec.
# ===> Epoch[16](11/25) : Loss: 0.0169 || Timer: 0.0020 sec.
# ===> Epoch[16](12/25) : Loss: 0.0116 || Timer: 0.0018 sec.
# ===> Epoch[16](13/25) : Loss: 0.0182 || Timer: 0.0021 sec.
# ===> Epoch[16](14/25) : Loss: 0.0172 || Timer: 0.0027 sec.
# ===> Epoch[16](15/25) : Loss: 0.0168 || Timer: 0.0015 sec.
# ===> Epoch[16](16/25) : Loss: 0.0160 || Timer: 0.0018 sec.
# ===> Epoch[16](17/25) : Loss: 0.0177 || Timer: 0.0018 sec.
# ===> Epoch[16](18/25) : Loss: 0.0110 || Timer: 0.0020 sec.
# ===> Epoch[16](19/25) : Loss: 0.0138 || Timer: 0.0015 sec.
# ===> Epoch[16](20/25) : Loss: 0.0169 || Timer: 0.0020 sec.
# ===> Epoch[16](21/25) : Loss: 0.0158 || Timer: 0.0020 sec.
# ===> Epoch[16](22/25) : Loss: 0.0177 || Timer: 0.0019 sec.
# ===> Epoch[16](23/25) : Loss: 0.0146 || Timer: 0.0020 sec.
# ===> Epoch[16](24/25) : Loss: 0.0186 || Timer: 0.0020 sec.
# ===> Epoch[16](25/25) : Loss: 0.0149 || Timer: 0.0016 sec.
# ===> Epoch 16 Complete : Avg. Loss: 0.0165
# ===> Epoch[17](1/25) : Loss: 0.0170 || Timer: 0.0029 sec.
# ===> Epoch[17](2/25) : Loss: 0.0163 || Timer: 0.0020 sec.
# ===> Epoch[17](3/25) : Loss: 0.0249 || Timer: 0.0020 sec.
# ===> Epoch[17](4/25) : Loss: 0.0185 || Timer: 0.0019 sec.
# ===> Epoch[17](5/25) : Loss: 0.0153 || Timer: 0.0019 sec.
# ===> Epoch[17](6/25) : Loss: 0.0156 || Timer: 0.0020 sec.
# ===> Epoch[17](7/25) : Loss: 0.0172 || Timer: 0.0020 sec.
# ===> Epoch[17](8/25) : Loss: 0.0190 || Timer: 0.0022 sec.
# ===> Epoch[17](9/25) : Loss: 0.0130 || Timer: 0.0027 sec.
# ===> Epoch[17](10/25) : Loss: 0.0197 || Timer: 0.0020 sec.
# ===> Epoch[17](11/25) : Loss: 0.0130 || Timer: 0.0021 sec.
# ===> Epoch[17](12/25) : Loss: 0.0154 || Timer: 0.0016 sec.
# ===> Epoch[17](13/25) : Loss: 0.0171 || Timer: 0.0014 sec.
# ===> Epoch[17](14/25) : Loss: 0.0185 || Timer: 0.0018 sec.
# ===> Epoch[17](15/25) : Loss: 0.0147 || Timer: 0.0022 sec.
# ===> Epoch[17](16/25) : Loss: 0.0162 || Timer: 0.0019 sec.
# ===> Epoch[17](17/25) : Loss: 0.0146 || Timer: 0.0020 sec.
# ===> Epoch[17](18/25) : Loss: 0.0143 || Timer: 0.0024 sec.
# ===> Epoch[17](19/25) : Loss: 0.0133 || Timer: 0.0021 sec.
# ===> Epoch[17](20/25) : Loss: 0.0164 || Timer: 0.0021 sec.
# ===> Epoch[17](21/25) : Loss: 0.0158 || Timer: 0.0019 sec.
# ===> Epoch[17](22/25) : Loss: 0.0166 || Timer: 0.0019 sec.
# ===> Epoch[17](23/25) : Loss: 0.0170 || Timer: 0.0028 sec.
# ===> Epoch[17](24/25) : Loss: 0.0186 || Timer: 0.0081 sec.
# ===> Epoch[17](25/25) : Loss: 0.0168 || Timer: 0.0020 sec.
# ===> Epoch 17 Complete : Avg. Loss: 0.0166
# ===> Epoch[18](1/25) : Loss: 0.0224 || Timer: 0.0035 sec.
# ===> Epoch[18](2/25) : Loss: 0.0153 || Timer: 0.0021 sec.
# ===> Epoch[18](3/25) : Loss: 0.0165 || Timer: 0.0019 sec.
# ===> Epoch[18](4/25) : Loss: 0.0173 || Timer: 0.0019 sec.
# ===> Epoch[18](5/25) : Loss: 0.0213 || Timer: 0.0020 sec.
# ===> Epoch[18](6/25) : Loss: 0.0130 || Timer: 0.0021 sec.
# ===> Epoch[18](7/25) : Loss: 0.0145 || Timer: 0.0021 sec.
# ===> Epoch[18](8/25) : Loss: 0.0180 || Timer: 0.0018 sec.
# ===> Epoch[18](9/25) : Loss: 0.0179 || Timer: 0.0019 sec.
# ===> Epoch[18](10/25) : Loss: 0.0120 || Timer: 0.0019 sec.
# ===> Epoch[18](11/25) : Loss: 0.0154 || Timer: 0.0018 sec.
# ===> Epoch[18](12/25) : Loss: 0.0153 || Timer: 0.0020 sec.
# ===> Epoch[18](13/25) : Loss: 0.0124 || Timer: 0.0020 sec.
# ===> Epoch[18](14/25) : Loss: 0.0115 || Timer: 0.0015 sec.
# ===> Epoch[18](15/25) : Loss: 0.0168 || Timer: 0.0022 sec.
# ===> Epoch[18](16/25) : Loss: 0.0167 || Timer: 0.0018 sec.
# ===> Epoch[18](17/25) : Loss: 0.0197 || Timer: 0.0023 sec.
# ===> Epoch[18](18/25) : Loss: 0.0200 || Timer: 0.0018 sec.
# ===> Epoch[18](19/25) : Loss: 0.0169 || Timer: 0.0020 sec.
# ===> Epoch[18](20/25) : Loss: 0.0133 || Timer: 0.0020 sec.
# ===> Epoch[18](21/25) : Loss: 0.0128 || Timer: 0.0020 sec.
# ===> Epoch[18](22/25) : Loss: 0.0177 || Timer: 0.0022 sec.
# ===> Epoch[18](23/25) : Loss: 0.0215 || Timer: 0.0020 sec.
# ===> Epoch[18](24/25) : Loss: 0.0174 || Timer: 0.0019 sec.
# ===> Epoch[18](25/25) : Loss: 0.0191 || Timer: 0.0014 sec.
# ===> Epoch 18 Complete : Avg. Loss: 0.0166
# ===> Epoch[19](1/25) : Loss: 0.0233 || Timer: 0.0032 sec.
# ===> Epoch[19](2/25) : Loss: 0.0178 || Timer: 0.0015 sec.
# ===> Epoch[19](3/25) : Loss: 0.0228 || Timer: 0.0019 sec.
# ===> Epoch[19](4/25) : Loss: 0.0130 || Timer: 0.0018 sec.
# ===> Epoch[19](5/25) : Loss: 0.0127 || Timer: 0.0018 sec.
# ===> Epoch[19](6/25) : Loss: 0.0146 || Timer: 0.0018 sec.
# ===> Epoch[19](7/25) : Loss: 0.0134 || Timer: 0.0018 sec.
# ===> Epoch[19](8/25) : Loss: 0.0141 || Timer: 0.0019 sec.
# ===> Epoch[19](9/25) : Loss: 0.0194 || Timer: 0.0021 sec.
# ===> Epoch[19](10/25) : Loss: 0.0163 || Timer: 0.0018 sec.
# ===> Epoch[19](11/25) : Loss: 0.0205 || Timer: 0.0018 sec.
# ===> Epoch[19](12/25) : Loss: 0.0164 || Timer: 0.0021 sec.
# ===> Epoch[19](13/25) : Loss: 0.0149 || Timer: 0.0017 sec.
# ===> Epoch[19](14/25) : Loss: 0.0177 || Timer: 0.0018 sec.
# ===> Epoch[19](15/25) : Loss: 0.0172 || Timer: 0.0018 sec.
# ===> Epoch[19](16/25) : Loss: 0.0162 || Timer: 0.0014 sec.
# ===> Epoch[19](17/25) : Loss: 0.0170 || Timer: 0.0018 sec.
# ===> Epoch[19](18/25) : Loss: 0.0193 || Timer: 0.0020 sec.
# ===> Epoch[19](19/25) : Loss: 0.0113 || Timer: 0.0020 sec.
# ===> Epoch[19](20/25) : Loss: 0.0163 || Timer: 0.0018 sec.
# ===> Epoch[19](21/25) : Loss: 0.0220 || Timer: 0.0020 sec.
# ===> Epoch[19](22/25) : Loss: 0.0104 || Timer: 0.0022 sec.
# ===> Epoch[19](23/25) : Loss: 0.0124 || Timer: 0.0020 sec.
# ===> Epoch[19](24/25) : Loss: 0.0119 || Timer: 0.0024 sec.
# ===> Epoch[19](25/25) : Loss: 0.0188 || Timer: 0.0015 sec.
# ===> Epoch 19 Complete : Avg. Loss: 0.0164
# Checkpoint saved to /content/gdrive/My Drive/study/SRCNN/weights/<built-in function gethostname>_epoch_19.pth
# ===> Epoch[20](1/25) : Loss: 0.0160 || Timer: 0.0031 sec.
# ===> Epoch[20](2/25) : Loss: 0.0107 || Timer: 0.0020 sec.
# ===> Epoch[20](3/25) : Loss: 0.0123 || Timer: 0.0023 sec.
# ===> Epoch[20](4/25) : Loss: 0.0116 || Timer: 0.0020 sec.
# ===> Epoch[20](5/25) : Loss: 0.0134 || Timer: 0.0020 sec.
# ===> Epoch[20](6/25) : Loss: 0.0126 || Timer: 0.0019 sec.
# ===> Epoch[20](7/25) : Loss: 0.0165 || Timer: 0.0018 sec.
# ===> Epoch[20](8/25) : Loss: 0.0146 || Timer: 0.0020 sec.
# ===> Epoch[20](9/25) : Loss: 0.0195 || Timer: 0.0020 sec.
# ===> Epoch[20](10/25) : Loss: 0.0215 || Timer: 0.0019 sec.
# ===> Epoch[20](11/25) : Loss: 0.0195 || Timer: 0.0027 sec.
# ===> Epoch[20](12/25) : Loss: 0.0122 || Timer: 0.0019 sec.
# ===> Epoch[20](13/25) : Loss: 0.0156 || Timer: 0.0055 sec.
# ===> Epoch[20](14/25) : Loss: 0.0195 || Timer: 0.0020 sec.
# ===> Epoch[20](15/25) : Loss: 0.0167 || Timer: 0.0024 sec.
# ===> Epoch[20](16/25) : Loss: 0.0144 || Timer: 0.0021 sec.
# ===> Epoch[20](17/25) : Loss: 0.0131 || Timer: 0.0020 sec.
# ===> Epoch[20](18/25) : Loss: 0.0143 || Timer: 0.0020 sec.
# ===> Epoch[20](19/25) : Loss: 0.0149 || Timer: 0.0023 sec.
# ===> Epoch[20](20/25) : Loss: 0.0176 || Timer: 0.0020 sec.
# ===> Epoch[20](21/25) : Loss: 0.0169 || Timer: 0.0025 sec.
# ===> Epoch[20](22/25) : Loss: 0.0216 || Timer: 0.0020 sec.
# ===> Epoch[20](23/25) : Loss: 0.0192 || Timer: 0.0018 sec.
# ===> Epoch[20](24/25) : Loss: 0.0162 || Timer: 0.0022 sec.
# ===> Epoch[20](25/25) : Loss: 0.0188 || Timer: 0.0015 sec.
# ===> Epoch 20 Complete : Avg. Loss: 0.0160
# ===> Epoch[21](1/25) : Loss: 0.0180 || Timer: 0.0034 sec.
# ===> Epoch[21](2/25) : Loss: 0.0148 || Timer: 0.0023 sec.
# ===> Epoch[21](3/25) : Loss: 0.0172 || Timer: 0.0034 sec.
# ===> Epoch[21](4/25) : Loss: 0.0151 || Timer: 0.0022 sec.
# ===> Epoch[21](5/25) : Loss: 0.0164 || Timer: 0.0022 sec.
# ===> Epoch[21](6/25) : Loss: 0.0150 || Timer: 0.0018 sec.
# ===> Epoch[21](7/25) : Loss: 0.0232 || Timer: 0.0014 sec.
# ===> Epoch[21](8/25) : Loss: 0.0144 || Timer: 0.0019 sec.
# ===> Epoch[21](9/25) : Loss: 0.0152 || Timer: 0.0018 sec.
# ===> Epoch[21](10/25) : Loss: 0.0168 || Timer: 0.0026 sec.
# ===> Epoch[21](11/25) : Loss: 0.0165 || Timer: 0.0020 sec.
# ===> Epoch[21](12/25) : Loss: 0.0214 || Timer: 0.0019 sec.
# ===> Epoch[21](13/25) : Loss: 0.0190 || Timer: 0.0019 sec.
# ===> Epoch[21](14/25) : Loss: 0.0100 || Timer: 0.0019 sec.
# ===> Epoch[21](15/25) : Loss: 0.0166 || Timer: 0.0019 sec.
# ===> Epoch[21](16/25) : Loss: 0.0190 || Timer: 0.0018 sec.
# ===> Epoch[21](17/25) : Loss: 0.0167 || Timer: 0.0020 sec.
# ===> Epoch[21](18/25) : Loss: 0.0189 || Timer: 0.0021 sec.
# ===> Epoch[21](19/25) : Loss: 0.0200 || Timer: 0.0019 sec.
# ===> Epoch[21](20/25) : Loss: 0.0166 || Timer: 0.0021 sec.
# ===> Epoch[21](21/25) : Loss: 0.0177 || Timer: 0.0021 sec.
# ===> Epoch[21](22/25) : Loss: 0.0124 || Timer: 0.0020 sec.
# ===> Epoch[21](23/25) : Loss: 0.0189 || Timer: 0.0021 sec.
# ===> Epoch[21](24/25) : Loss: 0.0155 || Timer: 0.0020 sec.
# ===> Epoch[21](25/25) : Loss: 0.0195 || Timer: 0.0016 sec.
# ===> Epoch 21 Complete : Avg. Loss: 0.0170
# ===> Epoch[22](1/25) : Loss: 0.0149 || Timer: 0.0030 sec.
# ===> Epoch[22](2/25) : Loss: 0.0143 || Timer: 0.0020 sec.
# ===> Epoch[22](3/25) : Loss: 0.0172 || Timer: 0.0021 sec.
# ===> Epoch[22](4/25) : Loss: 0.0156 || Timer: 0.0022 sec.
# ===> Epoch[22](5/25) : Loss: 0.0160 || Timer: 0.0021 sec.
# ===> Epoch[22](6/25) : Loss: 0.0152 || Timer: 0.0019 sec.
# ===> Epoch[22](7/25) : Loss: 0.0099 || Timer: 0.0020 sec.
# ===> Epoch[22](8/25) : Loss: 0.0106 || Timer: 0.0020 sec.
# ===> Epoch[22](9/25) : Loss: 0.0126 || Timer: 0.0018 sec.
# ===> Epoch[22](10/25) : Loss: 0.0150 || Timer: 0.0020 sec.
# ===> Epoch[22](11/25) : Loss: 0.0169 || Timer: 0.0020 sec.
# ===> Epoch[22](12/25) : Loss: 0.0171 || Timer: 0.0021 sec.
# ===> Epoch[22](13/25) : Loss: 0.0129 || Timer: 0.0019 sec.
# ===> Epoch[22](14/25) : Loss: 0.0174 || Timer: 0.0020 sec.
# ===> Epoch[22](15/25) : Loss: 0.0173 || Timer: 0.0022 sec.
# ===> Epoch[22](16/25) : Loss: 0.0155 || Timer: 0.0020 sec.
# ===> Epoch[22](17/25) : Loss: 0.0185 || Timer: 0.0014 sec.
# ===> Epoch[22](18/25) : Loss: 0.0158 || Timer: 0.0019 sec.
# ===> Epoch[22](19/25) : Loss: 0.0152 || Timer: 0.0019 sec.
# ===> Epoch[22](20/25) : Loss: 0.0139 || Timer: 0.0020 sec.
# ===> Epoch[22](21/25) : Loss: 0.0162 || Timer: 0.0019 sec.
# ===> Epoch[22](22/25) : Loss: 0.0208 || Timer: 0.0019 sec.
# ===> Epoch[22](23/25) : Loss: 0.0164 || Timer: 0.0020 sec.
# ===> Epoch[22](24/25) : Loss: 0.0174 || Timer: 0.0019 sec.
# ===> Epoch[22](25/25) : Loss: 0.0150 || Timer: 0.0015 sec.
# ===> Epoch 22 Complete : Avg. Loss: 0.0155
# ===> Epoch[23](1/25) : Loss: 0.0134 || Timer: 0.0030 sec.
# ===> Epoch[23](2/25) : Loss: 0.0171 || Timer: 0.0019 sec.
# ===> Epoch[23](3/25) : Loss: 0.0206 || Timer: 0.0021 sec.
# ===> Epoch[23](4/25) : Loss: 0.0185 || Timer: 0.0020 sec.
# ===> Epoch[23](5/25) : Loss: 0.0164 || Timer: 0.0018 sec.
# ===> Epoch[23](6/25) : Loss: 0.0170 || Timer: 0.0017 sec.
# ===> Epoch[23](7/25) : Loss: 0.0149 || Timer: 0.0020 sec.
# ===> Epoch[23](8/25) : Loss: 0.0148 || Timer: 0.0019 sec.
# ===> Epoch[23](9/25) : Loss: 0.0176 || Timer: 0.0020 sec.
# ===> Epoch[23](10/25) : Loss: 0.0160 || Timer: 0.0018 sec.
# ===> Epoch[23](11/25) : Loss: 0.0191 || Timer: 0.0021 sec.
# ===> Epoch[23](12/25) : Loss: 0.0178 || Timer: 0.0019 sec.
# ===> Epoch[23](13/25) : Loss: 0.0149 || Timer: 0.0018 sec.
# ===> Epoch[23](14/25) : Loss: 0.0146 || Timer: 0.0018 sec.
# ===> Epoch[23](15/25) : Loss: 0.0147 || Timer: 0.0019 sec.
# ===> Epoch[23](16/25) : Loss: 0.0160 || Timer: 0.0018 sec.
# ===> Epoch[23](17/25) : Loss: 0.0110 || Timer: 0.0014 sec.
# ===> Epoch[23](18/25) : Loss: 0.0146 || Timer: 0.0028 sec.
# ===> Epoch[23](19/25) : Loss: 0.0156 || Timer: 0.0019 sec.
# ===> Epoch[23](20/25) : Loss: 0.0129 || Timer: 0.0018 sec.
# ===> Epoch[23](21/25) : Loss: 0.0171 || Timer: 0.0021 sec.
# ===> Epoch[23](22/25) : Loss: 0.0170 || Timer: 0.0020 sec.
# ===> Epoch[23](23/25) : Loss: 0.0145 || Timer: 0.0021 sec.
# ===> Epoch[23](24/25) : Loss: 0.0182 || Timer: 0.0019 sec.
# ===> Epoch[23](25/25) : Loss: 0.0201 || Timer: 0.0014 sec.
# ===> Epoch 23 Complete : Avg. Loss: 0.0162
# ===> Epoch[24](1/25) : Loss: 0.0176 || Timer: 0.0034 sec.
# ===> Epoch[24](2/25) : Loss: 0.0136 || Timer: 0.0024 sec.
# ===> Epoch[24](3/25) : Loss: 0.0159 || Timer: 0.0018 sec.
# ===> Epoch[24](4/25) : Loss: 0.0169 || Timer: 0.0020 sec.
# ===> Epoch[24](5/25) : Loss: 0.0120 || Timer: 0.0875 sec.
# ===> Epoch[24](6/25) : Loss: 0.0174 || Timer: 0.0022 sec.
# ===> Epoch[24](7/25) : Loss: 0.0171 || Timer: 0.0019 sec.
# ===> Epoch[24](8/25) : Loss: 0.0180 || Timer: 0.0029 sec.
# ===> Epoch[24](9/25) : Loss: 0.0171 || Timer: 0.0019 sec.
# ===> Epoch[24](10/25) : Loss: 0.0200 || Timer: 0.0019 sec.
# ===> Epoch[24](11/25) : Loss: 0.0174 || Timer: 0.0020 sec.
# ===> Epoch[24](12/25) : Loss: 0.0120 || Timer: 0.0019 sec.
# ===> Epoch[24](13/25) : Loss: 0.0184 || Timer: 0.0066 sec.
# ===> Epoch[24](14/25) : Loss: 0.0174 || Timer: 0.0019 sec.
# ===> Epoch[24](15/25) : Loss: 0.0168 || Timer: 0.0018 sec.
# ===> Epoch[24](16/25) : Loss: 0.0137 || Timer: 0.0019 sec.
# ===> Epoch[24](17/25) : Loss: 0.0204 || Timer: 0.0019 sec.
# ===> Epoch[24](18/25) : Loss: 0.0170 || Timer: 0.0022 sec.
# ===> Epoch[24](19/25) : Loss: 0.0145 || Timer: 0.0020 sec.
# ===> Epoch[24](20/25) : Loss: 0.0177 || Timer: 0.0021 sec.
# ===> Epoch[24](21/25) : Loss: 0.0121 || Timer: 0.0019 sec.
# ===> Epoch[24](22/25) : Loss: 0.0222 || Timer: 0.0017 sec.
# ===> Epoch[24](23/25) : Loss: 0.0142 || Timer: 0.0020 sec.
# ===> Epoch[24](24/25) : Loss: 0.0172 || Timer: 0.0019 sec.
# ===> Epoch[24](25/25) : Loss: 0.0143 || Timer: 0.0014 sec.
# ===> Epoch 24 Complete : Avg. Loss: 0.0164
# ===> Epoch[25](1/25) : Loss: 0.0148 || Timer: 0.0031 sec.
# ===> Epoch[25](2/25) : Loss: 0.0122 || Timer: 0.0036 sec.
# ===> Epoch[25](3/25) : Loss: 0.0171 || Timer: 0.0020 sec.
# ===> Epoch[25](4/25) : Loss: 0.0151 || Timer: 0.0021 sec.
# ===> Epoch[25](5/25) : Loss: 0.0196 || Timer: 0.0020 sec.
# ===> Epoch[25](6/25) : Loss: 0.0143 || Timer: 0.0081 sec.
# ===> Epoch[25](7/25) : Loss: 0.0135 || Timer: 0.0018 sec.
# ===> Epoch[25](8/25) : Loss: 0.0169 || Timer: 0.0018 sec.
# ===> Epoch[25](9/25) : Loss: 0.0140 || Timer: 0.0028 sec.
# ===> Epoch[25](10/25) : Loss: 0.0134 || Timer: 0.0017 sec.
# ===> Epoch[25](11/25) : Loss: 0.0148 || Timer: 0.0026 sec.
# ===> Epoch[25](12/25) : Loss: 0.0187 || Timer: 0.0019 sec.
# ===> Epoch[25](13/25) : Loss: 0.0163 || Timer: 0.0021 sec.
# ===> Epoch[25](14/25) : Loss: 0.0135 || Timer: 0.0019 sec.
# ===> Epoch[25](15/25) : Loss: 0.0168 || Timer: 0.0018 sec.
# ===> Epoch[25](16/25) : Loss: 0.0109 || Timer: 0.0024 sec.
# ===> Epoch[25](17/25) : Loss: 0.0232 || Timer: 0.0018 sec.
# ===> Epoch[25](18/25) : Loss: 0.0164 || Timer: 0.0019 sec.
# ===> Epoch[25](19/25) : Loss: 0.0138 || Timer: 0.0018 sec.
# ===> Epoch[25](20/25) : Loss: 0.0149 || Timer: 0.0021 sec.
# ===> Epoch[25](21/25) : Loss: 0.0138 || Timer: 0.0020 sec.
# ===> Epoch[25](22/25) : Loss: 0.0181 || Timer: 0.0020 sec.
# ===> Epoch[25](23/25) : Loss: 0.0185 || Timer: 0.0018 sec.
# ===> Epoch[25](24/25) : Loss: 0.0101 || Timer: 0.0022 sec.
# ===> Epoch[25](25/25) : Loss: 0.0188 || Timer: 0.0014 sec.
# ===> Epoch 25 Complete : Avg. Loss: 0.0156
# ===> Epoch[26](1/25) : Loss: 0.0172 || Timer: 0.0033 sec.
# ===> Epoch[26](2/25) : Loss: 0.0138 || Timer: 0.0020 sec.
# ===> Epoch[26](3/25) : Loss: 0.0130 || Timer: 0.0014 sec.
# ===> Epoch[26](4/25) : Loss: 0.0159 || Timer: 0.0018 sec.
# ===> Epoch[26](5/25) : Loss: 0.0188 || Timer: 0.0018 sec.
# ===> Epoch[26](6/25) : Loss: 0.0118 || Timer: 0.0020 sec.
# ===> Epoch[26](7/25) : Loss: 0.0151 || Timer: 0.0023 sec.
# ===> Epoch[26](8/25) : Loss: 0.0121 || Timer: 0.0021 sec.
# ===> Epoch[26](9/25) : Loss: 0.0180 || Timer: 0.0020 sec.
# ===> Epoch[26](10/25) : Loss: 0.0180 || Timer: 0.0019 sec.
# ===> Epoch[26](11/25) : Loss: 0.0136 || Timer: 0.0021 sec.
# ===> Epoch[26](12/25) : Loss: 0.0192 || Timer: 0.0018 sec.
# ===> Epoch[26](13/25) : Loss: 0.0179 || Timer: 0.0026 sec.
# ===> Epoch[26](14/25) : Loss: 0.0158 || Timer: 0.0020 sec.
# ===> Epoch[26](15/25) : Loss: 0.0145 || Timer: 0.0018 sec.
# ===> Epoch[26](16/25) : Loss: 0.0171 || Timer: 0.0020 sec.
# ===> Epoch[26](17/25) : Loss: 0.0157 || Timer: 0.0020 sec.
# ===> Epoch[26](18/25) : Loss: 0.0146 || Timer: 0.0020 sec.
# ===> Epoch[26](19/25) : Loss: 0.0125 || Timer: 0.0021 sec.
# ===> Epoch[26](20/25) : Loss: 0.0151 || Timer: 0.0020 sec.
# ===> Epoch[26](21/25) : Loss: 0.0186 || Timer: 0.0022 sec.
# ===> Epoch[26](22/25) : Loss: 0.0156 || Timer: 0.0019 sec.
# ===> Epoch[26](23/25) : Loss: 0.0176 || Timer: 0.0020 sec.
# ===> Epoch[26](24/25) : Loss: 0.0135 || Timer: 0.0019 sec.
# ===> Epoch[26](25/25) : Loss: 0.0173 || Timer: 0.0015 sec.
# ===> Epoch 26 Complete : Avg. Loss: 0.0157
# ===> Epoch[27](1/25) : Loss: 0.0166 || Timer: 0.0031 sec.
# ===> Epoch[27](2/25) : Loss: 0.0189 || Timer: 0.0020 sec.
# ===> Epoch[27](3/25) : Loss: 0.0150 || Timer: 0.0020 sec.
# ===> Epoch[27](4/25) : Loss: 0.0171 || Timer: 0.0020 sec.
# ===> Epoch[27](5/25) : Loss: 0.0175 || Timer: 0.0076 sec.
# ===> Epoch[27](6/25) : Loss: 0.0162 || Timer: 0.0019 sec.
# ===> Epoch[27](7/25) : Loss: 0.0143 || Timer: 0.0019 sec.
# ===> Epoch[27](8/25) : Loss: 0.0189 || Timer: 0.0020 sec.
# ===> Epoch[27](9/25) : Loss: 0.0105 || Timer: 0.0020 sec.
# ===> Epoch[27](10/25) : Loss: 0.0154 || Timer: 0.0019 sec.
# ===> Epoch[27](11/25) : Loss: 0.0143 || Timer: 0.0021 sec.
# ===> Epoch[27](12/25) : Loss: 0.0163 || Timer: 0.0020 sec.
# ===> Epoch[27](13/25) : Loss: 0.0168 || Timer: 0.0019 sec.
# ===> Epoch[27](14/25) : Loss: 0.0133 || Timer: 0.0019 sec.
# ===> Epoch[27](15/25) : Loss: 0.0176 || Timer: 0.0032 sec.
# ===> Epoch[27](16/25) : Loss: 0.0159 || Timer: 0.0019 sec.
# ===> Epoch[27](17/25) : Loss: 0.0192 || Timer: 0.0028 sec.
# ===> Epoch[27](18/25) : Loss: 0.0151 || Timer: 0.0018 sec.
# ===> Epoch[27](19/25) : Loss: 0.0145 || Timer: 0.0019 sec.
# ===> Epoch[27](20/25) : Loss: 0.0145 || Timer: 0.0020 sec.
# ===> Epoch[27](21/25) : Loss: 0.0182 || Timer: 0.0019 sec.
# ===> Epoch[27](22/25) : Loss: 0.0192 || Timer: 0.0026 sec.
# ===> Epoch[27](23/25) : Loss: 0.0167 || Timer: 0.0018 sec.
# ===> Epoch[27](24/25) : Loss: 0.0130 || Timer: 0.0019 sec.
# ===> Epoch[27](25/25) : Loss: 0.0149 || Timer: 0.0014 sec.
# ===> Epoch 27 Complete : Avg. Loss: 0.0160
# ===> Epoch[28](1/25) : Loss: 0.0195 || Timer: 0.0033 sec.
# ===> Epoch[28](2/25) : Loss: 0.0134 || Timer: 0.0018 sec.
# ===> Epoch[28](3/25) : Loss: 0.0172 || Timer: 0.0018 sec.
# ===> Epoch[28](4/25) : Loss: 0.0210 || Timer: 0.0019 sec.
# ===> Epoch[28](5/25) : Loss: 0.0187 || Timer: 0.0019 sec.
# ===> Epoch[28](6/25) : Loss: 0.0121 || Timer: 0.0018 sec.
# ===> Epoch[28](7/25) : Loss: 0.0147 || Timer: 0.0025 sec.
# ===> Epoch[28](8/25) : Loss: 0.0164 || Timer: 0.0020 sec.
# ===> Epoch[28](9/25) : Loss: 0.0138 || Timer: 0.0019 sec.
# ===> Epoch[28](10/25) : Loss: 0.0179 || Timer: 0.0020 sec.
# ===> Epoch[28](11/25) : Loss: 0.0160 || Timer: 0.0020 sec.
# ===> Epoch[28](12/25) : Loss: 0.0154 || Timer: 0.0020 sec.
# ===> Epoch[28](13/25) : Loss: 0.0148 || Timer: 0.0017 sec.
# ===> Epoch[28](14/25) : Loss: 0.0134 || Timer: 0.0021 sec.
# ===> Epoch[28](15/25) : Loss: 0.0164 || Timer: 0.0021 sec.
# ===> Epoch[28](16/25) : Loss: 0.0157 || Timer: 0.0020 sec.
# ===> Epoch[28](17/25) : Loss: 0.0184 || Timer: 0.0018 sec.
# ===> Epoch[28](18/25) : Loss: 0.0154 || Timer: 0.0020 sec.
# ===> Epoch[28](19/25) : Loss: 0.0143 || Timer: 0.0014 sec.
# ===> Epoch[28](20/25) : Loss: 0.0117 || Timer: 0.0020 sec.
# ===> Epoch[28](21/25) : Loss: 0.0222 || Timer: 0.0018 sec.
# ===> Epoch[28](22/25) : Loss: 0.0186 || Timer: 0.0018 sec.
# ===> Epoch[28](23/25) : Loss: 0.0141 || Timer: 0.0019 sec.
# ===> Epoch[28](24/25) : Loss: 0.0108 || Timer: 0.0020 sec.
# ===> Epoch[28](25/25) : Loss: 0.0148 || Timer: 0.0016 sec.
# ===> Epoch 28 Complete : Avg. Loss: 0.0159
# ===> Epoch[29](1/25) : Loss: 0.0189 || Timer: 0.0030 sec.
# ===> Epoch[29](2/25) : Loss: 0.0170 || Timer: 0.0022 sec.
# ===> Epoch[29](3/25) : Loss: 0.0154 || Timer: 0.0018 sec.
# ===> Epoch[29](4/25) : Loss: 0.0148 || Timer: 0.0019 sec.
# ===> Epoch[29](5/25) : Loss: 0.0150 || Timer: 0.0019 sec.
# ===> Epoch[29](6/25) : Loss: 0.0156 || Timer: 0.0019 sec.
# ===> Epoch[29](7/25) : Loss: 0.0144 || Timer: 0.0019 sec.
# ===> Epoch[29](8/25) : Loss: 0.0141 || Timer: 0.0019 sec.
# ===> Epoch[29](9/25) : Loss: 0.0151 || Timer: 0.0019 sec.
# ===> Epoch[29](10/25) : Loss: 0.0198 || Timer: 0.0020 sec.
# ===> Epoch[29](11/25) : Loss: 0.0160 || Timer: 0.0020 sec.
# ===> Epoch[29](12/25) : Loss: 0.0147 || Timer: 0.0021 sec.
# ===> Epoch[29](13/25) : Loss: 0.0139 || Timer: 0.0020 sec.
# ===> Epoch[29](14/25) : Loss: 0.0124 || Timer: 0.0016 sec.
# ===> Epoch[29](15/25) : Loss: 0.0207 || Timer: 0.0016 sec.
# ===> Epoch[29](16/25) : Loss: 0.0162 || Timer: 0.0020 sec.
# ===> Epoch[29](17/25) : Loss: 0.0162 || Timer: 0.0018 sec.
# ===> Epoch[29](18/25) : Loss: 0.0110 || Timer: 0.0030 sec.
# ===> Epoch[29](19/25) : Loss: 0.0138 || Timer: 0.0019 sec.
# ===> Epoch[29](20/25) : Loss: 0.0164 || Timer: 0.0017 sec.
# ===> Epoch[29](21/25) : Loss: 0.0146 || Timer: 0.0022 sec.
# ===> Epoch[29](22/25) : Loss: 0.0172 || Timer: 0.0018 sec.
# ===> Epoch[29](23/25) : Loss: 0.0188 || Timer: 0.0018 sec.
# ===> Epoch[29](24/25) : Loss: 0.0185 || Timer: 0.0019 sec.
# ===> Epoch[29](25/25) : Loss: 0.0203 || Timer: 0.0015 sec.
# ===> Epoch 29 Complete : Avg. Loss: 0.0160
# ===> Epoch[30](1/25) : Loss: 0.0107 || Timer: 0.0035 sec.
# ===> Epoch[30](2/25) : Loss: 0.0118 || Timer: 0.0022 sec.
# ===> Epoch[30](3/25) : Loss: 0.0167 || Timer: 0.0020 sec.
# ===> Epoch[30](4/25) : Loss: 0.0169 || Timer: 0.0018 sec.
# ===> Epoch[30](5/25) : Loss: 0.0127 || Timer: 0.0020 sec.
# ===> Epoch[30](6/25) : Loss: 0.0149 || Timer: 0.0020 sec.
# ===> Epoch[30](7/25) : Loss: 0.0155 || Timer: 0.0023 sec.
# ===> Epoch[30](8/25) : Loss: 0.0137 || Timer: 0.0020 sec.
# ===> Epoch[30](9/25) : Loss: 0.0220 || Timer: 0.0020 sec.
# ===> Epoch[30](10/25) : Loss: 0.0152 || Timer: 0.0019 sec.
# ===> Epoch[30](11/25) : Loss: 0.0199 || Timer: 0.0020 sec.
# ===> Epoch[30](12/25) : Loss: 0.0160 || Timer: 0.0019 sec.
# ===> Epoch[30](13/25) : Loss: 0.0095 || Timer: 0.0018 sec.
# ===> Epoch[30](14/25) : Loss: 0.0181 || Timer: 0.0014 sec.
# ===> Epoch[30](15/25) : Loss: 0.0129 || Timer: 0.0021 sec.
# ===> Epoch[30](16/25) : Loss: 0.0143 || Timer: 0.0018 sec.
# ===> Epoch[30](17/25) : Loss: 0.0148 || Timer: 0.0020 sec.
# ===> Epoch[30](18/25) : Loss: 0.0174 || Timer: 0.0017 sec.
# ===> Epoch[30](19/25) : Loss: 0.0188 || Timer: 0.0019 sec.
# ===> Epoch[30](20/25) : Loss: 0.0160 || Timer: 0.0020 sec.
# ===> Epoch[30](21/25) : Loss: 0.0181 || Timer: 0.0020 sec.
# ===> Epoch[30](22/25) : Loss: 0.0199 || Timer: 0.0019 sec.
# ===> Epoch[30](23/25) : Loss: 0.0136 || Timer: 0.0020 sec.
# ===> Epoch[30](24/25) : Loss: 0.0158 || Timer: 0.0021 sec.
# ===> Epoch[30](25/25) : Loss: 0.0173 || Timer: 0.0019 sec.
# ===> Epoch 30 Complete : Avg. Loss: 0.0157
# ===> Epoch[31](1/25) : Loss: 0.0193 || Timer: 0.0031 sec.
# ===> Epoch[31](2/25) : Loss: 0.0144 || Timer: 0.0021 sec.
# ===> Epoch[31](3/25) : Loss: 0.0165 || Timer: 0.0018 sec.
# ===> Epoch[31](4/25) : Loss: 0.0136 || Timer: 0.0018 sec.
# ===> Epoch[31](5/25) : Loss: 0.0165 || Timer: 0.0020 sec.
# ===> Epoch[31](6/25) : Loss: 0.0151 || Timer: 0.0019 sec.
# ===> Epoch[31](7/25) : Loss: 0.0158 || Timer: 0.0020 sec.
# ===> Epoch[31](8/25) : Loss: 0.0209 || Timer: 0.0018 sec.
# ===> Epoch[31](9/25) : Loss: 0.0178 || Timer: 0.0022 sec.
# ===> Epoch[31](10/25) : Loss: 0.0178 || Timer: 0.0019 sec.
# ===> Epoch[31](11/25) : Loss: 0.0168 || Timer: 0.0018 sec.
# ===> Epoch[31](12/25) : Loss: 0.0130 || Timer: 0.0019 sec.
# ===> Epoch[31](13/25) : Loss: 0.0186 || Timer: 0.0017 sec.
# ===> Epoch[31](14/25) : Loss: 0.0138 || Timer: 0.0018 sec.
# ===> Epoch[31](15/25) : Loss: 0.0146 || Timer: 0.0018 sec.
# ===> Epoch[31](16/25) : Loss: 0.0231 || Timer: 0.0020 sec.
# ===> Epoch[31](17/25) : Loss: 0.0182 || Timer: 0.0020 sec.
# ===> Epoch[31](18/25) : Loss: 0.0117 || Timer: 0.0018 sec.
# ===> Epoch[31](19/25) : Loss: 0.0189 || Timer: 0.0017 sec.
# ===> Epoch[31](20/25) : Loss: 0.0138 || Timer: 0.0023 sec.
# ===> Epoch[31](21/25) : Loss: 0.0158 || Timer: 0.0017 sec.
# ===> Epoch[31](22/25) : Loss: 0.0138 || Timer: 0.0018 sec.
# ===> Epoch[31](23/25) : Loss: 0.0172 || Timer: 0.0018 sec.
# ===> Epoch[31](24/25) : Loss: 0.0145 || Timer: 0.0019 sec.
# ===> Epoch[31](25/25) : Loss: 0.0158 || Timer: 0.0015 sec.
# ===> Epoch 31 Complete : Avg. Loss: 0.0163
# ===> Epoch[32](1/25) : Loss: 0.0133 || Timer: 0.0031 sec.
# ===> Epoch[32](2/25) : Loss: 0.0172 || Timer: 0.0016 sec.
# ===> Epoch[32](3/25) : Loss: 0.0197 || Timer: 0.0022 sec.
# ===> Epoch[32](4/25) : Loss: 0.0170 || Timer: 0.0021 sec.
# ===> Epoch[32](5/25) : Loss: 0.0136 || Timer: 0.0019 sec.
# ===> Epoch[32](6/25) : Loss: 0.0158 || Timer: 0.0020 sec.
# ===> Epoch[32](7/25) : Loss: 0.0126 || Timer: 0.0018 sec.
# ===> Epoch[32](8/25) : Loss: 0.0133 || Timer: 0.0031 sec.
# ===> Epoch[32](9/25) : Loss: 0.0170 || Timer: 0.0019 sec.
# ===> Epoch[32](10/25) : Loss: 0.0157 || Timer: 0.0027 sec.
# ===> Epoch[32](11/25) : Loss: 0.0151 || Timer: 0.0019 sec.
# ...
# ===> Epoch[70](14/25) : Loss: 0.0188 || Timer: 0.0019 sec.
# ===> Epoch[70](15/25) : Loss: 0.0162 || Timer: 0.0018 sec.
# ===> Epoch[70](16/25) : Loss: 0.0137 || Timer: 0.0019 sec.
# ===> Epoch[70](17/25) : Loss: 0.0155 || Timer: 0.0018 sec.
# ===> Epoch[70](18/25) : Loss: 0.0144 || Timer: 0.0018 sec.
# ===> Epoch[70](19/25) : Loss: 0.0116 || Timer: 0.0019 sec.
# ===> Epoch[70](20/25) : Loss: 0.0170 || Timer: 0.0018 sec.
# ===> Epoch[70](21/25) : Loss: 0.0148 || Timer: 0.0018 sec.
# ===> Epoch[70](22/25) : Loss: 0.0124 || Timer: 0.0020 sec.
# ===> Epoch[70](23/25) : Loss: 0.0119 || Timer: 0.0018 sec.
# ===> Epoch[70](24/25) : Loss: 0.0172 || Timer: 0.0018 sec.
# ===> Epoch[70](25/25) : Loss: 0.0160 || Timer: 0.0021 sec.
# ===> Epoch 70 Complete : Avg. Loss: 0.0162
# ===> Epoch[71](1/25) : Loss: 0.0109 || Timer: 0.0033 sec.
# ===> Epoch[71](2/25) : Loss: 0.0143 || Timer: 0.0019 sec.
# ===> Epoch[71](3/25) : Loss: 0.0164 || Timer: 0.0019 sec.
# ===> Epoch[71](4/25) : Loss: 0.0179 || Timer: 0.0019 sec.
# ===> Epoch[71](5/25) : Loss: 0.0146 || Timer: 0.0021 sec.
# ===> Epoch[71](6/25) : Loss: 0.0128 || Timer: 0.0019 sec.
# ===> Epoch[71](7/25) : Loss: 0.0169 || Timer: 0.0021 sec.
# ===> Epoch[71](8/25) : Loss: 0.0116 || Timer: 0.0021 sec.
# ===> Epoch[71](9/25) : Loss: 0.0161 || Timer: 0.0019 sec.
# ===> Epoch[71](10/25) : Loss: 0.0160 || Timer: 0.0018 sec.
# ===> Epoch[71](11/25) : Loss: 0.0166 || Timer: 0.0020 sec.
# ===> Epoch[71](12/25) : Loss: 0.0126 || Timer: 0.0020 sec.
# ===> Epoch[71](13/25) : Loss: 0.0164 || Timer: 0.0021 sec.
# ===> Epoch[71](14/25) : Loss: 0.0183 || Timer: 0.0017 sec.
# ===> Epoch[71](15/25) : Loss: 0.0148 || Timer: 0.0021 sec.
# ===> Epoch[71](16/25) : Loss: 0.0106 || Timer: 0.0020 sec.
# ===> Epoch[71](17/25) : Loss: 0.0142 || Timer: 0.0018 sec.
# ===> Epoch[71](18/25) : Loss: 0.0192 || Timer: 0.0023 sec.
# ===> Epoch[71](19/25) : Loss: 0.0164 || Timer: 0.0018 sec.
# ===> Epoch[71](20/25) : Loss: 0.0147 || Timer: 0.0019 sec.
# ===> Epoch[71](21/25) : Loss: 0.0136 || Timer: 0.0017 sec.
# ===> Epoch[71](22/25) : Loss: 0.0132 || Timer: 0.0019 sec.
# ===> Epoch[71](23/25) : Loss: 0.0155 || Timer: 0.0018 sec.
# ===> Epoch[71](24/25) : Loss: 0.0156 || Timer: 0.0019 sec.
# ===> Epoch[71](25/25) : Loss: 0.0144 || Timer: 0.0014 sec.
# ===> Epoch 71 Complete : Avg. Loss: 0.0149
# ===> Epoch[72](1/25) : Loss: 0.0168 || Timer: 0.0032 sec.
# ===> Epoch[72](2/25) : Loss: 0.0194 || Timer: 0.0020 sec.
# ===> Epoch[72](3/25) : Loss: 0.0173 || Timer: 0.0022 sec.
# ===> Epoch[72](4/25) : Loss: 0.0153 || Timer: 0.0021 sec.
# ===> Epoch[72](5/25) : Loss: 0.0109 || Timer: 0.0023 sec.
# ===> Epoch[72](6/25) : Loss: 0.0211 || Timer: 0.0021 sec.
# ===> Epoch[72](7/25) : Loss: 0.0149 || Timer: 0.0020 sec.
# ===> Epoch[72](8/25) : Loss: 0.0146 || Timer: 0.0024 sec.
# ===> Epoch[72](9/25) : Loss: 0.0188 || Timer: 0.0022 sec.
# ===> Epoch[72](10/25) : Loss: 0.0142 || Timer: 0.0016 sec.
# ===> Epoch[72](11/25) : Loss: 0.0129 || Timer: 0.0023 sec.
# ===> Epoch[72](12/25) : Loss: 0.0165 || Timer: 0.0018 sec.
# ===> Epoch[72](13/25) : Loss: 0.0145 || Timer: 0.0020 sec.
# ===> Epoch[72](14/25) : Loss: 0.0165 || Timer: 0.0022 sec.
# ===> Epoch[72](15/25) : Loss: 0.0155 || Timer: 0.0023 sec.
# ===> Epoch[72](16/25) : Loss: 0.0138 || Timer: 0.0021 sec.
# ===> Epoch[72](17/25) : Loss: 0.0120 || Timer: 0.0020 sec.
# ===> Epoch[72](18/25) : Loss: 0.0174 || Timer: 0.0019 sec.
# ===> Epoch[72](19/25) : Loss: 0.0146 || Timer: 0.0020 sec.
# ===> Epoch[72](20/25) : Loss: 0.0208 || Timer: 0.0018 sec.
# ===> Epoch[72](21/25) : Loss: 0.0157 || Timer: 0.0023 sec.
# ===> Epoch[72](22/25) : Loss: 0.0111 || Timer: 0.0022 sec.
# ===> Epoch[72](23/25) : Loss: 0.0190 || Timer: 0.0021 sec.
# ===> Epoch[72](24/25) : Loss: 0.0175 || Timer: 0.0023 sec.
# ===> Epoch[72](25/25) : Loss: 0.0151 || Timer: 0.0017 sec.
# ===> Epoch 72 Complete : Avg. Loss: 0.0158
# ===> Epoch[73](1/25) : Loss: 0.0103 || Timer: 0.0032 sec.
# ===> Epoch[73](2/25) : Loss: 0.0140 || Timer: 0.0024 sec.
# ===> Epoch[73](3/25) : Loss: 0.0138 || Timer: 0.0022 sec.
# ===> Epoch[73](4/25) : Loss: 0.0151 || Timer: 0.0022 sec.
# ===> Epoch[73](5/25) : Loss: 0.0129 || Timer: 0.0021 sec.
# ===> Epoch[73](6/25) : Loss: 0.0133 || Timer: 0.0019 sec.
# ===> Epoch[73](7/25) : Loss: 0.0200 || Timer: 0.0024 sec.
# ===> Epoch[73](8/25) : Loss: 0.0125 || Timer: 0.0021 sec.
# ===> Epoch[73](9/25) : Loss: 0.0145 || Timer: 0.0021 sec.
# ===> Epoch[73](10/25) : Loss: 0.0155 || Timer: 0.0018 sec.
# ===> Epoch[73](11/25) : Loss: 0.0179 || Timer: 0.0020 sec.
# ===> Epoch[73](12/25) : Loss: 0.0129 || Timer: 0.0017 sec.
# ===> Epoch[73](13/25) : Loss: 0.0138 || Timer: 0.0019 sec.
# ===> Epoch[73](14/25) : Loss: 0.0159 || Timer: 0.0020 sec.
# ===> Epoch[73](15/25) : Loss: 0.0166 || Timer: 0.0020 sec.
# ===> Epoch[73](16/25) : Loss: 0.0152 || Timer: 0.0018 sec.
# ===> Epoch[73](17/25) : Loss: 0.0122 || Timer: 0.0022 sec.
# ===> Epoch[73](18/25) : Loss: 0.0188 || Timer: 0.0025 sec.
# ===> Epoch[73](19/25) : Loss: 0.0129 || Timer: 0.0021 sec.
# ===> Epoch[73](20/25) : Loss: 0.0209 || Timer: 0.0016 sec.
# ===> Epoch[73](21/25) : Loss: 0.0156 || Timer: 0.0074 sec.
# ===> Epoch[73](22/25) : Loss: 0.0125 || Timer: 0.0019 sec.
# ===> Epoch[73](23/25) : Loss: 0.0224 || Timer: 0.0020 sec.
# ===> Epoch[73](24/25) : Loss: 0.0168 || Timer: 0.0018 sec.
# ===> Epoch[73](25/25) : Loss: 0.0129 || Timer: 0.0014 sec.
# ===> Epoch 73 Complete : Avg. Loss: 0.0152
# ===> Epoch[74](1/25) : Loss: 0.0171 || Timer: 0.0031 sec.
# ===> Epoch[74](2/25) : Loss: 0.0165 || Timer: 0.0019 sec.
# ===> Epoch[74](3/25) : Loss: 0.0176 || Timer: 0.0019 sec.
# ===> Epoch[74](4/25) : Loss: 0.0134 || Timer: 0.0020 sec.
# ===> Epoch[74](5/25) : Loss: 0.0174 || Timer: 0.0021 sec.
# ===> Epoch[74](6/25) : Loss: 0.0157 || Timer: 0.0019 sec.
# ===> Epoch[74](7/25) : Loss: 0.0154 || Timer: 0.0019 sec.
# ===> Epoch[74](8/25) : Loss: 0.0150 || Timer: 0.0014 sec.
# ===> Epoch[74](9/25) : Loss: 0.0174 || Timer: 0.0018 sec.
# ===> Epoch[74](10/25) : Loss: 0.0141 || Timer: 0.0019 sec.
# ===> Epoch[74](11/25) : Loss: 0.0181 || Timer: 0.0020 sec.
# ===> Epoch[74](12/25) : Loss: 0.0141 || Timer: 0.0020 sec.
# ===> Epoch[74](13/25) : Loss: 0.0136 || Timer: 0.0020 sec.
# ===> Epoch[74](14/25) : Loss: 0.0208 || Timer: 0.0018 sec.
# ===> Epoch[74](15/25) : Loss: 0.0136 || Timer: 0.0020 sec.
# ===> Epoch[74](16/25) : Loss: 0.0184 || Timer: 0.0020 sec.
# ===> Epoch[74](17/25) : Loss: 0.0162 || Timer: 0.0014 sec.
# ===> Epoch[74](18/25) : Loss: 0.0139 || Timer: 0.0020 sec.
# ===> Epoch[74](19/25) : Loss: 0.0158 || Timer: 0.0019 sec.
# ===> Epoch[74](20/25) : Loss: 0.0149 || Timer: 0.0020 sec.
# ===> Epoch[74](21/25) : Loss: 0.0174 || Timer: 0.0021 sec.
# ===> Epoch[74](22/25) : Loss: 0.0170 || Timer: 0.0019 sec.
# ===> Epoch[74](23/25) : Loss: 0.0212 || Timer: 0.0020 sec.
# ===> Epoch[74](24/25) : Loss: 0.0139 || Timer: 0.0020 sec.
# ===> Epoch[74](25/25) : Loss: 0.0122 || Timer: 0.0014 sec.
# ===> Epoch 74 Complete : Avg. Loss: 0.0160
# ===> Epoch[75](1/25) : Loss: 0.0152 || Timer: 0.0032 sec.
# ===> Epoch[75](2/25) : Loss: 0.0172 || Timer: 0.0020 sec.
# ===> Epoch[75](3/25) : Loss: 0.0160 || Timer: 0.0019 sec.
# ===> Epoch[75](4/25) : Loss: 0.0157 || Timer: 0.0018 sec.
# ===> Epoch[75](5/25) : Loss: 0.0144 || Timer: 0.0019 sec.
# ===> Epoch[75](6/25) : Loss: 0.0158 || Timer: 0.0020 sec.
# ===> Epoch[75](7/25) : Loss: 0.0146 || Timer: 0.0019 sec.
# ===> Epoch[75](8/25) : Loss: 0.0176 || Timer: 0.0019 sec.
# ===> Epoch[75](9/25) : Loss: 0.0136 || Timer: 0.0019 sec.
# ===> Epoch[75](10/25) : Loss: 0.0098 || Timer: 0.0019 sec.
# ===> Epoch[75](11/25) : Loss: 0.0155 || Timer: 0.0019 sec.
# ===> Epoch[75](12/25) : Loss: 0.0141 || Timer: 0.0021 sec.
# ===> Epoch[75](13/25) : Loss: 0.0168 || Timer: 0.0019 sec.
# ===> Epoch[75](14/25) : Loss: 0.0152 || Timer: 0.0021 sec.
# ===> Epoch[75](15/25) : Loss: 0.0227 || Timer: 0.0019 sec.
# ===> Epoch[75](16/25) : Loss: 0.0164 || Timer: 0.0020 sec.
# ===> Epoch[75](17/25) : Loss: 0.0145 || Timer: 0.0021 sec.
# ===> Epoch[75](18/25) : Loss: 0.0137 || Timer: 0.0020 sec.
# ===> Epoch[75](19/25) : Loss: 0.0159 || Timer: 0.0019 sec.
# ===> Epoch[75](20/25) : Loss: 0.0162 || Timer: 0.0019 sec.
# ===> Epoch[75](21/25) : Loss: 0.0188 || Timer: 0.0018 sec.
# ===> Epoch[75](22/25) : Loss: 0.0165 || Timer: 0.0020 sec.
# ===> Epoch[75](23/25) : Loss: 0.0176 || Timer: 0.0036 sec.
# ===> Epoch[75](24/25) : Loss: 0.0237 || Timer: 0.0020 sec.
# ===> Epoch[75](25/25) : Loss: 0.0130 || Timer: 0.0015 sec.
# ===> Epoch 75 Complete : Avg. Loss: 0.0160
# ===> Epoch[76](1/25) : Loss: 0.0147 || Timer: 0.0034 sec.
# ===> Epoch[76](2/25) : Loss: 0.0119 || Timer: 0.0020 sec.
# ===> Epoch[76](3/25) : Loss: 0.0170 || Timer: 0.0019 sec.
# ===> Epoch[76](4/25) : Loss: 0.0222 || Timer: 0.0025 sec.
# ===> Epoch[76](5/25) : Loss: 0.0161 || Timer: 0.0022 sec.
# ===> Epoch[76](6/25) : Loss: 0.0145 || Timer: 0.0022 sec.
# ===> Epoch[76](7/25) : Loss: 0.0174 || Timer: 0.0018 sec.
# ===> Epoch[76](8/25) : Loss: 0.0154 || Timer: 0.0025 sec.
# ===> Epoch[76](9/25) : Loss: 0.0105 || Timer: 0.0020 sec.
# ===> Epoch[76](10/25) : Loss: 0.0104 || Timer: 0.0021 sec.
# ===> Epoch[76](11/25) : Loss: 0.0181 || Timer: 0.0018 sec.
# ===> Epoch[76](12/25) : Loss: 0.0155 || Timer: 0.0018 sec.
# ===> Epoch[76](13/25) : Loss: 0.0151 || Timer: 0.0020 sec.
# ===> Epoch[76](14/25) : Loss: 0.0109 || Timer: 0.0019 sec.
# ===> Epoch[76](15/25) : Loss: 0.0165 || Timer: 0.0021 sec.
# ===> Epoch[76](16/25) : Loss: 0.0167 || Timer: 0.0018 sec.
# ===> Epoch[76](17/25) : Loss: 0.0132 || Timer: 0.0029 sec.
# ===> Epoch[76](18/25) : Loss: 0.0129 || Timer: 0.0020 sec.
# ===> Epoch[76](19/25) : Loss: 0.0142 || Timer: 0.0016 sec.
# ===> Epoch[76](20/25) : Loss: 0.0174 || Timer: 0.0018 sec.
# ===> Epoch[76](21/25) : Loss: 0.0141 || Timer: 0.0019 sec.
# ===> Epoch[76](22/25) : Loss: 0.0132 || Timer: 0.0019 sec.
# ===> Epoch[76](23/25) : Loss: 0.0159 || Timer: 0.0060 sec.
# ===> Epoch[76](24/25) : Loss: 0.0160 || Timer: 0.0020 sec.
# ===> Epoch[76](25/25) : Loss: 0.0157 || Timer: 0.0015 sec.
# ===> Epoch 76 Complete : Avg. Loss: 0.0150
# ===> Epoch[77](1/25) : Loss: 0.0171 || Timer: 0.0032 sec.
# ===> Epoch[77](2/25) : Loss: 0.0157 || Timer: 0.0020 sec.
# ===> Epoch[77](3/25) : Loss: 0.0168 || Timer: 0.0055 sec.
# ===> Epoch[77](4/25) : Loss: 0.0127 || Timer: 0.0021 sec.
# ===> Epoch[77](5/25) : Loss: 0.0170 || Timer: 0.0020 sec.
# ===> Epoch[77](6/25) : Loss: 0.0156 || Timer: 0.0020 sec.
# ===> Epoch[77](7/25) : Loss: 0.0136 || Timer: 0.0019 sec.
# ===> Epoch[77](8/25) : Loss: 0.0160 || Timer: 0.0020 sec.
# ===> Epoch[77](9/25) : Loss: 0.0166 || Timer: 0.0022 sec.
# ===> Epoch[77](10/25) : Loss: 0.0151 || Timer: 0.0018 sec.
# ===> Epoch[77](11/25) : Loss: 0.0139 || Timer: 0.0016 sec.
# ===> Epoch[77](12/25) : Loss: 0.0144 || Timer: 0.0024 sec.
# ===> Epoch[77](13/25) : Loss: 0.0140 || Timer: 0.0019 sec.
# ===> Epoch[77](14/25) : Loss: 0.0166 || Timer: 0.0020 sec.
# ===> Epoch[77](15/25) : Loss: 0.0162 || Timer: 0.0031 sec.
# ===> Epoch[77](16/25) : Loss: 0.0159 || Timer: 0.0021 sec.
# ===> Epoch[77](17/25) : Loss: 0.0159 || Timer: 0.0020 sec.
# ===> Epoch[77](18/25) : Loss: 0.0191 || Timer: 0.0019 sec.
# ===> Epoch[77](19/25) : Loss: 0.0158 || Timer: 0.0021 sec.
# ===> Epoch[77](20/25) : Loss: 0.0162 || Timer: 0.0021 sec.
# ===> Epoch[77](21/25) : Loss: 0.0182 || Timer: 0.0020 sec.
# ===> Epoch[77](22/25) : Loss: 0.0161 || Timer: 0.0022 sec.
# ===> Epoch[77](23/25) : Loss: 0.0137 || Timer: 0.0020 sec.
# ===> Epoch[77](24/25) : Loss: 0.0178 || Timer: 0.0019 sec.
# ===> Epoch[77](25/25) : Loss: 0.0146 || Timer: 0.0014 sec.
# ===> Epoch 77 Complete : Avg. Loss: 0.0158
# ===> Epoch[78](1/25) : Loss: 0.0177 || Timer: 0.0035 sec.
# ===> Epoch[78](2/25) : Loss: 0.0229 || Timer: 0.0019 sec.
# ===> Epoch[78](3/25) : Loss: 0.0194 || Timer: 0.0019 sec.
# ===> Epoch[78](4/25) : Loss: 0.0124 || Timer: 0.0020 sec.
# ===> Epoch[78](5/25) : Loss: 0.0158 || Timer: 0.0020 sec.
# ===> Epoch[78](6/25) : Loss: 0.0138 || Timer: 0.0023 sec.
# ===> Epoch[78](7/25) : Loss: 0.0184 || Timer: 0.0022 sec.
# ===> Epoch[78](8/25) : Loss: 0.0175 || Timer: 0.0020 sec.
# ===> Epoch[78](9/25) : Loss: 0.0167 || Timer: 0.0018 sec.
# ===> Epoch[78](10/25) : Loss: 0.0197 || Timer: 0.0019 sec.
# ===> Epoch[78](11/25) : Loss: 0.0182 || Timer: 0.0025 sec.
# ===> Epoch[78](12/25) : Loss: 0.0128 || Timer: 0.0018 sec.
# ===> Epoch[78](13/25) : Loss: 0.0114 || Timer: 0.0019 sec.
# ===> Epoch[78](14/25) : Loss: 0.0138 || Timer: 0.0019 sec.
# ===> Epoch[78](15/25) : Loss: 0.0121 || Timer: 0.0018 sec.
# ===> Epoch[78](16/25) : Loss: 0.0131 || Timer: 0.0021 sec.
# ===> Epoch[78](17/25) : Loss: 0.0149 || Timer: 0.0021 sec.
# ===> Epoch[78](18/25) : Loss: 0.0195 || Timer: 0.0018 sec.
# ===> Epoch[78](19/25) : Loss: 0.0140 || Timer: 0.0018 sec.
# ===> Epoch[78](20/25) : Loss: 0.0168 || Timer: 0.0056 sec.
# ===> Epoch[78](21/25) : Loss: 0.0148 || Timer: 0.0019 sec.
# ===> Epoch[78](22/25) : Loss: 0.0121 || Timer: 0.0019 sec.
# ===> Epoch[78](23/25) : Loss: 0.0149 || Timer: 0.0021 sec.
# ===> Epoch[78](24/25) : Loss: 0.0155 || Timer: 0.0022 sec.
# ===> Epoch[78](25/25) : Loss: 0.0162 || Timer: 0.0024 sec.
# ===> Epoch 78 Complete : Avg. Loss: 0.0158
# ===> Epoch[79](1/25) : Loss: 0.0188 || Timer: 0.0033 sec.
# ===> Epoch[79](2/25) : Loss: 0.0162 || Timer: 0.0021 sec.
# ===> Epoch[79](3/25) : Loss: 0.0160 || Timer: 0.0020 sec.
# ===> Epoch[79](4/25) : Loss: 0.0132 || Timer: 0.0019 sec.
# ===> Epoch[79](5/25) : Loss: 0.0168 || Timer: 0.0020 sec.
# ===> Epoch[79](6/25) : Loss: 0.0188 || Timer: 0.0028 sec.
# ===> Epoch[79](7/25) : Loss: 0.0160 || Timer: 0.0018 sec.
# ===> Epoch[79](8/25) : Loss: 0.0118 || Timer: 0.0020 sec.
# ===> Epoch[79](9/25) : Loss: 0.0145 || Timer: 0.0019 sec.
# ===> Epoch[79](10/25) : Loss: 0.0185 || Timer: 0.0019 sec.
# ===> Epoch[79](11/25) : Loss: 0.0141 || Timer: 0.0021 sec.
# ===> Epoch[79](12/25) : Loss: 0.0186 || Timer: 0.0020 sec.
# ===> Epoch[79](13/25) : Loss: 0.0137 || Timer: 0.0019 sec.
# ===> Epoch[79](14/25) : Loss: 0.0142 || Timer: 0.0018 sec.
# ===> Epoch[79](15/25) : Loss: 0.0160 || Timer: 0.0026 sec.
# ===> Epoch[79](16/25) : Loss: 0.0178 || Timer: 0.0019 sec.
# ===> Epoch[79](17/25) : Loss: 0.0147 || Timer: 0.0018 sec.
# ===> Epoch[79](18/25) : Loss: 0.0171 || Timer: 0.0024 sec.
# ===> Epoch[79](19/25) : Loss: 0.0170 || Timer: 0.0018 sec.
# ===> Epoch[79](20/25) : Loss: 0.0160 || Timer: 0.0019 sec.
# ===> Epoch[79](21/25) : Loss: 0.0177 || Timer: 0.0045 sec.
# ===> Epoch[79](22/25) : Loss: 0.0142 || Timer: 0.0020 sec.
# ===> Epoch[79](23/25) : Loss: 0.0146 || Timer: 0.0020 sec.
# ===> Epoch[79](24/25) : Loss: 0.0125 || Timer: 0.0021 sec.
# ===> Epoch[79](25/25) : Loss: 0.0158 || Timer: 0.0015 sec.
# ===> Epoch 79 Complete : Avg. Loss: 0.0158
# Learning rate decay : lr=1e-05
# Checkpoint saved to /content/gdrive/My Drive/study/SRCNN/weights/<built-in function gethostname>_epoch_79.pth
# ===> Epoch[80](1/25) : Loss: 0.0145 || Timer: 0.0033 sec.
# ===> Epoch[80](2/25) : Loss: 0.0123 || Timer: 0.0020 sec.
# ===> Epoch[80](3/25) : Loss: 0.0143 || Timer: 0.0017 sec.
# ===> Epoch[80](4/25) : Loss: 0.0153 || Timer: 0.0021 sec.
# ===> Epoch[80](5/25) : Loss: 0.0128 || Timer: 0.0018 sec.
# ===> Epoch[80](6/25) : Loss: 0.0184 || Timer: 0.0018 sec.
# ===> Epoch[80](7/25) : Loss: 0.0162 || Timer: 0.0020 sec.
# ===> Epoch[80](8/25) : Loss: 0.0099 || Timer: 0.0021 sec.
# ===> Epoch[80](9/25) : Loss: 0.0176 || Timer: 0.0020 sec.
# ===> Epoch[80](10/25) : Loss: 0.0169 || Timer: 0.0019 sec.
# ===> Epoch[80](11/25) : Loss: 0.0163 || Timer: 0.0024 sec.
# ===> Epoch[80](12/25) : Loss: 0.0197 || Timer: 0.0017 sec.
# ===> Epoch[80](13/25) : Loss: 0.0139 || Timer: 0.0018 sec.
# ===> Epoch[80](14/25) : Loss: 0.0130 || Timer: 0.0020 sec.
# ===> Epoch[80](15/25) : Loss: 0.0164 || Timer: 0.0019 sec.
# ===> Epoch[80](16/25) : Loss: 0.0182 || Timer: 0.0020 sec.
# ===> Epoch[80](17/25) : Loss: 0.0186 || Timer: 0.0018 sec.
# ===> Epoch[80](18/25) : Loss: 0.0161 || Timer: 0.0023 sec.
# ===> Epoch[80](19/25) : Loss: 0.0177 || Timer: 0.0019 sec.
# ===> Epoch[80](20/25) : Loss: 0.0137 || Timer: 0.0020 sec.
# ===> Epoch[80](21/25) : Loss: 0.0122 || Timer: 0.0018 sec.
# ===> Epoch[80](22/25) : Loss: 0.0155 || Timer: 0.0021 sec.
# ===> Epoch[80](23/25) : Loss: 0.0126 || Timer: 0.0014 sec.
# ===> Epoch[80](24/25) : Loss: 0.0133 || Timer: 0.0023 sec.
# ===> Epoch[80](25/25) : Loss: 0.0117 || Timer: 0.0013 sec.
# ===> Epoch 80 Complete : Avg. Loss: 0.0151

# %% [markdown]
# # Testing

# %%
from __future__ import print_function
import argparse

import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import DataLoader
from functools import reduce
from math import log10

# from scipy.misc import imsave
import scipy.io as sio
import time
import cv2
import easydict
from google.colab import drive
drive.mount('/content/gdrive')

opt = easydict.EasyDict({ 
    "testBatchSize": 1, 
    "self_ensemble": False,
    "chop_forward": False,
    "gpu_mode": True,
    "threads": 1,
    "seed": 123,
    "gpus": 1,
    "upscale_factor": 2,

    "input_dir":"/content/gdrive/My Drive/study/VDSR/data/test/",  # test dataset 불러올위치
    "test_dataset": "Set5",                             # 사용할 test dataset

    "output": "/content/gdrive/My Drive/study/VDSR/Results/", # 결과영상 저장위치

    "model_type": "VDSR",
    "residual": False,
    "model": "/content/gdrive/My Drive/study/VDSR/weights/test02/<built-in function gethostname>_epoch_79.pth"})  # test에 사용할 weight 불러올 위치 ac040091dff2_epoch_59.pth
#<built-in function gethostname>_epoch_79.pth

gpus_list = range(opt.gpus)
print(opt)

cuda = opt.gpu_mode
if cuda and not torch.cuda.is_available():
    raise Exception("No GPU found, please run without --cuda")
    
torch.manual_seed(opt.seed)
criterion = nn.MSELoss()
    

print('===> Loading datasets')
test_set = get_eval_set(os.path.join(opt.input_dir,opt.test_dataset), opt.upscale_factor)
testing_data_loader = DataLoader(dataset=test_set, num_workers=opt.threads, batch_size=opt.testBatchSize, shuffle=False)
print('===> Building model')
model = VDSR()
model = torch.nn.DataParallel(model, device_ids = gpus_list)
model.load_state_dict(torch.load(opt.model, map_location=lambda storage, loc : storage))
print('Pre-trained SR model is loaded.')

if cuda:
    model = model.cuda(gpus_list[0])
    criterion = criterion.cuda(gpus_list[0])
    
     #필요하지 않나요????(소스코드에는 없음)

    
def eval():
    avg_psnr = 0
    psnr_sq = 0
    model.eval()
    for batch in testing_data_loader:
        with torch.no_grad():
            input, bicubic, target,name = Variable(batch[0]), Variable(batch[1]), Variable(batch[2]), batch[3]
        if cuda : 
            input = input.cuda(gpus_list[0])
            bicubic = bicubic.cuda(gpus_list[0])
            target = target.cuda(gpus_list[0])
            
        t0 = time.time()
        if opt.chop_forward : 
            with torch.no_grad():
                prediction = chop_forward(input, model, opt.upscale_factor)
        else : 
            if opt.self_ensemble :
                with torch.no_grad():
                    prediction = x8_forward(input, model)
            else : 
                with torch.no_grad():    
                    prediction = model(bicubic)  #현재 모델의 경우 이를 수행
        if opt.residual : 
            prediction = prediction + bicubic
        
        mse = criterion(prediction, target)
        psnr = 10 * log10(1 / mse.item())
        avg_psnr += psnr / len(testing_data_loader)
        psnr_sq += psnr*psnr
    
        t1 = time.time()
        print("===> Processing: %s || Timer: %.4f sec. PSNR : %.4f" % (name[0], (t1 - t0), psnr))
        
        save_img(bicubic.cpu().data, "bicubic_"+name[0])
        save_img(prediction.cpu().data, "prediction_"+name[0])
        save_img(target.cpu().data, "target_"+name[0])
        
    variance = psnr_sq / len(testing_data_loader) - avg_psnr*avg_psnr
    print("===> Processing Done, Average PSNR : %.4f" % (avg_psnr))
    print("===>PSNR Variance : %.4f" % (variance))
    
def save_img(img, img_name):
    save_img = img.squeeze().clamp(0, 1).numpy().transpose(1,2,0)
    # save img
    save_dir=os.path.join(opt.output,opt.test_dataset)
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
        
    save_fn = save_dir +'/'+ img_name
    cv2.imwrite(save_fn, cv2.cvtColor(save_img*255, cv2.COLOR_BGR2RGB),  [cv2.IMWRITE_PNG_COMPRESSION, 0])

#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
def x8_forward(img, model, precision = 'single'):  #if self_ensemble = True
    def _transform(v, op):
        if precision != 'single' : 
            v=v.float()
        v2np = v.data.cpu().numpy()  #np array로 바꿔줌
        if op == 'vflip' :
            tfnp = v2np[:, :, :, ::-1].copy()
        elif op == 'hflip':
            tfnp = v2np[:, :, ::-1, :].copy()
        elif op == 'transpose':
            tfnp = v2np.transpose((0, 1, 3, 2)).copy()
        
        ret = torch.Tensor(tfnp).cuda() #다시 Tensor로 변환
        
        if precision == 'half': #float16
            ret = ret.half()
        elif precision == 'double': #float64
            ret = ret.double()

        with torch.no_grad():
            ret = Variable(ret)

        return ret
            
    inputlist = [img]
    for tf in 'vflip', 'hflip', 'transpose': #inputlist에 'vflip', 'hflip', 'transpose' 시킨 data를 추가해줌 (augmentation?)
        inputlist.extend([_transform(t, tf) for t in inputlist])
        
    outputlist = [model(aug) for aug in inputlist] #늘어난 inputlist를 model에 넣어준 결과를 outputlist에 저장
    for i in range(len(outputlist)): #outputlist의 값들도 augmentation 하는건가???
        if i > 3:
            outputlist[i] = _transform(outputlist[i], 'transpose')
        if i % 4 > 1:
            outputlist[i] = _transform(outputlist[i], 'hflip')
        if (i % 4) % 2 == 1:
            outputlist[i] = _transform(outputlist[i], 'vflip')
    output = reduce((lambda x, y : x+y), outputlist) / len(outputlist)   #outputlist안에 data 누적해서 더하고 평균 구함
    return output
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------
def chop_forward(x, model, scale, shave=8, min_size=80000, nGPUs=opt.gpus): #if chop_forward = True
    b, c, h, w = x.size()
    h_half, w_half = h//2, w//2
    h_size, w_size = h_half + shave, w_half + shave   #chop 하는 size
    inputlist = [
        x[:, :, 0:h_size, 0:w_size],                       #4 방향 chop
        x[:, :, 0:h_size, (w - w_size):w],
        x[:, :, (h - h_size):h, 0:w_size],
        x[:, :, (h - h_size):h, (w - w_size):w]
    ]
    if w_size * h_size < min_size:
        outputlist = []
        for i in range(0, 4, nGPUs):
            with torch.no_grad():
                input_batch = torch.cat(inputlist[i:(i + nGPUs)], dim=0)
            if opt.self_ensemble:
                with torch.no_grad():
                    output_batch = x8_forward(input_batch, model)
            else:
                with torch.no_grad():
                    output_batch = model(input_batch)
            outputlist.extend(output_batch.chunk(nGPUs, dim=0))
    else : 
        outputlist = [
            chop_forward(patch, model, scale, shave, min_size, nGPUs)
            for patch in inputlist
        ] #회귀형 구조로 min_size 보다 작을때까지 진행시켜주며 outputlist에 추가시켜준다
        
    h, w = scale * h, scale * w
    h_half, w_half = scale * h_half, scale * w_half
    h_size, w_size = scale * h_size, scale * w_size
    shave *= scale
    
    with torch.no_grad():
        output = Variable(x.data.new(b, c, h, w))
#outputlist에 저장된 이미지들을 upscale 시킨 크기로 다시 chop해서 output에 저장(처음 x가 downscale된 상태로 들어옴)
    output[:, :, 0:h_half, 0:w_half] \
        = outputlist[0][:, :, 0:h_half, 0:w_half]
    output[:, :, 0:h_half, w_half:w] \
        = outputlist[1][:, :, 0:h_half, (w_size - w + w_half):w_size]
    output[:, :, h_half:h, 0:w_half] \
        = outputlist[2][:, :, (h_size - h + h_half):h_size, 0:w_half]
    output[:, :, h_half:h, w_half:w] \
        = outputlist[3][:, :, (h_size - h + h_half):h_size, (w_size - w + w_half):w_size]

    return output
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------    
    
if __name__ == '__main__':
    eval()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# {'testBatchSize': 1, 'self_ensemble': False, 'chop_forward': False, 'gpu_mode': True, 'threads': 1, 'seed': 123, 'gpus': 1, 'upscale_factor': 2, 'input_dir': '/content/gdrive/My Drive/study/VDSR/data/test/', 'test_dataset': 'Set5', 'output': '/content/gdrive/My Drive/study/VDSR/Results/', 'model_type': 'VDSR', 'residual': False, 'model': '/content/gdrive/My Drive/study/VDSR/weights/test02/<built-in function gethostname>_epoch_79.pth'}
# ===> Loading datasets
# ===> Building model
# Pre-trained SR model is loaded.
# ===> Processing: woman_GT.png || Timer: 0.2311 sec. PSNR : 33.9344
# ===> Processing: baby_GT.png || Timer: 0.0361 sec. PSNR : 36.8852
# ===> Processing: bird_GT.png || Timer: 0.0123 sec. PSNR : 37.9073
# ===> Processing: head_GT.png || Timer: 0.0117 sec. PSNR : 32.0754
# ===> Processing: butterfly_GT.png || Timer: 0.0103 sec. PSNR : 30.8683
# ===> Processing: Fingerprint.png || Timer: 0.0351 sec. PSNR : 32.5590
# ===> Processing: Foreman.png || Timer: 0.0094 sec. PSNR : 39.2461
# ===> Processing: Pepper.png || Timer: 0.0352 sec. PSNR : 34.6338
# ===> Processing: Lena.png || Timer: 0.0352 sec. PSNR : 36.0288
# ===> Processing: House.png || Timer: 0.0093 sec. PSNR : 34.8959
# ===> Processing Done, Average PSNR : 34.9034
# ===>PSNR Variance : 6.3864
