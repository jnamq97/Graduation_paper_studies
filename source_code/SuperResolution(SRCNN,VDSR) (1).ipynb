# %% [markdown]
# # Model

# %%
import os
import torch.nn as nn
import torch.optim as optim
from torchvision.transforms import *
import torch
import math 
from os.path import join
import torch.utils.data as data
import numpy as np
from os import listdir
from os.path import join
from PIL import Image, ImageOps
import random
from random import randrange
from math import sqrt

class ConvBlock(torch.nn.Module):
    def __init__(self, input_size, output_size, kernel_size=3, stride=1, padding=1, bias=True, activation='prelu', norm=None):
        super(ConvBlock, self).__init__()
        self.conv = torch.nn.Conv2d(input_size, output_size, kernel_size, stride, padding, bias=bias)

        self.norm = norm
        if self.norm =='batch':
            self.bn = torch.nn.BatchNorm2d(output_size)
        elif self.norm == 'instance':
            self.bn = torch.nn.InstanceNorm2d(output_size)

        self.activation = activation
        if self.activation == 'relu':
            self.act = torch.nn.ReLU(True)
        elif self.activation == 'prelu':
            self.act = torch.nn.PReLU()
        elif self.activation == 'lrelu':
            self.act = torch.nn.LeakyReLU(0.2, True)
        elif self.activation == 'tanh':
            self.act = torch.nn.Tanh()
        elif self.activation == 'sigmoid':
            self.act = torch.nn.Sigmoid()

    def forward(self, x):
        if self.norm is not None:
            out = self.bn(self.conv(x))
        else:
            out = self.conv(x)

        if self.activation is not None:
            return self.act(out)
        else:
            return out

class SRCNN(nn.Module):
    def __init__(self, num_channels, base_filter, scale_factor):
        super(SRCNN, self).__init__()

        # Initial Feature Extraction
        self.layer1 = ConvBlock(num_channels, base_filter, kernel_size=9, stride=1, padding=4, activation='relu', norm=None)
        self.layer2 = ConvBlock(base_filter, base_filter // 2, kernel_size=1, stride=1, padding=0, activation='relu', norm=None)
        self.layer3 = ConvBlock(base_filter // 2, 3, kernel_size=5, stride=1, padding=2, activation=None, norm=None)

        for m in self.modules():
            classname = m.__class__.__name__
            if classname.find('Conv2d') != -1:
                torch.nn.init.kaiming_normal_(m.weight)
                if m.bias is not None:
                    m.bias.data.zero_()
            elif classname.find('ConvTranspose2d') != -1:
                torch.nn.init.kaiming_normal_(m.weight)
                if m.bias is not None:
                    m.bias.data.zero_()

    def forward(self, x):
        f1 = self.layer1(x)
        f2 = self.layer2(f1)
        y = self.layer3(f2)

        return y

class Conv_ReLU_Block(nn.Module):
    def __init__(self):
        super(Conv_ReLU_Block, self).__init__()
        self.conv = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1, bias=False)
        self.relu = nn.ReLU(inplace=True)
        
    def forward(self, x):
        return self.relu(self.conv(x))

class VDSR(nn.Module):
    def __init__(self):
        super(VDSR, self).__init__()
        self.residual_layer = self.make_layer(Conv_ReLU_Block, 5)
        self.input = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, stride=1, padding=1, bias=False)
        self.output = nn.Conv2d(in_channels=64, out_channels=3, kernel_size=3, stride=1, padding=1, bias=False)
        self.relu = nn.ReLU(inplace=True)
    
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, sqrt(2. / n))
                
    def make_layer(self, block, num_of_layer):        
        layers = []
        for _ in range(num_of_layer):
            layers.append(block())
        return nn.Sequential(*layers)

    def forward(self, x):
        residual = x
        out = self.relu(self.input(x))
        out = self.residual_layer(out)
        out = self.output(out)
        out = torch.add(out,residual)
        return out



def is_image_file(filename):
    return any(filename.endswith(extension) for extension in [".png", ".jpg", ".jpeg",".bmp"])


def load_img(filepath):
    img = Image.open(filepath).convert('RGB')
    #y, _, _ = img.split()
    return img

def rescale_img(img_in, scale):
    size_in = img_in.size
    new_size_in = tuple([int(x * scale) for x in size_in])
    img_in = img_in.resize(new_size_in, resample=Image.BICUBIC)
    return img_in

def get_patch(img_in, img_tar, img_bic, patch_size, scale, ix=-1, iy=-1):
    (ih, iw) = img_in.size
    (th, tw) = (scale * ih, scale * iw)

    patch_mult = scale #if len(scale) > 1 else 1
    tp = patch_mult * patch_size
    ip = tp // scale

    if ix == -1:
        ix = random.randrange(0, iw - ip + 1)
    if iy == -1:
        iy = random.randrange(0, ih - ip + 1)

    (tx, ty) = (scale * ix, scale * iy)

    img_in = img_in.crop((iy,ix,iy + ip, ix + ip))
    img_tar = img_tar.crop((ty,tx,ty + tp, tx + tp))
    img_bic = img_bic.crop((ty,tx,ty + tp, tx + tp))
                
    info_patch = {
        'ix': ix, 'iy': iy, 'ip': ip, 'tx': tx, 'ty': ty, 'tp': tp}

    return img_in, img_tar, img_bic, info_patch

def augment(img_in, img_tar, img_bic, flip_h=True, rot=True):
    info_aug = {'flip_h': False, 'flip_v': False, 'trans': False}
    
    if random.random() < 0.5 and flip_h:
        img_in = ImageOps.flip(img_in)
        img_tar = ImageOps.flip(img_tar)
        img_bic = ImageOps.flip(img_bic)
        info_aug['flip_h'] = True

    if rot:
        if random.random() < 0.5:
            img_in = ImageOps.mirror(img_in)
            img_tar = ImageOps.mirror(img_tar)
            img_bic = ImageOps.mirror(img_bic)
            info_aug['flip_v'] = True
        if random.random() < 0.5:
            img_in = img_in.rotate(180)
            img_tar = img_tar.rotate(180)
            img_bic = img_bic.rotate(180)
            info_aug['trans'] = True
            
    return img_in, img_tar, img_bic, info_aug
    
class DatasetFromFolder(data.Dataset):
    def __init__(self, image_dir, patch_size, upscale_factor, data_augmentation, transform=None):
        super(DatasetFromFolder, self).__init__()
        self.image_filenames = [join(image_dir, x) for x in listdir(image_dir) if is_image_file(x)]
        self.patch_size = patch_size
        self.upscale_factor = upscale_factor
        self.transform = transform
        self.data_augmentation = data_augmentation

    def __getitem__(self, index):
        target = load_img(self.image_filenames[index])
        
        input = target.resize((int(target.size[0]/self.upscale_factor),int(target.size[1]/self.upscale_factor)), Image.BICUBIC)       
        bicubic = rescale_img(input, self.upscale_factor)
        
        input, target, bicubic, _ = get_patch(input,target,bicubic,self.patch_size, self.upscale_factor)
        
        if self.data_augmentation:
            input, target, bicubic, _ = augment(input, target, bicubic)
        
        if self.transform:
            input = self.transform(input)
            bicubic = self.transform(bicubic)
            target = self.transform(target)
                
        return input, target, bicubic

    def __len__(self):
        return len(self.image_filenames)

class DatasetFromFolderEval(data.Dataset):
    def __init__(self, lr_dir, upscale_factor, transform=None):
        super(DatasetFromFolderEval, self).__init__()
        self.image_filenames = [join(lr_dir, x) for x in listdir(lr_dir) if is_image_file(x)]
        self.upscale_factor = upscale_factor
        self.transform = transform

    def __getitem__(self, index):
        target = load_img(self.image_filenames[index])
        _, file = os.path.split(self.image_filenames[index])

        input = target.resize((int(target.size[0]/self.upscale_factor),int(target.size[1]/self.upscale_factor)), Image.BICUBIC)       
        bicubic = rescale_img(input, self.upscale_factor)
        
        if self.transform:
            input = self.transform(input)
            bicubic = self.transform(bicubic)
            target = self.transform(target)
            
        return input, bicubic, target, file
      
    def __len__(self):
        return len(self.image_filenames)


def transform():
    return Compose([
        ToTensor(),
    ])

def get_training_set(data_dir, hr, upscale_factor, patch_size, data_augmentation):
    hr_dir = join(data_dir, hr)
    return DatasetFromFolder(hr_dir,patch_size, upscale_factor, data_augmentation,
                             transform=transform())

def get_eval_set(lr_dir, upscale_factor):
    return DatasetFromFolderEval(lr_dir, upscale_factor,
                             transform=transform())

# %% [markdown]
# #Training

# %%
from __future__ import print_function
import argparse
from math import log10

import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.backends.cudnn as cudnn
from torch.autograd import Variable
from torch.utils.data import DataLoader
import pdb
import socket
import time
import easydict

from google.colab import drive
drive.mount('/content/gdrive')

opt = easydict.EasyDict({ 
    "batchSize": 32,           # batch size - 한번에 training할 patch의 숫자
    "lr": 1e-3,                # learning rate
    "upscale_factor": 2,       # Upscale 정도 - 2배, 4배
    "patch_size": 64,         # patch 크기
    "feature_number": 64,     # SRCNN model에서 사용할 feature 숫자
    
    "start_iter": 1,           
    "nEpochs": 200,            # training 횟수
    "snapshots": 20,           # weight 저장 주기
   
    "data_dir":"/content/gdrive/My Drive/study/SRCNN/data/train/", # dataset 저장 위치
    "hr_train_dataset": "DIV2K_train_HR", # training에 사용할 dataset 종류

    "model_type": "VDSR",         # 모델이름

    "save_folder": "/content/gdrive/My Drive/study/SRCNN/weights/", # weight 저장 위치
    

    "pretrained_sr": "/content/gdrive/My Drive/study/SRCNN/weights/ckpt_diff11_label",
    "pretrained": False,
    "data_augmentation": False,
    "residual": False,
    "gpu_mode": True,
    "threads": 1,
    "seed": 123,
    "gpus": 1,
    "prefix": "tpami_residual_filter8"})

gpus_list = range(opt.gpus)
hostname = str(socket.gethostname())
cudnn.benchmark = True
print(opt)

def train(epoch):
    epoch_loss = 0
    model.train()
    for iteration, batch in enumerate(training_data_loader, 1):
        _, target, bicubic = Variable(batch[0]), Variable(batch[1]), Variable(batch[2])
        if cuda:
            # input = input.cuda(gpus_list[0])
            target = target.cuda(gpus_list[0])
            bicubic = bicubic.cuda(gpus_list[0])

        optimizer.zero_grad()
        t0 = time.time()
        prediction = model(bicubic)

        if opt.residual:
            prediction = prediction + bicubic

        loss = criterion(prediction, target)
        t1 = time.time()
        epoch_loss += loss.data
        loss.backward()
        optimizer.step()

        print("===> Epoch[{}]({}/{}): Loss: {:.4f} || Timer: {:.4f} sec.".format(epoch, iteration, len(training_data_loader), loss.data, (t1 - t0)))

    print("===> Epoch {} Complete: Avg. Loss: {:.4f}".format(epoch, epoch_loss / len(training_data_loader)))

def print_network(net):
    num_params = 0
    for param in net.parameters():
        num_params += param.numel()
    print(net)
    print('Total number of parameters: %d' % num_params)

def checkpoint(epoch):
    model_out_path = opt.save_folder+hostname+"_epoch_{}.pth".format(epoch)
    torch.save(model.state_dict(), model_out_path)
    print("Checkpoint saved to {}".format(model_out_path))

if __name__ == '__main__':

    cuda = opt.gpu_mode
    if cuda and not torch.cuda.is_available():
        raise Exception("No GPU found, please run without --cuda")

    torch.manual_seed(opt.seed)
    if cuda:
        torch.cuda.manual_seed(opt.seed)

    print('===> Loading datasets')
    train_set = get_training_set(opt.data_dir, opt.hr_train_dataset, opt.upscale_factor, opt.patch_size, opt.data_augmentation)
    training_data_loader = DataLoader(dataset=train_set, num_workers=opt.threads, batch_size=opt.batchSize, shuffle=True)

    print('===> Building model ', opt.model_type)
    if opt.model_type == 'SRCNN':
        model = SRCNN(num_channels=3, base_filter=opt.feature_number, scale_factor=opt.upscale_factor)
    elif opt.model_type == 'VDSR':
        model = VDSR()
        
        model = torch.nn.DataParallel(model, device_ids=gpus_list)
    criterion = nn.L1Loss()

    if opt.pretrained:
        model_name = os.path.join(opt.save_folder + opt.pretrained_sr)
        if os.path.exists(model_name):
            #model= torch.load(model_name, map_location=lambda storage, loc: storage)
            model.load_state_dict(torch.load(model_name, map_location=lambda storage, loc: storage))
            print('Pre-trained SR model is loaded.')

    if cuda:
        model = model.cuda(gpus_list[0])
        criterion = criterion.cuda(gpus_list[0])

    optimizer = optim.Adam(model.parameters(), lr=opt.lr, betas=(0.9, 0.999), eps=1e-8)

    for epoch in range(opt.start_iter, opt.nEpochs + 1):
        train(epoch)

        # learning rate is decayed by a factor of 10 every half of total epochs
        if (epoch+1) % (opt.nEpochs/2) == 0:
            for param_group in optimizer.param_groups:
                param_group['lr'] /= 10.0
            print('Learning rate decay: lr={}'.format(optimizer.param_groups[0]['lr']))

        if (epoch+1) % (opt.snapshots) == 0:
            checkpoint(epoch)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# {'batchSize': 32, 'lr': 0.001, 'upscale_factor': 2, 'patch_size': 64, 'feature_number': 64, 'start_iter': 1, 'nEpochs': 200, 'snapshots': 20, 'data_dir': '/content/gdrive/My Drive/SRCNN/data/train/', 'hr_train_dataset': 'DIV2K_train_HR', 'model_type': 'VDSR', 'save_folder': '/content/gdrive/My Drive/SRCNN/weights/', 'pretrained_sr': '/content/gdrive/My Drive/SRCNN/weights/ckpt_diff11_label', 'pretrained': False, 'data_augmentation': False, 'residual': False, 'gpu_mode': True, 'threads': 1, 'seed': 123, 'gpus': 1, 'prefix': 'tpami_residual_filter8'}
# ===> Loading datasets
# ===> Building model  VDSR
# ===> Epoch[1](1/25): Loss: 0.5000 || Timer: 1.3301 sec.
# ===> Epoch[1](2/25): Loss: 0.1695 || Timer: 0.0045 sec.
# ===> Epoch[1](3/25): Loss: 0.1852 || Timer: 0.0039 sec.
# ===> Epoch[1](4/25): Loss: 0.0409 || Timer: 0.0052 sec.
# ===> Epoch[1](5/25): Loss: 0.0442 || Timer: 0.0039 sec.
# ===> Epoch[1](6/25): Loss: 0.0426 || Timer: 0.0052 sec.
# ===> Epoch[1](7/25): Loss: 0.0334 || Timer: 0.0045 sec.
# ===> Epoch[1](8/25): Loss: 0.0362 || Timer: 0.0044 sec.
# ===> Epoch[1](9/25): Loss: 0.0245 || Timer: 0.0036 sec.
# ===> Epoch[1](10/25): Loss: 0.0260 || Timer: 0.0043 sec.
# ===> Epoch[1](11/25): Loss: 0.0237 || Timer: 0.0040 sec.
# ===> Epoch[1](12/25): Loss: 0.0266 || Timer: 0.0037 sec.
# ===> Epoch[1](13/25): Loss: 0.0259 || Timer: 0.0097 sec.
# ===> Epoch[1](14/25): Loss: 0.0210 || Timer: 0.0049 sec.
# ===> Epoch[1](15/25): Loss: 0.0232 || Timer: 0.0040 sec.
# ===> Epoch[1](16/25): Loss: 0.0236 || Timer: 0.0042 sec.
# ===> Epoch[1](17/25): Loss: 0.0172 || Timer: 0.0038 sec.
# ===> Epoch[1](18/25): Loss: 0.0176 || Timer: 0.0053 sec.
# ===> Epoch[1](19/25): Loss: 0.0260 || Timer: 0.0111 sec.
# ===> Epoch[1](20/25): Loss: 0.0193 || Timer: 0.0048 sec.
# ===> Epoch[1](21/25): Loss: 0.0190 || Timer: 0.0039 sec.
# ===> Epoch[1](22/25): Loss: 0.0187 || Timer: 0.0044 sec.
# ===> Epoch[1](23/25): Loss: 0.0183 || Timer: 0.0038 sec.
# ===> Epoch[1](24/25): Loss: 0.0171 || Timer: 0.0043 sec.
# ===> Epoch[1](25/25): Loss: 0.0241 || Timer: 0.0028 sec.
# ===> Epoch 1 Complete: Avg. Loss: 0.0570
# ===> Epoch[2](1/25): Loss: 0.0187 || Timer: 0.0060 sec.
# ===> Epoch[2](2/25): Loss: 0.0174 || Timer: 0.0032 sec.
# ===> Epoch[2](3/25): Loss: 0.0227 || Timer: 0.0039 sec.
# ===> Epoch[2](4/25): Loss: 0.0195 || Timer: 0.0040 sec.
# ===> Epoch[2](5/25): Loss: 0.0197 || Timer: 0.0040 sec.
# ===> Epoch[2](6/25): Loss: 0.0197 || Timer: 0.0042 sec.
# ===> Epoch[2](7/25): Loss: 0.0167 || Timer: 0.0040 sec.
# ===> Epoch[2](8/25): Loss: 0.0156 || Timer: 0.0039 sec.
# ===> Epoch[2](9/25): Loss: 0.0177 || Timer: 0.0046 sec.
# ===> Epoch[2](10/25): Loss: 0.0192 || Timer: 0.0040 sec.
# ===> Epoch[2](11/25): Loss: 0.0145 || Timer: 0.0026 sec.
# ===> Epoch[2](12/25): Loss: 0.0214 || Timer: 0.0040 sec.
# ===> Epoch[2](13/25): Loss: 0.0197 || Timer: 0.0040 sec.
# ===> Epoch[2](14/25): Loss: 0.0186 || Timer: 0.0041 sec.
# ===> Epoch[2](15/25): Loss: 0.0163 || Timer: 0.0037 sec.
# ===> Epoch[2](16/25): Loss: 0.0201 || Timer: 0.0040 sec.
# ===> Epoch[2](17/25): Loss: 0.0221 || Timer: 0.0039 sec.
# ===> Epoch[2](18/25): Loss: 0.0206 || Timer: 0.0039 sec.
# ===> Epoch[2](19/25): Loss: 0.0129 || Timer: 0.0039 sec.
# ===> Epoch[2](20/25): Loss: 0.0177 || Timer: 0.0045 sec.
# ===> Epoch[2](21/25): Loss: 0.0173 || Timer: 0.0039 sec.
# ===> Epoch[2](22/25): Loss: 0.0151 || Timer: 0.0041 sec.
# ===> Epoch[2](23/25): Loss: 0.0209 || Timer: 0.0045 sec.
# ===> Epoch[2](24/25): Loss: 0.0178 || Timer: 0.0081 sec.
# ===> Epoch[2](25/25): Loss: 0.0147 || Timer: 0.0026 sec.
# ===> Epoch 2 Complete: Avg. Loss: 0.0183
# ===> Epoch[3](1/25): Loss: 0.0167 || Timer: 0.0050 sec.
# ===> Epoch[3](2/25): Loss: 0.0208 || Timer: 0.0041 sec.
# ===> Epoch[3](3/25): Loss: 0.0193 || Timer: 0.0038 sec.
# ===> Epoch[3](4/25): Loss: 0.0186 || Timer: 0.0040 sec.
# ===> Epoch[3](5/25): Loss: 0.0182 || Timer: 0.0038 sec.
# ===> Epoch[3](6/25): Loss: 0.0178 || Timer: 0.0040 sec.
# ===> Epoch[3](7/25): Loss: 0.0159 || Timer: 0.0041 sec.
# ===> Epoch[3](8/25): Loss: 0.0186 || Timer: 0.0105 sec.
# ===> Epoch[3](9/25): Loss: 0.0168 || Timer: 0.0045 sec.
# ===> Epoch[3](10/25): Loss: 0.0213 || Timer: 0.0041 sec.
# ===> Epoch[3](11/25): Loss: 0.0140 || Timer: 0.0041 sec.
# ===> Epoch[3](12/25): Loss: 0.0159 || Timer: 0.0041 sec.
# ===> Epoch[3](13/25): Loss: 0.0188 || Timer: 0.0037 sec.
# ===> Epoch[3](14/25): Loss: 0.0174 || Timer: 0.0039 sec.
# ===> Epoch[3](15/25): Loss: 0.0230 || Timer: 0.0036 sec.
# ===> Epoch[3](16/25): Loss: 0.0155 || Timer: 0.0049 sec.
# ===> Epoch[3](17/25): Loss: 0.0191 || Timer: 0.0043 sec.
# ===> Epoch[3](18/25): Loss: 0.0221 || Timer: 0.0040 sec.
# ===> Epoch[3](19/25): Loss: 0.0132 || Timer: 0.0039 sec.
# ===> Epoch[3](20/25): Loss: 0.0214 || Timer: 0.0041 sec.
# ===> Epoch[3](21/25): Loss: 0.0170 || Timer: 0.0038 sec.
# ===> Epoch[3](22/25): Loss: 0.0185 || Timer: 0.0030 sec.
# ===> Epoch[3](23/25): Loss: 0.0173 || Timer: 0.0040 sec.
# ===> Epoch[3](24/25): Loss: 0.0249 || Timer: 0.0038 sec.
# ===> Epoch[3](25/25): Loss: 0.0250 || Timer: 0.0045 sec.
# ===> Epoch 3 Complete: Avg. Loss: 0.0187
# ===> Epoch[4](1/25): Loss: 0.0194 || Timer: 0.0048 sec.
# ===> Epoch[4](2/25): Loss: 0.0159 || Timer: 0.0044 sec.
# ===> Epoch[4](3/25): Loss: 0.0240 || Timer: 0.0036 sec.
# ===> Epoch[4](4/25): Loss: 0.0172 || Timer: 0.0046 sec.
# ===> Epoch[4](5/25): Loss: 0.0201 || Timer: 0.0039 sec.
# ===> Epoch[4](6/25): Loss: 0.0206 || Timer: 0.0039 sec.
# ===> Epoch[4](7/25): Loss: 0.0195 || Timer: 0.0040 sec.
# ===> Epoch[4](8/25): Loss: 0.0178 || Timer: 0.0040 sec.
# ===> Epoch[4](9/25): Loss: 0.0154 || Timer: 0.0038 sec.
# ===> Epoch[4](10/25): Loss: 0.0214 || Timer: 0.0041 sec.
# ===> Epoch[4](11/25): Loss: 0.0148 || Timer: 0.0037 sec.
# ===> Epoch[4](12/25): Loss: 0.0176 || Timer: 0.0042 sec.
# ===> Epoch[4](13/25): Loss: 0.0218 || Timer: 0.0041 sec.
# ===> Epoch 5 Complete: Avg. Loss: 0.0173
# ===> Epoch[6](1/25): Loss: 0.0166 || Timer: 0.0053 sec.
# ===> Epoch[6](2/25): Loss: 0.0178 || Timer: 0.0037 sec.
# ===> Epoch[6](3/25): Loss: 0.0176 || Timer: 0.0038 sec.
# ===> Epoch[6](4/25): Loss: 0.0196 || Timer: 0.0040 sec.
# ===> Epoch[6](5/25): Loss: 0.0192 || Timer: 0.0041 sec.
# ===> Epoch[6](6/25): Loss: 0.0137 || Timer: 0.0038 sec.
# ===> Epoch[6](7/25): Loss: 0.0214 || Timer: 0.0036 sec.
# ===> Epoch[6](8/25): Loss: 0.0141 || Timer: 0.0040 sec.
# ===> Epoch[6](9/25): Loss: 0.0126 || Timer: 0.0041 sec.
# ===> Epoch[6](10/25): Loss: 0.0177 || Timer: 0.0039 sec.
# ===> Epoch[6](11/25): Loss: 0.0131 || Timer: 0.0038 sec.
# ===> Epoch[6](12/25): Loss: 0.0189 || Timer: 0.0029 sec.
# ===> Epoch[6](13/25): Loss: 0.0172 || Timer: 0.0039 sec.
# ===> Epoch[6](14/25): Loss: 0.0155 || Timer: 0.0038 sec.
# ===> Epoch[6](15/25): Loss: 0.0156 || Timer: 0.0037 sec.
# ===> Epoch[6](16/25): Loss: 0.0132 || Timer: 0.0043 sec.
# ===> Epoch[6](17/25): Loss: 0.0189 || Timer: 0.0038 sec.
# ===> Epoch[6](18/25): Loss: 0.0214 || Timer: 0.0057 sec.
# ===> Epoch[6](19/25): Loss: 0.0210 || Timer: 0.0038 sec.
# ===> Epoch[6](20/25): Loss: 0.0147 || Timer: 0.0039 sec.
# ===> Epoch[6](21/25): Loss: 0.0169 || Timer: 0.0040 sec.
# ===> Epoch[6](22/25): Loss: 0.0146 || Timer: 0.0038 sec.
# ===> Epoch[6](23/25): Loss: 0.0209 || Timer: 0.0040 sec.
# ===> Epoch[6](24/25): Loss: 0.0150 || Timer: 0.0052 sec.
# ===> Epoch[6](25/25): Loss: 0.0142 || Timer: 0.0026 sec.
# ===> Epoch 6 Complete: Avg. Loss: 0.0169
# ===> Epoch[7](1/25): Loss: 0.0152 || Timer: 0.0056 sec.
# ===> Epoch[7](2/25): Loss: 0.0182 || Timer: 0.0066 sec.
# ===> Epoch[7](3/25): Loss: 0.0149 || Timer: 0.0029 sec.
# ===> Epoch[7](4/25): Loss: 0.0175 || Timer: 0.0036 sec.
# ===> Epoch[7](5/25): Loss: 0.0179 || Timer: 0.0037 sec.
# ===> Epoch[7](6/25): Loss: 0.0180 || Timer: 0.0042 sec.
# ===> Epoch[7](7/25): Loss: 0.0119 || Timer: 0.0039 sec.
# ===> Epoch[7](8/25): Loss: 0.0170 || Timer: 0.0041 sec.
# ===> Epoch[7](9/25): Loss: 0.0198 || Timer: 0.0045 sec.
# ===> Epoch[7](10/25): Loss: 0.0168 || Timer: 0.0040 sec.
# ===> Epoch[7](11/25): Loss: 0.0206 || Timer: 0.0035 sec.
# ===> Epoch[7](12/25): Loss: 0.0152 || Timer: 0.0035 sec.
# ===> Epoch[7](13/25): Loss: 0.0171 || Timer: 0.0044 sec.
# ===> Epoch[7](14/25): Loss: 0.0156 || Timer: 0.0045 sec.
# ===> Epoch[7](15/25): Loss: 0.0209 || Timer: 0.0039 sec.
# ===> Epoch[7](16/25): Loss: 0.0203 || Timer: 0.0044 sec.
# ===> Epoch[7](17/25): Loss: 0.0181 || Timer: 0.0040 sec.
# ===> Epoch[7](18/25): Loss: 0.0153 || Timer: 0.0040 sec.
# ===> Epoch[7](19/25): Loss: 0.0181 || Timer: 0.0040 sec.
# ===> Epoch[7](20/25): Loss: 0.0128 || Timer: 0.0039 sec.
# ===> Epoch[7](21/25): Loss: 0.0211 || Timer: 0.0039 sec.
# ===> Epoch[7](22/25): Loss: 0.0152 || Timer: 0.0037 sec.
# ===> Epoch[7](23/25): Loss: 0.0147 || Timer: 0.0039 sec.
# ===> Epoch[7](24/25): Loss: 0.0194 || Timer: 0.0042 sec.
# ===> Epoch[7](25/25): Loss: 0.0149 || Timer: 0.0027 sec.
# ===> Epoch 7 Complete: Avg. Loss: 0.0171
# ===> Epoch[8](1/25): Loss: 0.0171 || Timer: 0.0051 sec.
# ===> Epoch[8](2/25): Loss: 0.0133 || Timer: 0.0040 sec.
# ===> Epoch[8](3/25): Loss: 0.0171 || Timer: 0.0041 sec.
# ===> Epoch[8](4/25): Loss: 0.0187 || Timer: 0.0046 sec.
# ===> Epoch[8](5/25): Loss: 0.0169 || Timer: 0.0040 sec.
# ===> Epoch[8](6/25): Loss: 0.0149 || Timer: 0.0039 sec.
# ===> Epoch[8](7/25): Loss: 0.0162 || Timer: 0.0040 sec.
# ===> Epoch[8](8/25): Loss: 0.0191 || Timer: 0.0164 sec.
# ===> Epoch[8](9/25): Loss: 0.0222 || Timer: 0.0041 sec.
# ===> Epoch[8](10/25): Loss: 0.0165 || Timer: 0.0043 sec.
# ===> Epoch[8](11/25): Loss: 0.0129 || Timer: 0.0044 sec.
# ===> Epoch[8](12/25): Loss: 0.0166 || Timer: 0.0039 sec.
# ===> Epoch[8](13/25): Loss: 0.0132 || Timer: 0.0033 sec.
# ===> Epoch[8](14/25): Loss: 0.0147 || Timer: 0.0043 sec.
# ===> Epoch[8](15/25): Loss: 0.0179 || Timer: 0.0058 sec.
# ===> Epoch[8](16/25): Loss: 0.0168 || Timer: 0.0040 sec.
# ===> Epoch[8](17/25): Loss: 0.0144 || Timer: 0.0041 sec.
# ===> Epoch[8](18/25): Loss: 0.0179 || Timer: 0.0136 sec.
# ===> Epoch[8](19/25): Loss: 0.0138 || Timer: 0.0032 sec.
# ===> Epoch[8](20/25): Loss: 0.0142 || Timer: 0.0038 sec.
# ===> Epoch[8](21/25): Loss: 0.0170 || Timer: 0.0039 sec.
# ===> Epoch[8](22/25): Loss: 0.0228 || Timer: 0.0040 sec.
# ===> Epoch[8](23/25): Loss: 0.0204 || Timer: 0.0038 sec.
# ===> Epoch[8](24/25): Loss: 0.0139 || Timer: 0.0037 sec.
# ===> Epoch[8](25/25): Loss: 0.0156 || Timer: 0.0025 sec.
# ===> Epoch 8 Complete: Avg. Loss: 0.0166
# ===> Epoch[9](1/25): Loss: 0.0160 || Timer: 0.0051 sec.
# ===> Epoch[9](2/25): Loss: 0.0209 || Timer: 0.0042 sec.
# ===> Epoch[9](3/25): Loss: 0.0177 || Timer: 0.0028 sec.
# ===> Epoch[9](4/25): Loss: 0.0185 || Timer: 0.0058 sec.
# ===> Epoch[9](5/25): Loss: 0.0210 || Timer: 0.0042 sec.
# ===> Epoch[9](6/25): Loss: 0.0143 || Timer: 0.0039 sec.
# ===> Epoch[9](7/25): Loss: 0.0169 || Timer: 0.0040 sec.
# ===> Epoch[9](8/25): Loss: 0.0176 || Timer: 0.0041 sec.
# ===> Epoch[9](9/25): Loss: 0.0155 || Timer: 0.0038 sec.
# ===> Epoch[9](10/25): Loss: 0.0149 || Timer: 0.0040 sec.
# ===> Epoch[9](11/25): Loss: 0.0148 || Timer: 0.0040 sec.
# ===> Epoch[9](12/25): Loss: 0.0184 || Timer: 0.0039 sec.
# ===> Epoch[9](13/25): Loss: 0.0149 || Timer: 0.0029 sec.
# ===> Epoch[9](14/25): Loss: 0.0201 || Timer: 0.0048 sec.
# ===> Epoch[9](15/25): Loss: 0.0157 || Timer: 0.0039 sec.
# ===> Epoch[9](16/25): Loss: 0.0156 || Timer: 0.0041 sec.
# ===> Epoch[9](17/25): Loss: 0.0140 || Timer: 0.0041 sec.
# ===> Epoch[9](18/25): Loss: 0.0174 || Timer: 0.0044 sec.
# ===> Epoch[9](19/25): Loss: 0.0191 || Timer: 0.0032 sec.
# ===> Epoch[9](20/25): Loss: 0.0203 || Timer: 0.0042 sec.
# ===> Epoch[9](21/25): Loss: 0.0190 || Timer: 0.0038 sec.
# ===> Epoch[9](22/25): Loss: 0.0165 || Timer: 0.0039 sec.
# ===> Epoch[9](23/25): Loss: 0.0199 || Timer: 0.0036 sec.
# ===> Epoch[9](24/25): Loss: 0.0158 || Timer: 0.0037 sec.
# ===> Epoch[9](25/25): Loss: 0.0131 || Timer: 0.0024 sec.
# ===> Epoch 9 Complete: Avg. Loss: 0.0171
# ===> Epoch[10](1/25): Loss: 0.0173 || Timer: 0.0052 sec.
# ===> Epoch[10](2/25): Loss: 0.0135 || Timer: 0.0040 sec.
# ===> Epoch[10](3/25): Loss: 0.0168 || Timer: 0.0042 sec.
# ===> Epoch[10](4/25): Loss: 0.0137 || Timer: 0.0040 sec.
# ===> Epoch[10](5/25): Loss: 0.0153 || Timer: 0.0038 sec.
# ===> Epoch[10](6/25): Loss: 0.0205 || Timer: 0.0037 sec.
# ===> Epoch[10](7/25): Loss: 0.0167 || Timer: 0.0039 sec.
# ===> Epoch[10](8/25): Loss: 0.0159 || Timer: 0.0041 sec.
# ===> Epoch[10](9/25): Loss: 0.0175 || Timer: 0.0039 sec.
# ===> Epoch[10](10/25): Loss: 0.0181 || Timer: 0.0040 sec.
# ===> Epoch[10](11/25): Loss: 0.0165 || Timer: 0.0038 sec.
# ===> Epoch[10](12/25): Loss: 0.0160 || Timer: 0.0038 sec.
# ===> Epoch[10](13/25): Loss: 0.0213 || Timer: 0.0048 sec.
# ===> Epoch[10](14/25): Loss: 0.0111 || Timer: 0.0039 sec.
# ===> Epoch[10](15/25): Loss: 0.0135 || Timer: 0.0030 sec.
# ===> Epoch[10](16/25): Loss: 0.0131 || Timer: 0.0049 sec.
# ===> Epoch[10](17/25): Loss: 0.0167 || Timer: 0.0037 sec.
# ===> Epoch[10](18/25): Loss: 0.0145 || Timer: 0.0037 sec.
# ===> Epoch[10](19/25): Loss: 0.0177 || Timer: 0.0042 sec.
# ===> Epoch[10](20/25): Loss: 0.0239 || Timer: 0.0037 sec.
# ===> Epoch[10](21/25): Loss: 0.0145 || Timer: 0.0042 sec.
# ===> Epoch[10](22/25): Loss: 0.0161 || Timer: 0.0038 sec.
# ===> Epoch[10](23/25): Loss: 0.0151 || Timer: 0.0036 sec.
# ===> Epoch[10](24/25): Loss: 0.0156 || Timer: 0.0043 sec.
# ===> Epoch[10](25/25): Loss: 0.0161 || Timer: 0.0027 sec.
# ===> Epoch 10 Complete: Avg. Loss: 0.0163
# ===> Epoch[11](1/25): Loss: 0.0148 || Timer: 0.0052 sec.
# ===> Epoch[11](2/25): Loss: 0.0161 || Timer: 0.0039 sec.
# ===> Epoch[11](3/25): Loss: 0.0159 || Timer: 0.0037 sec.
# ===> Epoch[11](4/25): Loss: 0.0157 || Timer: 0.0038 sec.
# ===> Epoch[11](5/25): Loss: 0.0169 || Timer: 0.0040 sec.
# ===> Epoch[11](6/25): Loss: 0.0169 || Timer: 0.0049 sec.
# ===> Epoch[11](7/25): Loss: 0.0186 || Timer: 0.0045 sec.
# ===> Epoch[11](8/25): Loss: 0.0181 || Timer: 0.0039 sec.
# ===> Epoch[11](9/25): Loss: 0.0172 || Timer: 0.0039 sec.
# ===> Epoch[11](10/25): Loss: 0.0187 || Timer: 0.0034 sec.
# ===> Epoch[11](11/25): Loss: 0.0155 || Timer: 0.0037 sec.
# ===> Epoch[11](12/25): Loss: 0.0138 || Timer: 0.0046 sec.
# ===> Epoch[11](13/25): Loss: 0.0139 || Timer: 0.0058 sec.
# ===> Epoch[11](14/25): Loss: 0.0165 || Timer: 0.0037 sec.
# ===> Epoch[11](15/25): Loss: 0.0165 || Timer: 0.0041 sec.
# ===> Epoch[11](16/25): Loss: 0.0188 || Timer: 0.0039 sec.
# ===> Epoch[11](17/25): Loss: 0.0122 || Timer: 0.0039 sec.
# ===> Epoch[11](18/25): Loss: 0.0179 || Timer: 0.0039 sec.
# ===> Epoch[11](19/25): Loss: 0.0155 || Timer: 0.0038 sec.
# ===> Epoch[11](20/25): Loss: 0.0127 || Timer: 0.0039 sec.
# ===> Epoch[11](21/25): Loss: 0.0145 || Timer: 0.0078 sec.
# ===> Epoch[11](22/25): Loss: 0.0153 || Timer: 0.0044 sec.
# ===> Epoch[11](23/25): Loss: 0.0175 || Timer: 0.0038 sec.
# ===> Epoch[11](24/25): Loss: 0.0115 || Timer: 0.0038 sec.
# ===> Epoch[11](25/25): Loss: 0.0209 || Timer: 0.0026 sec.
# ===> Epoch 11 Complete: Avg. Loss: 0.0161
# ===> Epoch[12](1/25): Loss: 0.0198 || Timer: 0.0052 sec.
# ===> Epoch[12](2/25): Loss: 0.0169 || Timer: 0.0041 sec.
# ===> Epoch[12](3/25): Loss: 0.0134 || Timer: 0.0040 sec.
# ===> Epoch[12](4/25): Loss: 0.0152 || Timer: 0.0078 sec.
# ===> Epoch[12](5/25): Loss: 0.0159 || Timer: 0.0038 sec.
# ===> Epoch[12](6/25): Loss: 0.0139 || Timer: 0.0037 sec.
# ===> Epoch[12](7/25): Loss: 0.0177 || Timer: 0.0041 sec.
# ===> Epoch[12](8/25): Loss: 0.0151 || Timer: 0.0036 sec.
# ===> Epoch[12](9/25): Loss: 0.0168 || Timer: 0.0038 sec.
# ===> Epoch[12](10/25): Loss: 0.0159 || Timer: 0.0040 sec.
# ===> Epoch[12](11/25): Loss: 0.0144 || Timer: 0.0036 sec.
# ===> Epoch[12](12/25): Loss: 0.0156 || Timer: 0.0038 sec.
# ===> Epoch[12](13/25): Loss: 0.0191 || Timer: 0.0038 sec.
# ===> Epoch[12](14/25): Loss: 0.0165 || Timer: 0.0035 sec.
# ===> Epoch[12](15/25): Loss: 0.0202 || Timer: 0.0040 sec.
# ===> Epoch[12](16/25): Loss: 0.0126 || Timer: 0.0038 sec.
# ===> Epoch[12](17/25): Loss: 0.0166 || Timer: 0.0036 sec.
# ===> Epoch[12](18/25): Loss: 0.0130 || Timer: 0.0038 sec.
# ===> Epoch[12](19/25): Loss: 0.0209 || Timer: 0.0040 sec.
# ===> Epoch[12](20/25): Loss: 0.0159 || Timer: 0.0052 sec.
# ===> Epoch[12](21/25): Loss: 0.0159 || Timer: 0.0039 sec.
# ===> Epoch[12](22/25): Loss: 0.0148 || Timer: 0.0072 sec.
# ===> Epoch[12](23/25): Loss: 0.0141 || Timer: 0.0038 sec.
# ===> Epoch[12](24/25): Loss: 0.0145 || Timer: 0.0039 sec.
# ===> Epoch[12](25/25): Loss: 0.0207 || Timer: 0.0026 sec.
# ===> Epoch 12 Complete: Avg. Loss: 0.0162
# ===> Epoch[13](1/25): Loss: 0.0150 || Timer: 0.0054 sec.
# ===> Epoch[13](2/25): Loss: 0.0153 || Timer: 0.0039 sec.
# ===> Epoch[13](3/25): Loss: 0.0147 || Timer: 0.0037 sec.
# ===> Epoch[13](4/25): Loss: 0.0150 || Timer: 0.0038 sec.
# ===> Epoch[13](5/25): Loss: 0.0169 || Timer: 0.0039 sec.
# ===> Epoch[13](6/25): Loss: 0.0182 || Timer: 0.0038 sec.
# ===> Epoch[13](7/25): Loss: 0.0112 || Timer: 0.0040 sec.
# ===> Epoch[13](8/25): Loss: 0.0179 || Timer: 0.0042 sec.
# ===> Epoch[13](9/25): Loss: 0.0175 || Timer: 0.0040 sec.
# ===> Epoch[13](10/25): Loss: 0.0177 || Timer: 0.0037 sec.
# ===> Epoch[13](11/25): Loss: 0.0233 || Timer: 0.0039 sec.
# ===> Epoch[13](12/25): Loss: 0.0179 || Timer: 0.0038 sec.
# ===> Epoch[13](13/25): Loss: 0.0182 || Timer: 0.0040 sec.
# ===> Epoch[13](14/25): Loss: 0.0214 || Timer: 0.0035 sec.
# ===> Epoch[13](15/25): Loss: 0.0199 || Timer: 0.0039 sec.
# ===> Epoch[13](16/25): Loss: 0.0137 || Timer: 0.0040 sec.
# ===> Epoch[13](17/25): Loss: 0.0133 || Timer: 0.0040 sec.
# ===> Epoch[13](18/25): Loss: 0.0193 || Timer: 0.0037 sec.
# ===> Epoch[13](19/25): Loss: 0.0143 || Timer: 0.0028 sec.
# ===> Epoch[18](8/25): Loss: 0.0259 || Timer: 0.0041 sec.
# ===> Epoch[18](9/25): Loss: 0.0173 || Timer: 0.0040 sec.
# ===> Epoch[18](10/25): Loss: 0.0166 || Timer: 0.0042 sec.
# ===> Epoch[18](11/25): Loss: 0.0160 || Timer: 0.0043 sec.
# ===> Epoch[18](12/25): Loss: 0.0133 || Timer: 0.0038 sec.
# ===> Epoch[18](13/25): Loss: 0.0179 || Timer: 0.0037 sec.
# ===> Epoch[18](14/25): Loss: 0.0138 || Timer: 0.0057 sec.
# ===> Epoch[18](15/25): Loss: 0.0135 || Timer: 0.0039 sec.
# ===> Epoch[18](16/25): Loss: 0.0167 || Timer: 0.0039 sec.
# ===> Epoch[18](17/25): Loss: 0.0188 || Timer: 0.0029 sec.
# ===> Epoch[18](18/25): Loss: 0.0140 || Timer: 0.0072 sec.
# ===> Epoch[18](19/25): Loss: 0.0199 || Timer: 0.0028 sec.
# ===> Epoch[18](20/25): Loss: 0.0131 || Timer: 0.0041 sec.
# ===> Epoch[18](21/25): Loss: 0.0150 || Timer: 0.0036 sec.
# ===> Epoch[18](22/25): Loss: 0.0162 || Timer: 0.0039 sec.
# ===> Epoch[18](23/25): Loss: 0.0149 || Timer: 0.0038 sec.
# ===> Epoch[18](24/25): Loss: 0.0147 || Timer: 0.0037 sec.
# ===> Epoch[18](25/25): Loss: 0.0161 || Timer: 0.0027 sec.
# ===> Epoch 18 Complete: Avg. Loss: 0.0161
# ===> Epoch[19](1/25): Loss: 0.0152 || Timer: 0.0096 sec.
# ===> Epoch[19](2/25): Loss: 0.0149 || Timer: 0.0042 sec.
# ===> Epoch[19](3/25): Loss: 0.0148 || Timer: 0.0039 sec.
# ===> Epoch[19](4/25): Loss: 0.0166 || Timer: 0.0035 sec.
# ===> Epoch[19](5/25): Loss: 0.0155 || Timer: 0.0045 sec.
# ===> Epoch[19](6/25): Loss: 0.0208 || Timer: 0.0036 sec.
# ===> Epoch[19](7/25): Loss: 0.0130 || Timer: 0.0037 sec.
# ===> Epoch[19](8/25): Loss: 0.0168 || Timer: 0.0038 sec.
# ===> Epoch[19](9/25): Loss: 0.0160 || Timer: 0.0038 sec.
# ===> Epoch[19](10/25): Loss: 0.0155 || Timer: 0.0036 sec.
# ===> Epoch[19](11/25): Loss: 0.0166 || Timer: 0.0038 sec.
# ===> Epoch[19](12/25): Loss: 0.0166 || Timer: 0.0036 sec.
# ===> Epoch[19](13/25): Loss: 0.0163 || Timer: 0.0045 sec.
# ===> Epoch[19](14/25): Loss: 0.0157 || Timer: 0.0036 sec.
# ===> Epoch[19](15/25): Loss: 0.0166 || Timer: 0.0038 sec.
# ===> Epoch[19](16/25): Loss: 0.0145 || Timer: 0.0036 sec.
# ===> Epoch[19](17/25): Loss: 0.0144 || Timer: 0.0037 sec.
# ===> Epoch[19](18/25): Loss: 0.0184 || Timer: 0.0038 sec.
# ===> Epoch[19](19/25): Loss: 0.0126 || Timer: 0.0038 sec.
# ===> Epoch[19](20/25): Loss: 0.0141 || Timer: 0.0037 sec.
# ===> Epoch[19](21/25): Loss: 0.0182 || Timer: 0.0037 sec.
# ===> Epoch[19](22/25): Loss: 0.0109 || Timer: 0.0041 sec.
# ===> Epoch[19](23/25): Loss: 0.0144 || Timer: 0.0037 sec.
# ===> Epoch[19](24/25): Loss: 0.0136 || Timer: 0.0042 sec.
# ===> Epoch[19](25/25): Loss: 0.0135 || Timer: 0.0026 sec.
# ===> Epoch 19 Complete: Avg. Loss: 0.0154
# Checkpoint saved to /content/gdrive/My Drive/SRCNN/weights/ac040091dff2_epoch_19.pth
# ===> Epoch[20](1/25): Loss: 0.0146 || Timer: 0.0053 sec.
# ===> Epoch[20](2/25): Loss: 0.0193 || Timer: 0.0042 sec.
# ===> Epoch[20](3/25): Loss: 0.0190 || Timer: 0.0042 sec.
# ===> Epoch[20](4/25): Loss: 0.0160 || Timer: 0.0041 sec.
# ===> Epoch[20](5/25): Loss: 0.0126 || Timer: 0.0038 sec.
# ===> Epoch[20](6/25): Loss: 0.0205 || Timer: 0.0043 sec.
# ===> Epoch[20](7/25): Loss: 0.0148 || Timer: 0.0040 sec.
# ===> Epoch[20](8/25): Loss: 0.0150 || Timer: 0.0051 sec.
# ===> Epoch[20](9/25): Loss: 0.0165 || Timer: 0.0039 sec.
# ===> Epoch[20](10/25): Loss: 0.0146 || Timer: 0.0031 sec.
# ===> Epoch[20](11/25): Loss: 0.0160 || Timer: 0.0037 sec.
# ===> Epoch[20](12/25): Loss: 0.0135 || Timer: 0.0039 sec.
# ===> Epoch[20](13/25): Loss: 0.0161 || Timer: 0.0038 sec.
# ===> Epoch[20](14/25): Loss: 0.0161 || Timer: 0.0037 sec.
# ===> Epoch[20](15/25): Loss: 0.0130 || Timer: 0.0035 sec.
# ===> Epoch[20](16/25): Loss: 0.0156 || Timer: 0.0036 sec.
# ===> Epoch[20](17/25): Loss: 0.0150 || Timer: 0.0038 sec.
# ===> Epoch[20](18/25): Loss: 0.0189 || Timer: 0.0038 sec.
# ===> Epoch[20](19/25): Loss: 0.0203 || Timer: 0.0041 sec.
# ===> Epoch[20](20/25): Loss: 0.0170 || Timer: 0.0047 sec.
# ===> Epoch[20](21/25): Loss: 0.0184 || Timer: 0.0041 sec.
# ===> Epoch[20](22/25): Loss: 0.0163 || Timer: 0.0037 sec.
# ===> Epoch[20](23/25): Loss: 0.0174 || Timer: 0.0037 sec.
# ===> Epoch[20](24/25): Loss: 0.0144 || Timer: 0.0039 sec.
# ===> Epoch[20](25/25): Loss: 0.0142 || Timer: 0.0025 sec.
# ===> Epoch 20 Complete: Avg. Loss: 0.0162
# ===> Epoch[21](1/25): Loss: 0.0178 || Timer: 0.0054 sec.
# ===> Epoch[21](2/25): Loss: 0.0148 || Timer: 0.0037 sec.
# ===> Epoch[21](3/25): Loss: 0.0136 || Timer: 0.0041 sec.
# ===> Epoch[21](4/25): Loss: 0.0200 || Timer: 0.0040 sec.
# ===> Epoch[21](5/25): Loss: 0.0155 || Timer: 0.0041 sec.
# ===> Epoch[21](6/25): Loss: 0.0134 || Timer: 0.0038 sec.
# ===> Epoch[22](21/25): Loss: 0.0155 || Timer: 0.0036 sec.
# ===> Epoch[22](22/25): Loss: 0.0217 || Timer: 0.0037 sec.
# ===> Epoch[22](23/25): Loss: 0.0174 || Timer: 0.0037 sec.
# ===> Epoch[22](24/25): Loss: 0.0169 || Timer: 0.0048 sec.
# ===> Epoch[22](25/25): Loss: 0.0143 || Timer: 0.0027 sec.
# ===> Epoch 22 Complete: Avg. Loss: 0.0158
# ===> Epoch[23](1/25): Loss: 0.0178 || Timer: 0.0050 sec.
# ===> Epoch[23](2/25): Loss: 0.0135 || Timer: 0.0039 sec.
# ===> Epoch[23](3/25): Loss: 0.0216 || Timer: 0.0037 sec.
# ===> Epoch[23](4/25): Loss: 0.0152 || Timer: 0.0036 sec.
# ===> Epoch[23](5/25): Loss: 0.0128 || Timer: 0.0039 sec.
# ===> Epoch[23](6/25): Loss: 0.0137 || Timer: 0.0037 sec.
# ===> Epoch[23](7/25): Loss: 0.0145 || Timer: 0.0038 sec.
# ===> Epoch[23](8/25): Loss: 0.0162 || Timer: 0.0038 sec.
# ===> Epoch[23](9/25): Loss: 0.0170 || Timer: 0.0039 sec.
# ===> Epoch[23](10/25): Loss: 0.0165 || Timer: 0.0039 sec.
# ===> Epoch[23](11/25): Loss: 0.0195 || Timer: 0.0036 sec.
# ===> Epoch[23](12/25): Loss: 0.0155 || Timer: 0.0037 sec.
# ===> Epoch[23](13/25): Loss: 0.0158 || Timer: 0.0037 sec.
# ===> Epoch[23](14/25): Loss: 0.0150 || Timer: 0.0046 sec.
# ===> Epoch[23](15/25): Loss: 0.0119 || Timer: 0.0037 sec.
# ===> Epoch[23](16/25): Loss: 0.0165 || Timer: 0.0042 sec.
# ===> Epoch[23](17/25): Loss: 0.0118 || Timer: 0.0042 sec.
# ===> Epoch[23](18/25): Loss: 0.0146 || Timer: 0.0042 sec.
# ===> Epoch[23](19/25): Loss: 0.0177 || Timer: 0.0036 sec.
# ===> Epoch[23](20/25): Loss: 0.0160 || Timer: 0.0040 sec.
# ===> Epoch[23](21/25): Loss: 0.0147 || Timer: 0.0038 sec.
# ===> Epoch[23](22/25): Loss: 0.0147 || Timer: 0.0037 sec.
# ===> Epoch[23](23/25): Loss: 0.0169 || Timer: 0.0038 sec.
# ===> Epoch[23](24/25): Loss: 0.0163 || Timer: 0.0054 sec.
# ===> Epoch[23](25/25): Loss: 0.0155 || Timer: 0.0026 sec.
# ===> Epoch 23 Complete: Avg. Loss: 0.0156
# ===> Epoch[24](1/25): Loss: 0.0189 || Timer: 0.0049 sec.
# ===> Epoch[24](2/25): Loss: 0.0180 || Timer: 0.0039 sec.
# ===> Epoch[24](3/25): Loss: 0.0153 || Timer: 0.0037 sec.
# ===> Epoch[24](4/25): Loss: 0.0124 || Timer: 0.0039 sec.
# ===> Epoch[24](5/25): Loss: 0.0170 || Timer: 0.0038 sec.
# ===> Epoch[24](6/25): Loss: 0.0134 || Timer: 0.0046 sec.
# ===> Epoch[24](7/25): Loss: 0.0125 || Timer: 0.0041 sec.
# ===> Epoch[24](8/25): Loss: 0.0115 || Timer: 0.0044 sec.
# ===> Epoch[24](9/25): Loss: 0.0150 || Timer: 0.0042 sec.
# ===> Epoch[24](10/25): Loss: 0.0162 || Timer: 0.0041 sec.
# ===> Epoch[24](11/25): Loss: 0.0183 || Timer: 0.0039 sec.
# ===> Epoch[24](12/25): Loss: 0.0158 || Timer: 0.0038 sec.
# ===> Epoch[24](13/25): Loss: 0.0176 || Timer: 0.0037 sec.
# ===> Epoch[24](14/25): Loss: 0.0168 || Timer: 0.0037 sec.
# ===> Epoch[24](15/25): Loss: 0.0151 || Timer: 0.0039 sec.
# ===> Epoch[24](16/25): Loss: 0.0166 || Timer: 0.0038 sec.
# ===> Epoch[24](17/25): Loss: 0.0162 || Timer: 0.0037 sec.
# ===> Epoch[24](18/25): Loss: 0.0178 || Timer: 0.0039 sec.
# ===> Epoch[24](19/25): Loss: 0.0214 || Timer: 0.0040 sec.
# ===> Epoch[24](20/25): Loss: 0.0176 || Timer: 0.0042 sec.
# ===> Epoch[24](21/25): Loss: 0.0144 || Timer: 0.0026 sec.
# ===> Epoch[24](22/25): Loss: 0.0113 || Timer: 0.0037 sec.
# ===> Epoch[24](23/25): Loss: 0.0147 || Timer: 0.0040 sec.
# ===> Epoch[24](24/25): Loss: 0.0186 || Timer: 0.0037 sec.
# ===> Epoch[24](25/25): Loss: 0.0099 || Timer: 0.0027 sec.
# ===> Epoch 24 Complete: Avg. Loss: 0.0157
# ===> Epoch[25](1/25): Loss: 0.0114 || Timer: 0.0051 sec.
# ===> Epoch[25](2/25): Loss: 0.0184 || Timer: 0.0040 sec.
# ===> Epoch[25](3/25): Loss: 0.0128 || Timer: 0.0043 sec.
# ===> Epoch[25](4/25): Loss: 0.0110 || Timer: 0.0040 sec.
# ===> Epoch[25](5/25): Loss: 0.0158 || Timer: 0.0040 sec.
# ===> Epoch[25](6/25): Loss: 0.0126 || Timer: 0.0041 sec.
# ===> Epoch[25](7/25): Loss: 0.0174 || Timer: 0.0039 sec.
# ===> Epoch[25](8/25): Loss: 0.0179 || Timer: 0.0039 sec.
# ===> Epoch[25](9/25): Loss: 0.0209 || Timer: 0.0040 sec.
# ===> Epoch[25](10/25): Loss: 0.0215 || Timer: 0.0036 sec.
# ===> Epoch[25](11/25): Loss: 0.0144 || Timer: 0.0040 sec.
# ===> Epoch[25](12/25): Loss: 0.0151 || Timer: 0.0042 sec.
# ===> Epoch[25](13/25): Loss: 0.0159 || Timer: 0.0042 sec.
# ===> Epoch[25](14/25): Loss: 0.0154 || Timer: 0.0045 sec.
# ===> Epoch[25](15/25): Loss: 0.0146 || Timer: 0.0042 sec.
# ===> Epoch[25](16/25): Loss: 0.0172 || Timer: 0.0040 sec.
# ===> Epoch[25](17/25): Loss: 0.0167 || Timer: 0.0041 sec.
# ===> Epoch[25](18/25): Loss: 0.0132 || Timer: 0.0044 sec.
# ===> Epoch[25](19/25): Loss: 0.0155 || Timer: 0.0045 sec.
# ===> Epoch[25](20/25): Loss: 0.0188 || Timer: 0.0087 sec.
# ===> Epoch[25](21/25): Loss: 0.0205 || Timer: 0.0039 sec.
# ===> Epoch[25](22/25): Loss: 0.0143 || Timer: 0.0038 sec.
# ===> Epoch[25](23/25): Loss: 0.0148 || Timer: 0.0042 sec.
# ===> Epoch[25](24/25): Loss: 0.0157 || Timer: 0.0046 sec.
# ===> Epoch[25](25/25): Loss: 0.0160 || Timer: 0.0027 sec.
# ===> Epoch 25 Complete: Avg. Loss: 0.0159
# ===> Epoch[26](1/25): Loss: 0.0153 || Timer: 0.0059 sec.
# ===> Epoch[26](2/25): Loss: 0.0102 || Timer: 0.0059 sec.
# ===> Epoch[26](3/25): Loss: 0.0166 || Timer: 0.0040 sec.
# ===> Epoch[26](4/25): Loss: 0.0103 || Timer: 0.0039 sec.
# ===> Epoch[26](5/25): Loss: 0.0145 || Timer: 0.0043 sec.
# ===> Epoch[26](6/25): Loss: 0.0101 || Timer: 0.0043 sec.
# ===> Epoch[26](7/25): Loss: 0.0231 || Timer: 0.0044 sec.
# ===> Epoch[26](8/25): Loss: 0.0169 || Timer: 0.0037 sec.
# ===> Epoch[26](9/25): Loss: 0.0157 || Timer: 0.0028 sec.
# ===> Epoch[26](10/25): Loss: 0.0145 || Timer: 0.0040 sec.
# ===> Epoch[26](11/25): Loss: 0.0168 || Timer: 0.0037 sec.
# ===> Epoch[26](12/25): Loss: 0.0214 || Timer: 0.0039 sec.
# ===> Epoch[26](13/25): Loss: 0.0135 || Timer: 0.0039 sec.
# ===> Epoch[26](14/25): Loss: 0.0134 || Timer: 0.0039 sec.
# ===> Epoch[26](15/25): Loss: 0.0147 || Timer: 0.0040 sec.
# ===> Epoch[26](16/25): Loss: 0.0183 || Timer: 0.0039 sec.
# ===> Epoch[26](17/25): Loss: 0.0112 || Timer: 0.0038 sec.
# ===> Epoch[26](18/25): Loss: 0.0134 || Timer: 0.0037 sec.
# ===> Epoch[26](19/25): Loss: 0.0191 || Timer: 0.0040 sec.
# ===> Epoch[26](20/25): Loss: 0.0146 || Timer: 0.0038 sec.
# ===> Epoch[26](21/25): Loss: 0.0179 || Timer: 0.0039 sec.
# ===> Epoch[26](22/25): Loss: 0.0169 || Timer: 0.0040 sec.
# ===> Epoch[26](23/25): Loss: 0.0150 || Timer: 0.0038 sec.
# ===> Epoch[26](24/25): Loss: 0.0125 || Timer: 0.0036 sec.
# ===> Epoch[26](25/25): Loss: 0.0185 || Timer: 0.0026 sec.
# ===> Epoch 26 Complete: Avg. Loss: 0.0154
# ===> Epoch[27](1/25): Loss: 0.0157 || Timer: 0.0050 sec.
# ===> Epoch[27](2/25): Loss: 0.0139 || Timer: 0.0031 sec.
# ===> Epoch[27](3/25): Loss: 0.0154 || Timer: 0.0040 sec.
# ===> Epoch[27](4/25): Loss: 0.0149 || Timer: 0.0040 sec.
# ===> Epoch[27](5/25): Loss: 0.0148 || Timer: 0.0041 sec.
# ===> Epoch[27](6/25): Loss: 0.0144 || Timer: 0.0048 sec.
# ===> Epoch[27](7/25): Loss: 0.0141 || Timer: 0.0045 sec.
# ===> Epoch[27](8/25): Loss: 0.0145 || Timer: 0.0048 sec.
# ===> Epoch[27](9/25): Loss: 0.0182 || Timer: 0.0037 sec.
# ===> Epoch[27](10/25): Loss: 0.0182 || Timer: 0.0039 sec.
# ===> Epoch[27](11/25): Loss: 0.0143 || Timer: 0.0041 sec.
# ===> Epoch[27](12/25): Loss: 0.0169 || Timer: 0.0038 sec.
# ===> Epoch[27](13/25): Loss: 0.0157 || Timer: 0.0040 sec.
# ===> Epoch[27](14/25): Loss: 0.0147 || Timer: 0.0036 sec.
# ===> Epoch[27](15/25): Loss: 0.0159 || Timer: 0.0037 sec.
# ===> Epoch[27](16/25): Loss: 0.0173 || Timer: 0.0038 sec.
# ===> Epoch[27](17/25): Loss: 0.0165 || Timer: 0.0037 sec.
# ===> Epoch[27](18/25): Loss: 0.0179 || Timer: 0.0040 sec.
# ===> Epoch[27](19/25): Loss: 0.0116 || Timer: 0.0046 sec.
# ===> Epoch[27](20/25): Loss: 0.0164 || Timer: 0.0039 sec.
# ===> Epoch[27](21/25): Loss: 0.0157 || Timer: 0.0037 sec.
# ===> Epoch[27](22/25): Loss: 0.0150 || Timer: 0.0038 sec.
# ===> Epoch[27](23/25): Loss: 0.0138 || Timer: 0.0038 sec.
# ===> Epoch[27](24/25): Loss: 0.0154 || Timer: 0.0037 sec.
# ===> Epoch[27](25/25): Loss: 0.0189 || Timer: 0.0026 sec.
# ===> Epoch 27 Complete: Avg. Loss: 0.0156
# ===> Epoch[28](1/25): Loss: 0.0153 || Timer: 0.0057 sec.
# ===> Epoch[28](2/25): Loss: 0.0158 || Timer: 0.0039 sec.
# ===> Epoch[28](3/25): Loss: 0.0163 || Timer: 0.0044 sec.
# ===> Epoch[28](4/25): Loss: 0.0158 || Timer: 0.0040 sec.
# ===> Epoch[28](5/25): Loss: 0.0172 || Timer: 0.0039 sec.
# ===> Epoch[28](6/25): Loss: 0.0147 || Timer: 0.0039 sec.
# ===> Epoch[28](7/25): Loss: 0.0195 || Timer: 0.0038 sec.
# ===> Epoch[28](8/25): Loss: 0.0185 || Timer: 0.0042 sec.
# ===> Epoch[28](9/25): Loss: 0.0153 || Timer: 0.0039 sec.
# ===> Epoch[28](10/25): Loss: 0.0129 || Timer: 0.0177 sec.
# ===> Epoch[28](11/25): Loss: 0.0201 || Timer: 0.0036 sec.
# ===> Epoch[28](12/25): Loss: 0.0142 || Timer: 0.0041 sec.
# ===> Epoch[28](13/25): Loss: 0.0171 || Timer: 0.0040 sec.
# ===> Epoch[28](14/25): Loss: 0.0195 || Timer: 0.0056 sec.
# ===> Epoch[28](15/25): Loss: 0.0132 || Timer: 0.0042 sec.
# ===> Epoch[28](16/25): Loss: 0.0176 || Timer: 0.0038 sec.
# ===> Epoch[28](17/25): Loss: 0.0192 || Timer: 0.0037 sec.
# ===> Epoch[28](18/25): Loss: 0.0166 || Timer: 0.0038 sec.
# ===> Epoch[28](19/25): Loss: 0.0150 || Timer: 0.0041 sec.
# ===> Epoch[28](20/25): Loss: 0.0189 || Timer: 0.0038 sec.
# ===> Epoch[28](21/25): Loss: 0.0132 || Timer: 0.0036 sec.
# ===> Epoch[28](22/25): Loss: 0.0155 || Timer: 0.0038 sec.
# ===> Epoch[28](23/25): Loss: 0.0139 || Timer: 0.0044 sec.
# ===> Epoch[28](24/25): Loss: 0.0173 || Timer: 0.0037 sec.
# ===> Epoch[28](25/25): Loss: 0.0189 || Timer: 0.0025 sec.
# ===> Epoch 28 Complete: Avg. Loss: 0.0165
# ===> Epoch[29](1/25): Loss: 0.0183 || Timer: 0.0050 sec.
# ===> Epoch[29](2/25): Loss: 0.0219 || Timer: 0.0038 sec.
# ===> Epoch[29](3/25): Loss: 0.0127 || Timer: 0.0039 sec.
# ===> Epoch[29](4/25): Loss: 0.0192 || Timer: 0.0040 sec.
# ===> Epoch[29](5/25): Loss: 0.0178 || Timer: 0.0042 sec.
# ===> Epoch[29](6/25): Loss: 0.0151 || Timer: 0.0037 sec.
# ===> Epoch[29](7/25): Loss: 0.0194 || Timer: 0.0038 sec.
# ===> Epoch[29](8/25): Loss: 0.0151 || Timer: 0.0038 sec.
# ===> Epoch[29](9/25): Loss: 0.0137 || Timer: 0.0037 sec.
# ===> Epoch[29](10/25): Loss: 0.0147 || Timer: 0.0045 sec.
# ===> Epoch[29](11/25): Loss: 0.0171 || Timer: 0.0038 sec.
# ===> Epoch[29](12/25): Loss: 0.0160 || Timer: 0.0039 sec.
# ===> Epoch[29](13/25): Loss: 0.0120 || Timer: 0.0044 sec.
# ===> Epoch[29](14/25): Loss: 0.0141 || Timer: 0.0038 sec.
# ===> Epoch[29](15/25): Loss: 0.0197 || Timer: 0.0040 sec.
# ===> Epoch[29](16/25): Loss: 0.0146 || Timer: 0.0037 sec.
# ===> Epoch[29](17/25): Loss: 0.0125 || Timer: 0.0040 sec.
# ===> Epoch[29](18/25): Loss: 0.0169 || Timer: 0.0037 sec.
# ===> Epoch[29](19/25): Loss: 0.0169 || Timer: 0.0039 sec.
# ===> Epoch[29](20/25): Loss: 0.0122 || Timer: 0.0038 sec.
# ===> Epoch[29](21/25): Loss: 0.0174 || Timer: 0.0041 sec.
# ===> Epoch[29](22/25): Loss: 0.0162 || Timer: 0.0056 sec.
# ===> Epoch[29](23/25): Loss: 0.0175 || Timer: 0.0027 sec.
# ===> Epoch[29](24/25): Loss: 0.0105 || Timer: 0.0047 sec.
# ===> Epoch[29](25/25): Loss: 0.0173 || Timer: 0.0028 sec.
# ===> Epoch 29 Complete: Avg. Loss: 0.0160
# ===> Epoch[30](1/25): Loss: 0.0173 || Timer: 0.0051 sec.
# ===> Epoch[30](2/25): Loss: 0.0172 || Timer: 0.0039 sec.
# ===> Epoch[30](3/25): Loss: 0.0146 || Timer: 0.0037 sec.
# ===> Epoch[30](4/25): Loss: 0.0136 || Timer: 0.0031 sec.
# ===> Epoch[30](5/25): Loss: 0.0201 || Timer: 0.0043 sec.
# ===> Epoch[30](6/25): Loss: 0.0151 || Timer: 0.0044 sec.
# ===> Epoch[30](7/25): Loss: 0.0167 || Timer: 0.0038 sec.
# ===> Epoch[30](8/25): Loss: 0.0126 || Timer: 0.0041 sec.
# ===> Epoch[30](9/25): Loss: 0.0190 || Timer: 0.0063 sec.
# ===> Epoch[30](10/25): Loss: 0.0165 || Timer: 0.0041 sec.
# ===> Epoch[30](11/25): Loss: 0.0182 || Timer: 0.0039 sec.
# ===> Epoch[30](12/25): Loss: 0.0166 || Timer: 0.0034 sec.
# ===> Epoch[30](13/25): Loss: 0.0151 || Timer: 0.0047 sec.
# ===> Epoch[30](14/25): Loss: 0.0135 || Timer: 0.0040 sec.
# ===> Epoch[30](15/25): Loss: 0.0143 || Timer: 0.0036 sec.
# ===> Epoch[30](16/25): Loss: 0.0155 || Timer: 0.0042 sec.
# ===> Epoch[30](17/25): Loss: 0.0110 || Timer: 0.0036 sec.
# ===> Epoch[30](18/25): Loss: 0.0176 || Timer: 0.0041 sec.
# ===> Epoch[30](19/25): Loss: 0.0134 || Timer: 0.0038 sec.
# ===> Epoch[30](20/25): Loss: 0.0171 || Timer: 0.0036 sec.
# ===> Epoch[30](21/25): Loss: 0.0150 || Timer: 0.0038 sec.
# ===> Epoch[30](22/25): Loss: 0.0172 || Timer: 0.0046 sec.
# ===> Epoch[30](23/25): Loss: 0.0189 || Timer: 0.0035 sec.
# ===> Epoch[30](24/25): Loss: 0.0142 || Timer: 0.0042 sec.
# ===> Epoch[30](25/25): Loss: 0.0169 || Timer: 0.0024 sec.
# ===> Epoch 30 Complete: Avg. Loss: 0.0159
# ===> Epoch[31](1/25): Loss: 0.0171 || Timer: 0.0050 sec.
# ===> Epoch[31](2/25): Loss: 0.0167 || Timer: 0.0042 sec.
# ===> Epoch[31](3/25): Loss: 0.0152 || Timer: 0.0037 sec.
# ===> Epoch[31](4/25): Loss: 0.0151 || Timer: 0.0037 sec.
# ===> Epoch[31](5/25): Loss: 0.0182 || Timer: 0.0040 sec.
# ===> Epoch[31](6/25): Loss: 0.0170 || Timer: 0.0059 sec.
# ===> Epoch[31](7/25): Loss: 0.0145 || Timer: 0.0041 sec.
# ===> Epoch[31](8/25): Loss: 0.0178 || Timer: 0.0039 sec.
# ===> Epoch[31](9/25): Loss: 0.0160 || Timer: 0.0039 sec.
# ===> Epoch[31](10/25): Loss: 0.0158 || Timer: 0.0041 sec.
# ===> Epoch[31](11/25): Loss: 0.0123 || Timer: 0.0037 sec.
# ===> Epoch[31](12/25): Loss: 0.0173 || Timer: 0.0040 sec.
# ===> Epoch[31](13/25): Loss: 0.0135 || Timer: 0.0039 sec.
# ===> Epoch[31](14/25): Loss: 0.0115 || Timer: 0.0038 sec.
# ===> Epoch[31](15/25): Loss: 0.0163 || Timer: 0.0040 sec.
# ===> Epoch[31](16/25): Loss: 0.0168 || Timer: 0.0038 sec.
# ===> Epoch[31](17/25): Loss: 0.0139 || Timer: 0.0038 sec.
# ===> Epoch[31](18/25): Loss: 0.0166 || Timer: 0.0038 sec.
# ===> Epoch[31](19/25): Loss: 0.0137 || Timer: 0.0038 sec.
# ===> Epoch[31](20/25): Loss: 0.0134 || Timer: 0.0037 sec.
# ===> Epoch[31](21/25): Loss: 0.0122 || Timer: 0.0038 sec.
# ===> Epoch[31](22/25): Loss: 0.0163 || Timer: 0.0042 sec.
# ===> Epoch[31](23/25): Loss: 0.0134 || Timer: 0.0036 sec.
# ===> Epoch[31](24/25): Loss: 0.0161 || Timer: 0.0050 sec.
# ===> Epoch[31](25/25): Loss: 0.0192 || Timer: 0.0026 sec.
# ===> Epoch 31 Complete: Avg. Loss: 0.0154
# ===> Epoch[32](1/25): Loss: 0.0173 || Timer: 0.0054 sec.
# ===> Epoch[32](2/25): Loss: 0.0198 || Timer: 0.0039 sec.
# ===> Epoch[32](3/25): Loss: 0.0162 || Timer: 0.0040 sec.
# ===> Epoch[32](4/25): Loss: 0.0167 || Timer: 0.0039 sec.
# ===> Epoch[32](5/25): Loss: 0.0173 || Timer: 0.0038 sec.
# ===> Epoch[32](6/25): Loss: 0.0164 || Timer: 0.0039 sec.
# ===> Epoch[32](7/25): Loss: 0.0190 || Timer: 0.0048 sec.
# ===> Epoch[32](8/25): Loss: 0.0138 || Timer: 0.0047 sec.
# ===> Epoch[32](9/25): Loss: 0.0180 || Timer: 0.0043 sec.
# ===> Epoch[32](10/25): Loss: 0.0151 || Timer: 0.0068 sec.
# ===> Epoch[32](11/25): Loss: 0.0134 || Timer: 0.0037 sec.
# ===> Epoch[32](12/25): Loss: 0.0102 || Timer: 0.0043 sec.
# ===> Epoch[32](13/25): Loss: 0.0148 || Timer: 0.0037 sec.
# ===> Epoch[32](14/25): Loss: 0.0152 || Timer: 0.0038 sec.
# ===> Epoch[32](15/25): Loss: 0.0146 || Timer: 0.0049 sec.
# ===> Epoch[32](16/25): Loss: 0.0161 || Timer: 0.0039 sec.
# ===> Epoch[32](17/25): Loss: 0.0154 || Timer: 0.0044 sec.
# ===> Epoch[32](18/25): Loss: 0.0133 || Timer: 0.0050 sec.
# ===> Epoch[32](19/25): Loss: 0.0158 || Timer: 0.0040 sec.
# ===> Epoch[32](20/25): Loss: 0.0202 || Timer: 0.0040 sec.
# ===> Epoch[32](21/25): Loss: 0.0173 || Timer: 0.0038 sec.
# ===> Epoch[32](22/25): Loss: 0.0126 || Timer: 0.0038 sec.
# ===> Epoch[32](23/25): Loss: 0.0147 || Timer: 0.0038 sec.
# ===> Epoch[32](24/25): Loss: 0.0204 || Timer: 0.0039 sec.
# ===> Epoch[32](25/25): Loss: 0.0165 || Timer: 0.0026 sec.
# ...
# ===> Epoch[59](20/25): Loss: 0.0115 || Timer: 0.0040 sec.
# ===> Epoch[59](21/25): Loss: 0.0162 || Timer: 0.0047 sec.
# ===> Epoch[59](22/25): Loss: 0.0154 || Timer: 0.0036 sec.
# ===> Epoch[59](23/25): Loss: 0.0145 || Timer: 0.0043 sec.
# ===> Epoch[59](24/25): Loss: 0.0132 || Timer: 0.0039 sec.
# ===> Epoch[59](25/25): Loss: 0.0173 || Timer: 0.0027 sec.
# ===> Epoch 59 Complete: Avg. Loss: 0.0153
# Checkpoint saved to /content/gdrive/My Drive/SRCNN/weights/ac040091dff2_epoch_59.pth
# ===> Epoch[60](1/25): Loss: 0.0159 || Timer: 0.0055 sec.
# ===> Epoch[60](2/25): Loss: 0.0146 || Timer: 0.0059 sec.
# ===> Epoch[60](3/25): Loss: 0.0172 || Timer: 0.0039 sec.
# ===> Epoch[60](4/25): Loss: 0.0121 || Timer: 0.0039 sec.
# ===> Epoch[60](5/25): Loss: 0.0147 || Timer: 0.0037 sec.
# ===> Epoch[60](6/25): Loss: 0.0157 || Timer: 0.0038 sec.
# ===> Epoch[60](7/25): Loss: 0.0161 || Timer: 0.0039 sec.
# ===> Epoch[60](8/25): Loss: 0.0162 || Timer: 0.0040 sec.
# ===> Epoch[60](9/25): Loss: 0.0215 || Timer: 0.0042 sec.
# ===> Epoch[60](10/25): Loss: 0.0193 || Timer: 0.0036 sec.
# ===> Epoch[60](11/25): Loss: 0.0171 || Timer: 0.0039 sec.
# ===> Epoch[60](12/25): Loss: 0.0161 || Timer: 0.0038 sec.
# ===> Epoch[60](13/25): Loss: 0.0123 || Timer: 0.0039 sec.
# ===> Epoch[60](14/25): Loss: 0.0207 || Timer: 0.0036 sec.
# ===> Epoch[60](15/25): Loss: 0.0161 || Timer: 0.0037 sec.
# ===> Epoch[60](16/25): Loss: 0.0145 || Timer: 0.0038 sec.
# ===> Epoch[60](17/25): Loss: 0.0142 || Timer: 0.0040 sec.
# ===> Epoch[60](18/25): Loss: 0.0158 || Timer: 0.0042 sec.
# ===> Epoch[60](19/25): Loss: 0.0142 || Timer: 0.0036 sec.
# ===> Epoch[60](20/25): Loss: 0.0174 || Timer: 0.0040 sec.
# ===> Epoch[60](21/25): Loss: 0.0141 || Timer: 0.0036 sec.
# ===> Epoch[60](22/25): Loss: 0.0131 || Timer: 0.0036 sec.
# ===> Epoch[60](23/25): Loss: 0.0172 || Timer: 0.0039 sec.
# ===> Epoch[60](24/25): Loss: 0.0146 || Timer: 0.0048 sec.
# ===> Epoch[60](25/25): Loss: 0.0160 || Timer: 0.0026 sec.
# ===> Epoch 60 Complete: Avg. Loss: 0.0159
# ===> Epoch[61](1/25): Loss: 0.0141 || Timer: 0.0065 sec.
# ===> Epoch[61](2/25): Loss: 0.0143 || Timer: 0.0048 sec.
# ===> Epoch[61](3/25): Loss: 0.0169 || Timer: 0.0041 sec.
# ===> Epoch[61](4/25): Loss: 0.0190 || Timer: 0.0038 sec.
# ===> Epoch[61](5/25): Loss: 0.0154 || Timer: 0.0039 sec.
# ===> Epoch[61](6/25): Loss: 0.0170 || Timer: 0.0041 sec.
# ===> Epoch[61](7/25): Loss: 0.0167 || Timer: 0.0037 sec.
# ===> Epoch[61](8/25): Loss: 0.0134 || Timer: 0.0042 sec.
# ===> Epoch[61](9/25): Loss: 0.0140 || Timer: 0.0039 sec.
# ===> Epoch[61](10/25): Loss: 0.0142 || Timer: 0.0037 sec.
# ===> Epoch[61](11/25): Loss: 0.0153 || Timer: 0.0038 sec.
# ===> Epoch[61](12/25): Loss: 0.0182 || Timer: 0.0039 sec.
# ===> Epoch[61](13/25): Loss: 0.0222 || Timer: 0.0039 sec.
# ===> Epoch[61](14/25): Loss: 0.0126 || Timer: 0.0037 sec.
# ===> Epoch[61](15/25): Loss: 0.0134 || Timer: 0.0036 sec.
# ===> Epoch[61](16/25): Loss: 0.0141 || Timer: 0.0040 sec.
# ===> Epoch[61](17/25): Loss: 0.0154 || Timer: 0.0038 sec.
# ===> Epoch[61](18/25): Loss: 0.0125 || Timer: 0.0038 sec.
# ===> Epoch[61](19/25): Loss: 0.0193 || Timer: 0.0040 sec.
# ===> Epoch[61](20/25): Loss: 0.0180 || Timer: 0.0041 sec.
# ===> Epoch[61](21/25): Loss: 0.0147 || Timer: 0.0035 sec.
# ===> Epoch[61](22/25): Loss: 0.0145 || Timer: 0.0039 sec.
# ===> Epoch[61](23/25): Loss: 0.0187 || Timer: 0.0038 sec.
# ===> Epoch[61](24/25): Loss: 0.0156 || Timer: 0.0039 sec.
# ===> Epoch[61](25/25): Loss: 0.0121 || Timer: 0.0024 sec.
# ===> Epoch 61 Complete: Avg. Loss: 0.0157
# ===> Epoch[62](1/25): Loss: 0.0166 || Timer: 0.0054 sec.
# ===> Epoch[62](2/25): Loss: 0.0126 || Timer: 0.0037 sec.
# ===> Epoch[62](3/25): Loss: 0.0123 || Timer: 0.0039 sec.
# ===> Epoch[62](4/25): Loss: 0.0141 || Timer: 0.0039 sec.
# ===> Epoch[62](5/25): Loss: 0.0184 || Timer: 0.0040 sec.
# ===> Epoch[62](6/25): Loss: 0.0149 || Timer: 0.0041 sec.
# ===> Epoch[62](7/25): Loss: 0.0133 || Timer: 0.0041 sec.
# ===> Epoch[62](8/25): Loss: 0.0126 || Timer: 0.0042 sec.
# ===> Epoch[62](9/25): Loss: 0.0153 || Timer: 0.0041 sec.
# ===> Epoch[62](10/25): Loss: 0.0149 || Timer: 0.0042 sec.
# ===> Epoch[62](11/25): Loss: 0.0165 || Timer: 0.0042 sec.
# ===> Epoch[62](12/25): Loss: 0.0161 || Timer: 0.0037 sec.
# ===> Epoch[62](13/25): Loss: 0.0156 || Timer: 0.0039 sec.
# ===> Epoch[62](14/25): Loss: 0.0201 || Timer: 0.0044 sec.
# ===> Epoch[62](15/25): Loss: 0.0154 || Timer: 0.0040 sec.
# ===> Epoch[62](16/25): Loss: 0.0109 || Timer: 0.0037 sec.
# ===> Epoch[62](17/25): Loss: 0.0154 || Timer: 0.0038 sec.
# ===> Epoch[62](18/25): Loss: 0.0194 || Timer: 0.0037 sec.
# ===> Epoch[62](19/25): Loss: 0.0183 || Timer: 0.0039 sec.
# ===> Epoch[62](20/25): Loss: 0.0167 || Timer: 0.0040 sec.
# ===> Epoch[62](21/25): Loss: 0.0147 || Timer: 0.0039 sec.
# ===> Epoch[62](22/25): Loss: 0.0201 || Timer: 0.0040 sec.
# ===> Epoch[62](23/25): Loss: 0.0180 || Timer: 0.0042 sec.
# ===> Epoch[62](24/25): Loss: 0.0139 || Timer: 0.0042 sec.
# ===> Epoch[62](25/25): Loss: 0.0161 || Timer: 0.0030 sec.
# ===> Epoch 62 Complete: Avg. Loss: 0.0157
# ===> Epoch[63](1/25): Loss: 0.0145 || Timer: 0.0055 sec.
# ===> Epoch[63](2/25): Loss: 0.0170 || Timer: 0.0053 sec.
# ===> Epoch[63](3/25): Loss: 0.0146 || Timer: 0.0045 sec.
# ===> Epoch[63](4/25): Loss: 0.0159 || Timer: 0.0041 sec.
# ===> Epoch[63](5/25): Loss: 0.0176 || Timer: 0.0042 sec.
# ===> Epoch[63](6/25): Loss: 0.0167 || Timer: 0.0039 sec.
# ===> Epoch[63](7/25): Loss: 0.0143 || Timer: 0.0045 sec.
# ===> Epoch[63](8/25): Loss: 0.0147 || Timer: 0.0039 sec.
# ===> Epoch[63](9/25): Loss: 0.0132 || Timer: 0.0036 sec.
# ===> Epoch[63](10/25): Loss: 0.0174 || Timer: 0.0044 sec.
# ===> Epoch[63](11/25): Loss: 0.0156 || Timer: 0.0042 sec.
# ===> Epoch[63](12/25): Loss: 0.0160 || Timer: 0.0037 sec.
# ===> Epoch[63](13/25): Loss: 0.0145 || Timer: 0.0058 sec.
# ===> Epoch[63](14/25): Loss: 0.0195 || Timer: 0.0039 sec.
# ===> Epoch[63](15/25): Loss: 0.0162 || Timer: 0.0038 sec.
# ===> Epoch[63](16/25): Loss: 0.0128 || Timer: 0.0036 sec.
# ===> Epoch[63](17/25): Loss: 0.0127 || Timer: 0.0039 sec.
# ===> Epoch[63](18/25): Loss: 0.0167 || Timer: 0.0037 sec.
# ===> Epoch[63](19/25): Loss: 0.0156 || Timer: 0.0032 sec.
# ===> Epoch[63](20/25): Loss: 0.0160 || Timer: 0.0036 sec.
# ===> Epoch[63](21/25): Loss: 0.0141 || Timer: 0.0039 sec.
# ===> Epoch[63](22/25): Loss: 0.0172 || Timer: 0.0040 sec.
# ===> Epoch[63](23/25): Loss: 0.0131 || Timer: 0.0035 sec.
# ===> Epoch[63](24/25): Loss: 0.0208 || Timer: 0.0041 sec.
# ===> Epoch[63](25/25): Loss: 0.0157 || Timer: 0.0026 sec.
# ===> Epoch 63 Complete: Avg. Loss: 0.0157
# ===> Epoch[64](1/25): Loss: 0.0139 || Timer: 0.0049 sec.
# ===> Epoch[64](2/25): Loss: 0.0165 || Timer: 0.0044 sec.
# ===> Epoch[64](3/25): Loss: 0.0146 || Timer: 0.0039 sec.
# ===> Epoch[64](4/25): Loss: 0.0184 || Timer: 0.0037 sec.
# ===> Epoch[64](5/25): Loss: 0.0139 || Timer: 0.0039 sec.
# ===> Epoch[64](6/25): Loss: 0.0157 || Timer: 0.0036 sec.
# ===> Epoch[64](7/25): Loss: 0.0190 || Timer: 0.0040 sec.
# ===> Epoch[64](8/25): Loss: 0.0165 || Timer: 0.0037 sec.
# ===> Epoch[64](9/25): Loss: 0.0164 || Timer: 0.0035 sec.
# ===> Epoch[64](10/25): Loss: 0.0128 || Timer: 0.0038 sec.
# ===> Epoch[64](11/25): Loss: 0.0158 || Timer: 0.0040 sec.
# ===> Epoch[64](12/25): Loss: 0.0139 || Timer: 0.0037 sec.
# ===> Epoch[64](13/25): Loss: 0.0194 || Timer: 0.0037 sec.
# ===> Epoch[64](14/25): Loss: 0.0154 || Timer: 0.0042 sec.
# ===> Epoch[64](15/25): Loss: 0.0133 || Timer: 0.0042 sec.
# ===> Epoch[67](15/25): Loss: 0.0167 || Timer: 0.0036 sec.
# ===> Epoch[67](16/25): Loss: 0.0155 || Timer: 0.0039 sec.
# ===> Epoch[67](17/25): Loss: 0.0132 || Timer: 0.0039 sec.
# ===> Epoch[67](18/25): Loss: 0.0171 || Timer: 0.0044 sec.
# ===> Epoch[67](19/25): Loss: 0.0135 || Timer: 0.0044 sec.
# ===> Epoch[67](20/25): Loss: 0.0142 || Timer: 0.0039 sec.
# ===> Epoch[67](21/25): Loss: 0.0170 || Timer: 0.0036 sec.
# ===> Epoch[67](22/25): Loss: 0.0185 || Timer: 0.0038 sec.
# ===> Epoch[67](23/25): Loss: 0.0181 || Timer: 0.0054 sec.
# ===> Epoch[67](24/25): Loss: 0.0179 || Timer: 0.0038 sec.
# ===> Epoch[67](25/25): Loss: 0.0162 || Timer: 0.0028 sec.
# ===> Epoch 67 Complete: Avg. Loss: 0.0155
# ===> Epoch[68](1/25): Loss: 0.0107 || Timer: 0.0051 sec.
# ===> Epoch[68](2/25): Loss: 0.0148 || Timer: 0.0039 sec.
# ===> Epoch[68](3/25): Loss: 0.0180 || Timer: 0.0040 sec.
# ===> Epoch[68](4/25): Loss: 0.0195 || Timer: 0.0038 sec.
# ===> Epoch[68](5/25): Loss: 0.0173 || Timer: 0.0037 sec.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-fc4b4345276e> in <module>()
#     128
#     129     for epoch in range(opt.start_iter, opt.nEpochs + 1):
# --> 130         train(epoch)
#     131
#     132         # learning rate is decayed by a factor of 10 every half of total epochs
#
# <ipython-input-4-fc4b4345276e> in train(epoch)
#      55     epoch_loss = 0
#      56     model.train()
# ---> 57     for iteration, batch in enumerate(training_data_loader, 1):
#      58         _, target, bicubic = Variable(batch[0]), Variable(batch[1]), Variable(batch[2])
#      59         if cuda:
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1184
#    1185             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1186             idx, data = self._get_data()
#    1187             self._tasks_outstanding -= 1
#    1188             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1150         else:
#    1151             while True:
# -> 1152                 success, data = self._try_get_data()
#    1153                 if success:
#    1154                     return data
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     988         #   (bool: whether successfully get data, any: data if successful else None)
#     989         try:
# --> 990             data = self._data_queue.get(timeout=timeout)
#     991             return (True, data)
#     992         except Exception as e:
#
# /usr/lib/python3.7/multiprocessing/queues.py in get(self, block, timeout)
#     102                 if block:
#     103                     timeout = deadline - time.monotonic()
# --> 104                     if not self._poll(timeout):
#     105                         raise Empty
#     106                 elif not self._poll():
#
# /usr/lib/python3.7/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# /usr/lib/python3.7/multiprocessing/connection.py in _poll(self, timeout)
#     412
#     413     def _poll(self, timeout):
# --> 414         r = wait([self], timeout)
#     415         return bool(r)
#     416
#
# /usr/lib/python3.7/multiprocessing/connection.py in wait(object_list, timeout)
#     919
#     920             while True:
# --> 921                 ready = selector.select(timeout)
#     922                 if ready:
#     923                     return [key.fileobj for (key, events) in ready]
#
# /usr/lib/python3.7/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %% [markdown]
# # Testing

# %%
from __future__ import print_function
import argparse

import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import DataLoader
from functools import reduce
from math import log10

# from scipy.misc import imsave
import scipy.io as sio
import time
import cv2
import easydict
from google.colab import drive
drive.mount('/content/gdrive')

opt = easydict.EasyDict({ 
    "testBatchSize": 1, 
    "self_ensemble": False,
    "chop_forward": False,
    "gpu_mode": True,
    "threads": 1,
    "seed": 123,
    "gpus": 1,
    "upscale_factor": 2,

    "input_dir":"/content/gdrive/My Drive/study/SRCNN/data/test/",  # test dataset 불러올위치
    "test_dataset": "Set5",                             # 사용할 test dataset

    "output": "/content/gdrive/My Drive/study/SRCNN/Results/", # 결과영상 저장위치

    "model_type": "VDSR",
    "residual": False,
    "model": "/content/gdrive/My Drive/study/SRCNN/weights/ac040091dff2_epoch_59.pth"})  # test에 사용할 weight 불러올 위치 ac040091dff2_epoch_59.pth


gpus_list=range(opt.gpus)
print(opt)

cuda = opt.gpu_mode
if cuda and not torch.cuda.is_available():
    raise Exception("No GPU found, please run without --cuda")

torch.manual_seed(opt.seed)
criterion = nn.MSELoss()

if cuda:
    model = model.cuda(gpus_list[0])
    criterion = criterion.cuda(gpus_list[0])


print('===> Loading datasets')
test_set = get_eval_set(os.path.join(opt.input_dir,opt.test_dataset), opt.upscale_factor)
testing_data_loader = DataLoader(dataset=test_set, num_workers=opt.threads, batch_size=opt.testBatchSize, shuffle=False)

print('===> Building model')

    #model = SRCNN(num_channels=3, base_filter=64, scale_factor=opt.upscale_factor)
model = VDSR()
model = torch.nn.DataParallel(model, device_ids=gpus_list)
model.load_state_dict(torch.load(opt.model, map_location=lambda storage, loc: storage))
print('Pre-trained SR model is loaded.')

if cuda:
    model = model.cuda(gpus_list[0])

def eval():
    avg_psnr = 0
    psnr_sq = 0
    model.eval()
    for batch in testing_data_loader:
        with torch.no_grad():
            input, bicubic, target, name = Variable(batch[0]), Variable(batch[1]), Variable(batch[2]), batch[3]
        if cuda:
            input = input.cuda(gpus_list[0])
            bicubic = bicubic.cuda(gpus_list[0])
            target = target.cuda(gpus_list[0])

        t0 = time.time()
        if opt.chop_forward:
            with torch.no_grad():
                prediction = chop_forward(input, model, opt.upscale_factor)
        else:
            if opt.self_ensemble:
                with torch.no_grad():
                    prediction = x8_forward(input, model)
            else:
                with torch.no_grad():
                    prediction = model(bicubic)
                
        if opt.residual:
            prediction = prediction + bicubic

        mse = criterion(prediction, target)
        psnr = 10 * log10(1 / mse.item())
        avg_psnr += psnr
        psnr_sq += psnr*psnr

        t1 = time.time()
        print("===> Processing: %s || Timer: %.4f sec. PSNR : %.4f" % (name[0], (t1 - t0), psnr))
        # save_img(prediction.cpu().data, name[0])
        save_img(bicubic.cpu().data, name[0])
        # save_img(target.cpu().data, name[0])
        average = avg_psnr/len(testing_data_loader)
        variance = psnr_sq/len(testing_data_loader)-average*average
    print("===> Processing Done, Average PSNR : %.4f" % (average))
    print("===>PSNR Variance : %.4f" % (variance))
def save_img(img, img_name):
    save_img = img.squeeze().clamp(0, 1).numpy().transpose(1,2,0)
    # save img
    save_dir=os.path.join(opt.output,opt.test_dataset)
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
        
    save_fn = save_dir +'/'+ img_name
    cv2.imwrite(save_fn, cv2.cvtColor(save_img*255, cv2.COLOR_BGR2RGB),  [cv2.IMWRITE_PNG_COMPRESSION, 0])

def x8_forward(img, model, precision='single'):
    def _transform(v, op):
        if precision != 'single': v = v.float()

        v2np = v.data.cpu().numpy()
        if op == 'vflip':
            tfnp = v2np[:, :, :, ::-1].copy()
        elif op == 'hflip':
            tfnp = v2np[:, :, ::-1, :].copy()
        elif op == 'transpose':
            tfnp = v2np.transpose((0, 1, 3, 2)).copy()
        
        ret = torch.Tensor(tfnp).cuda()

        if precision == 'half':
            ret = ret.half()
        elif precision == 'double':
            ret = ret.double()

        with torch.no_grad():
            ret = Variable(ret)

        return ret

    inputlist = [img]
    for tf in 'vflip', 'hflip', 'transpose':
        inputlist.extend([_transform(t, tf) for t in inputlist])

    outputlist = [model(aug) for aug in inputlist]
    for i in range(len(outputlist)):
        if i > 3:
            outputlist[i] = _transform(outputlist[i], 'transpose')
        if i % 4 > 1:
            outputlist[i] = _transform(outputlist[i], 'hflip')
        if (i % 4) % 2 == 1:
            outputlist[i] = _transform(outputlist[i], 'vflip')
    
    output = reduce((lambda x, y: x + y), outputlist) / len(outputlist)

    return output
    
def chop_forward(x, model, scale, shave=8, min_size=80000, nGPUs=opt.gpus):
    b, c, h, w = x.size()
    h_half, w_half = h // 2, w // 2
    h_size, w_size = h_half + shave, w_half + shave
    inputlist = [
        x[:, :, 0:h_size, 0:w_size],
        x[:, :, 0:h_size, (w - w_size):w],
        x[:, :, (h - h_size):h, 0:w_size],
        x[:, :, (h - h_size):h, (w - w_size):w]]

    if w_size * h_size < min_size:
        outputlist = []
        for i in range(0, 4, nGPUs):
            with torch.no_grad():
                input_batch = torch.cat(inputlist[i:(i + nGPUs)], dim=0)
            if opt.self_ensemble:
                with torch.no_grad():
                    output_batch = x8_forward(input_batch, model)
            else:
                with torch.no_grad():
                    output_batch = model(input_batch)
            outputlist.extend(output_batch.chunk(nGPUs, dim=0))
    else:
        outputlist = [
            chop_forward(patch, model, scale, shave, min_size, nGPUs)
            for patch in inputlist]

    h, w = scale * h, scale * w
    h_half, w_half = scale * h_half, scale * w_half
    h_size, w_size = scale * h_size, scale * w_size
    shave *= scale

    with torch.no_grad():
        output = Variable(x.data.new(b, c, h, w))

    output[:, :, 0:h_half, 0:w_half] \
        = outputlist[0][:, :, 0:h_half, 0:w_half]
    output[:, :, 0:h_half, w_half:w] \
        = outputlist[1][:, :, 0:h_half, (w_size - w + w_half):w_size]
    output[:, :, h_half:h, 0:w_half] \
        = outputlist[2][:, :, (h_size - h + h_half):h_size, 0:w_half]
    output[:, :, h_half:h, w_half:w] \
        = outputlist[3][:, :, (h_size - h + h_half):h_size, (w_size - w + w_half):w_size]

    return output

##Eval Start!!!!
if __name__ == '__main__':
    eval()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# {'testBatchSize': 1, 'self_ensemble': False, 'chop_forward': False, 'gpu_mode': True, 'threads': 1, 'seed': 123, 'gpus': 1, 'upscale_factor': 2, 'input_dir': '/content/gdrive/My Drive/SRCNN/data/test/', 'test_dataset': 'Set5', 'output': '/content/gdrive/My Drive/SRCNN/Results/', 'model_type': 'VDSR', 'residual': False, 'model': '/content/gdrive/My Drive/SRCNN/weights/ac040091dff2_epoch_59.pth'}
# ===> Loading datasets
# ===> Building model
# Pre-trained SR model is loaded.
# ===> Processing: Pepper.png || Timer: 0.1297 sec. PSNR : 34.7727
# ===> Processing: Fingerprint.png || Timer: 0.1168 sec. PSNR : 32.7983
# ===> Processing: House.png || Timer: 0.0297 sec. PSNR : 34.9382
# ===> Processing: Foreman.png || Timer: 0.0286 sec. PSNR : 39.4226
# ===> Processing: Lena.png || Timer: 0.1057 sec. PSNR : 36.2157
# ===> Processing: baby_GT.png || Timer: 0.0995 sec. PSNR : 36.9518
# ===> Processing: bird_GT.png || Timer: 0.0315 sec. PSNR : 37.9912
# ===> Processing: head_GT.png || Timer: 0.0296 sec. PSNR : 32.1019
# ===> Processing: butterfly_GT.png || Timer: 0.0247 sec. PSNR : 30.9518
# ===> Processing: woman_GT.png || Timer: 0.0294 sec. PSNR : 33.8992
# ===> Processing Done, Average PSNR : 35.0043
# ===>PSNR Variance : 6.4696
