# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# %cd '/gdrive/MyDrive/study/VDSR/'
# Out:
# /gdrive/MyDrive/study/VDSR

# %%
# !git remote rm origin

# %%
# !git pull
# Out:
# There is no tracking information for the current branch.
# Please specify which branch you want to merge with.
# See git-pull(1) for details.
#
#     git pull <remote> <branch>
#
# If you wish to set tracking information for this branch you can do so with:
#
#     git branch --set-upstream-to=<remote>/<branch> main

# %%
# !git pull origin main --allow-unrelated-histories
# Out:
# fatal: 'origin' does not appear to be a git repository
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !echo "#VDSR" >> README.md
# !git init
# !git config --global user.email "namkyo0724@gmail.com"
# !git config --global user.name "jnamq97"
# !git add README.md
# !git add For_github_commit.ipynb
# !git add source_code/
# !git add VDSR_test/
# !git add weights/
# !git add VDSR_SE_test/
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://jnamq97: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@github.com/jnamq97/Graduation_paper_studies.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /gdrive/MyDrive/study/VDSR/.git/
# [main b798d38] first commit
#  79 files changed, 6 insertions(+), 2 deletions(-)
#  rewrite For_github_commit.ipynb (83%)
#  create mode 100644 VDSR_test/VDSR_test01.ipynb
#  create mode 100644 VDSR_test/VDSR_test02.ipynb
#  create mode 100644 VDSR_test/VDSR_test03.ipynb
#  create mode 100644 VDSR_test/VDSR_test04.ipynb
#  create mode 100644 VDSR_test/test_nonres_01.ipynb
#  create mode 100644 weights/SE_test0/<built-in function gethostname>_epoch_19.pth
#  create mode 100644 weights/SE_test0/<built-in function gethostname>_epoch_39.pth
#  create mode 100644 weights/SE_test0/<built-in function gethostname>_epoch_59.pth
#  create mode 100644 weights/SE_test1/<built-in function gethostname>_epoch_19.pth
#  create mode 100644 weights/SE_test1/<built-in function gethostname>_epoch_39.pth
#  create mode 100644 weights/SE_test1/<built-in function gethostname>_epoch_59.pth
#  create mode 100644 weights/SE_test2/<built-in function gethostname>_epoch_19.pth
#  create mode 100644 weights/SE_test2/<built-in function gethostname>_epoch_39.pth
#  create mode 100644 weights/SE_test2/<built-in function gethostname>_epoch_59.pth
#  create mode 100644 weights/SE_test3/SE_test3<built-in function gethostname>_epoch_19.pth
#  create mode 100644 weights/SE_test3/SE_test3<built-in function gethostname>_epoch_39.pth
#  create mode 100644 weights/SE_test3/SE_test3<built-in function gethostname>_epoch_59.pth
#  create mode 100644 weights/SE_test4/<built-in function gethostname>_epoch_19.pth
#  create mode 100644 weights/SE_test4/<built-in function gethostname>_epoch_39.pth
#  create mode 100644 weights/SE_test4/<built-in function gethostname>_epoch_59.pth
#  create mode 100644 weights/SE_test5/<built-in function gethostname>_epoch_19.pth
#  create mode 100644 weights/SE_test5/<built-in function gethostname>_epoch_39.pth
#  create mode 100644 weights/SE_test5/<built-in function gethostname>_epoch_59.pth
#  create mode 100644 weights/SE_test6/<built-in function gethostname>_epoch_19.pth
#  create mode 100644 weights/SE_test6/<built-in function gethostname>_epoch_39.pth
#  create mode 100644 weights/SE_test6/<built-in function gethostname>_epoch_59.pth
#  create mode 100644 weights/test01/<built-in function gethostname>_epoch_19.pth
#  create mode 100644 weights/test01/<built-in function gethostname>_epoch_39.pth
#  create mode 100644 weights/test01/<built-in function gethostname>_epoch_59.pth
#  create mode 100644 weights/test01/<built-in function gethostname>_epoch_79.pth
#  create mode 100644 weights/test02/<built-in function gethostname>_epoch_19.pth
#  create mode 100644 weights/test02/<built-in function gethostname>_epoch_39.pth
#  create mode 100644 weights/test02/<built-in function gethostname>_epoch_59.pth
#  create mode 100644 weights/test02/<built-in function gethostname>_epoch_79.pth
#  create mode 100644 weights/test03/<built-in function gethostname>_epoch_19.pth
#  create mode 100644 weights/test03/<built-in function gethostname>_epoch_39.pth
#  create mode 100644 weights/test03/<built-in function gethostname>_epoch_59.pth
#  create mode 100644 weights/test03/<built-in function gethostname>_epoch_79.pth
#  create mode 100644 weights/test_nonres_01/<built-in function gethostname>_epoch_19.pth
#  create mode 100644 weights/test_nonres_01/<built-in function gethostname>_epoch_39.pth
#  create mode 100644 weights/test_nonres_01/<built-in function gethostname>_epoch_59.pth
#  create mode 100644 weights/test_nonres_01/<built-in function gethostname>_epoch_79.pth
#  create mode 100644 weights/used/SRCNN_epoch_test1_19.pth
#  create mode 100644 weights/used/SRCNN_epoch_test1_39.pth
#  create mode 100644 weights/used/SRCNN_epoch_test1_59.pth
#  create mode 100644 weights/used/SRCNN_epoch_test1_79.pth
#  create mode 100644 weights/used/SRCNN_epoch_test1_99.pth
#  create mode 100644 weights/used/SRCNN_epoch_test2_19.pth
#  create mode 100644 weights/used/SRCNN_epoch_test2_1_19.pth
#  create mode 100644 weights/used/SRCNN_epoch_test2_1_39.pth
#  create mode 100644 weights/used/SRCNN_epoch_test2_1_59.pth
#  create mode 100644 weights/used/SRCNN_epoch_test2_1_79.pth
#  create mode 100644 weights/used/SRCNN_epoch_test2_1_99.pth
#  create mode 100644 weights/used/SRCNN_epoch_test2_39.pth
#  create mode 100644 weights/used/SRCNN_epoch_test2_59.pth
#  create mode 100644 weights/used/SRCNN_epoch_test2_79.pth
#  create mode 100644 weights/used/SRCNN_epoch_test2_99.pth
#  create mode 100644 weights/used/SRCNN_epoch_test3_1_19.pth
#  create mode 100644 weights/used/SRCNN_epoch_test3_1_39.pth
#  create mode 100644 weights/used/SRCNN_epoch_test3_1_59.pth
#  create mode 100644 weights/used/SRCNN_epoch_test3_1_79.pth
#  create mode 100644 weights/used/SRCNN_epoch_test3_1_99.pth
#  create mode 100644 weights/used/SRCNN_epoch_test3_2_19.pth
#  create mode 100644 weights/used/SRCNN_epoch_test3_2_39.pth
#  create mode 100644 weights/used/SRCNN_epoch_test3_2_59.pth
#  create mode 100644 weights/used/SRCNN_epoch_test3_2_79.pth
#  create mode 100644 weights/used/SRCNN_epoch_test3_2_99.pth
#  create mode 100644 weights/used/SRCNN_epoch_test4_1_19.pth
#  create mode 100644 weights/used/SRCNN_epoch_test4_1_39.pth
#  create mode 100644 weights/used/SRCNN_epoch_test4_1_59.pth
#  create mode 100644 weights/used/SRCNN_epoch_test4_1_79.pth
#  create mode 100644 weights/used/SRCNN_epoch_test4_1_99.pth
#  create mode 100644 weights/used/SRCNN_epoch_test4_2_19.pth
#  create mode 100644 weights/used/SRCNN_epoch_test4_2_39.pth
#  create mode 100644 weights/used/SRCNN_epoch_test4_2_59.pth
#  create mode 100644 weights/used/SRCNN_epoch_test4_2_79.pth
#  create mode 100644 weights/used/SRCNN_epoch_test4_2_99.pth
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://jnamq97: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@github.com/jnamq97/Graduation_paper_studies.git/'

# %%
# !git add .
# !git commit -m "setup"
# !git push
# Out:
# ^C
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
# 	For_github_commit.ipynb
# 	Results/
# 	VDSR_SE_test/
# 	VDSR_test/
# 	data/
# 	source_code/
# 	weights/
#
# nothing added to commit but untracked files present
# Everything up-to-date
