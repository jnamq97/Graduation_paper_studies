# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# %cd '/gdrive/MyDrive/study/VDSR/'
# Out:
# /gdrive/MyDrive/study/VDSR

# %%
# !git remote rm origin

# %%
# !git pull
# Out:
# There is no tracking information for the current branch.
# Please specify which branch you want to merge with.
# See git-pull(1) for details.
#
#     git pull <remote> <branch>
#
# If you wish to set tracking information for this branch you can do so with:
#
#     git branch --set-upstream-to=<remote>/<branch> main

# %%
# !git pull origin main --allow-unrelated-histories
# Out:
# fatal: 'origin' does not appear to be a git repository
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !echo "#VDSR" >> README.md
# !git init
# !git config --global user.email "namkyo0724@gmail.com"
# !git config --global user.name "jnamq97"
# !git add README.md
# !git add For_github_commit.ipynb
# !git add data/
# !git add Results/
# !git add source_code/
# !git add VDSR_test/
# !git add weights/
# !git add VDSR_SE_test/
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://jnamq97: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@github.com/jnamq97/Graduation_paper_studies.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /gdrive/MyDrive/study/VDSR/.git/
#
# ^C
# ^C
# ^C
# ^C
# [main 1c14bc8] first commit
#  11 files changed, 11 insertions(+)
#  create mode 100644 For_github_commit.ipynb
#  create mode 100644 VDSR_SE_test/VDSR_SE_test0.ipynb
#  create mode 100644 VDSR_SE_test/VDSR_SE_test1.ipynb
#  create mode 100644 VDSR_SE_test/VDSR_SE_test2.ipynb
#  create mode 100644 VDSR_SE_test/VDSR_SE_test3.ipynb
#  create mode 100644 VDSR_SE_test/VDSR_SE_test4.ipynb
#  create mode 100644 VDSR_SE_test/VDSR_SE_test5.ipynb
#  create mode 100644 VDSR_SE_test/VDSR_SE_test6.ipynb
#  create mode 100644 source_code/SuperResolution(SRCNN,VDSR) (1).ipynb
#  create mode 100644 source_code/SuperResolution(SRCNN,VDSR).ipynb
# Counting objects: 15, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (14/14), done.
# Writing objects: 100% (15/15), 108.30 KiB | 1.90 MiB/s, done.
# Total 15 (delta 7), reused 0 (delta 0)
# remote: Resolving deltas: 100% (7/7), done.
# To https://github.com/jnamq97/Graduation_paper_studies.git
#    eb5801f..1c14bc8  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !git add .
# !git commit -m "setup"
# !git push
# Out:
# ^C
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
# 	For_github_commit.ipynb
# 	Results/
# 	VDSR_SE_test/
# 	VDSR_test/
# 	data/
# 	source_code/
# 	weights/
#
# nothing added to commit but untracked files present
# Everything up-to-date
